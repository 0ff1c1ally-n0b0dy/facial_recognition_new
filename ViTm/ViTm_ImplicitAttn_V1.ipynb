# %%
#####################
#FB and GOOG face recognition combined (most kept from FB and included some ideas from GOOG).
#FB
#Facebook transformer for image classification: https://github.com/facebookresearch/deit/blob/main/models_v2.py
#Go to line 269 for examples for different models with different inputs.
#The paper with details on learning rate, optimizer type etc is: https://arxiv.org/pdf/2012.12877.pdf
#GOOG
#Google transformer for image classification: https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#The paper is at the following link: https://arxiv.org/pdf/2010.11929.pdf
#Implementation that generalizes Layer_scale_init_Block and adds ScaledLayers, following Google's idea for ParallelBlock.
#Implementation of attention from the original well known paperȘ Attention is all you need: 
#https://nlp.seas.harvard.edu/2018/04/03/attention.html
#####################
###########################
#Use implicit layers in attention with different formulas. Idk what works. I am trying linear(old formula) or 
#linear(old formula)+linear(old formula**2).
############################
from torch import nn, optim, as_tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.nn.init import *
from torchvision import transforms, utils, datasets, models
import cv2
from PIL import Image
from pdb import set_trace
import time
import copy
from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import io, transform
from tqdm import trange, tqdm
import csv 
import glob 
import dlib
import pandas as pd
import numpy as np
from functools import partial
from collections import OrderedDict

# !pip install timm
from timm.models.vision_transformer import Mlp, PatchEmbed , _cfg
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model


#Imports inside facenet scripts that need to be loaded here on google colab.
import requests
from requests.adapters import HTTPAdapter
import torch
import hashlib
import shutil
import tempfile
from urllib.request import urlopen, Request

use_cuda=torch.cuda.is_available()
device=torch.device("cuda" if use_cuda else "cpu")
print(device)

#####################
#Global valriables
####################
#The following variable determines how many pictures are fed at once into the NN (this is made for speed). 
#Facebook does 4096.
batches=32   
#The following path points to the folder that contains the images with faces only.
data_dir=r"C:\Users\mihnea.andrei\Work\facial_recognition\faces_images"

def imshow(inp,title=None):
  ############
  #Imshow for tensor
  #############
    inp=inp.numpy().transpose([1,2,0])
    mean=np.array([0.485, 0.456, 0.406])
    std=np.array([0.229, 0.224, 0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.0001)

#The following function times the NN.
def timming(since):
    time_elapsed=time.time()-since
    minutes=time_elapsed // 60
    seconds=time_elapsed%60
    return "%d m:%d s"%(minutes,seconds)
# Out:
# Requirement already satisfied: timm in c:\users\mihnea.andrei\anaconda3\lib\site-packages (0.6.7)
# Requirement already satisfied: torchvision in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (0.13.0)
# Requirement already satisfied: torch>=1.4 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (1.12.0)
# Requirement already satisfied: typing_extensions in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: numpy in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (1.21.5)
# Requirement already satisfied: requests in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (9.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2021.10.8)
# cpu

# %%
#If you use the MTCNN code that does the random transformations also, you do not need all those transformations again 
#(maybe) except the horizonta flip - the angle from which the picture is taken.
data_transforms={
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),  
        #transforms.ColorJitter(brightness=0.5,contrast=0.5),
        #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(3, 7)),
        #transforms.RandomAdjustSharpness(sharpness_factor=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'eval': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])
}
phases=list(data_transforms.keys())
image_datasets={x:datasets.ImageFolder(os.path.join(data_dir,x),data_transforms[x]) for x in list(data_transforms.keys())}
dataloaders={x:torch.utils.data.DataLoader(image_datasets[x],batch_size=batches,shuffle=True) for x in list(data_transforms.keys())}
data_sizes={x:len(image_datasets[x]) for x in list(data_transforms.keys())}
class_names=image_datasets['train'].classes 

inputs, classes = next(iter(dataloaders['train']))
out=utils.make_grid(inputs)
imshow(out,title=",".join([class_names[i] for i in classes.tolist()]))

# %%
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class impl_attention(nn.Module):
    def __init__(self,dim, mask=None, dropout=None,tol=10**(-4),max_iter=50):
    #def __init__(self,query, key, value, dim, mask=None, dropout=None,tol=10**(-4),max_iter=50):
        super().__init__()
        #self.query=query
        #self.key=key
        #self.value=value
        self.mask=mask
        self.dropout=dropout
        self.tol=tol
        self.max_iter=max_iter
        self.softmax=nn.Softmax(dim=-1)
        self.tanh=nn.Tanh()
        self.relu=nn.ReLU()
        
        ##############################
        #d_k=self.query.size(-1)
        #scores=torch.matmul(query,key.transpose(-2,-1)) / math.sqrt(d_k)
        #if mask is not None:
        #    scores=scores.masked_fill(mask==0,10**(-9))   
        #in_dim=torch.matmul(self.softmax(scores),value).shape[0]
        #self.conv=nn.Conv2d(in_dim,in_dim,kernel_size=2, stride=2)
        #solf.conv_out=nn.Conv2d(in_dim,dim,kernel_size=2,stride=2)
        ###########################
        
        self.linear1=nn.Linear(dim,dim)
        self.linear2=nn.Linear(dim,dim)
        if dropout is not None:
            self.dropout_nn=nn.Dropout(dropout)
        
        
    def forward(self,query, key, value):
        value_next=torch.zeros_like(value)
        self.iterations=0
        d_k=query.size(-1)
        scores=torch.matmul(query,key.transpose(-2,-1)) / math.sqrt(d_k)
        if self.mask is not None:
            scores=scores.masked_fill(mask==0,10**(-9))
        
        while self.iterations<=self.max_iter:
            #value_next=self.linear1(torch.matmul(self.softmax(scores),value))
            #value_next=self.linear1(torch.matmul(self.softmax(scores),value)+value)
            ####################################
            #1.
            #value_next=self.softmax(self.linear1(torch.matmul(scores,value)+value))
            #2.
            #value_next=self.tanh(self.linear1(torch.matmul(self.softmax(scores),value)+value))
            #3.
            #value_next=self.tanh(self.linear1(torch.matmul(self.softmax(scores),value))+value)
            #4.
            #value_next=self.tanh(self.linear1(torch.matmul(self.softmax(scores),value)))+self.tanh(self.linear2(torch.matmul(self.softmax(scores),value)))
            #5.
            values_next=(1/d_k)*torch.sin(self.linear1(d_k*torch.matmul(self.softmax(scores),value)))
            #6.
            #values_next=(1/d_k)*torch.cos(self.linear1(d_k*torch.matmul(self.softmax(scores),value)))
            ####################################
            self.err=torch.norm(value_next-value)
            value=value_next
            self.iterations+=1
            
            if self.err<=self.tol:
                break
        
        out=value
        if self.dropout is not None:
            out=self.dropout_nn(out)
        #out=self.conv_out(torch.matmul(self.softmax(scores),value))       
        return out 
    
#LayerScale from Google
class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma

# %%
#Original Block class from FB to which I try to add the extra layers that Google has
#Can be passed to block_layers parameter in main class.
class Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,
                 Attention_block = impl_attention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        
        self.attn = Attention_block(dim=dim,dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        #Below, I add the LayerScale that Google has.
        self.ls1=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        #Below I add another LayerScale that Google has
        self.ls2=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        

    def forward(self, x):
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x),self.norm1(x),self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
#Take class from below from FB     
#Can be passed to block_layers parameter in main class.
class Layer_scale_init_Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    # with slight modifications
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm,Attention_block = impl_attention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.attn = Attention_block(dim=dim,dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        self.gamma_1 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)
        self.gamma_2 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)

    def forward(self, x):
        x = x + self.drop_path(self.gamma_1 * self.attn(x,x,x))
        x = x + self.drop_path(self.gamma_2 * self.mlp(self.norm2(x)))
        return x

# %%
###################1#########################
#Can be passed to block_layers parameter in main class.
#Implementation that generalizes Layer_scale_init_Block following Google's idea for ParallelBlock.
#############################################
class ParallelLayer_scale_init_Block(nn.Module):
    def __init__(self,dim,num_heads,mlp_ratio=4,dropout=0,drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,
                 Attention_block=impl_attention,Mlp_block=Mlp,init_values=10**(-4),num_parallel=2):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        
        #####################3
        #do not know how to multiply by gammas since those are just compositions of functions basically.
        #hopefully it does not matter since gammas are parameters and maybe it will be better if num_parameters>2
        #could add LayerScale to both attention and forward feed.
        ############################
        mlp_hidden_dim = int(dim * mlp_ratio)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim=dim,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp_block(in_features=dim,hidden_features=mlp_hidden_dim,act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm1(x),self.norm1(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#####################2##########################
#Use the generalized implementation that Google has for FB's Block_paralx2 (num_parallel=2 here for FB's implementation).
#Can be passed to block_layers parameter in main class.
################################################
class ParallelBlock(nn.Module):
    def __init__(self,dim,num_heads,num_parallel=2,mlp_ratio=4,init_values=10**(-4),dropout=0,drop_path=0,act_layer=nn.GELU,
                 norm_layer=nn.LayerNorm,Attention_block=impl_attention,Mlp_block=Mlp):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        self.norm2=norm_layer(dim)
        self.norm3=norm_layer(dim)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim=dim,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity()) 
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp(dim,hidden_features=int(dim*mlp_ratio),act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path", DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm2(x),self.norm3(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Copy class from below from FB
class hMLP_stem(nn.Module):
    """ hMLP_stem: https://arxiv.org/pdf/2203.09795.pdf
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, embed_dim=768,norm_layer=nn.SyncBatchNorm):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.proj = torch.nn.Sequential(*[nn.Conv2d(in_chans, embed_dim//4, kernel_size=4, stride=4),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim//4, kernel_size=2, stride=2),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim, kernel_size=2, stride=2),
                                          norm_layer(embed_dim),
                                         ])
        

    def forward(self, x):
        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

# %%
#Copy class from below from FB
class vit_models(nn.Module):
    """ Vision Transformer with LayerScale (https://arxiv.org/abs/2103.17239) support
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, num_classes=1000, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., drop_rate=0.,
                 drop_path_rate=0., norm_layer=nn.LayerNorm, global_pool=None,
                 block_layers = Block,
                 Patch_layer=PatchEmbed,act_layer=nn.GELU,
                 Attention_block = impl_attention, Mlp_block=Mlp,
                dpr_constant=True,init_scale=1e-4,
                mlp_ratio_clstk = 4.0):
        super().__init__()
        
        self.dropout_rate = drop_rate

            
        self.num_classes = num_classes
        self.num_features = self.embed_dim = embed_dim

        self.patch_embed = Patch_layer(
                img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))

        dpr = [drop_path_rate for i in range(depth)]
        self.blocks = nn.ModuleList([
            block_layers(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio,
                dropout=0.0, drop_path=dpr[i], norm_layer=norm_layer,
                act_layer=act_layer,Attention_block=Attention_block,Mlp_block=Mlp_block,init_values=init_scale)
            for i in range(depth)])
        

        
            
        self.norm = norm_layer(embed_dim)

        self.feature_info = [dict(num_chs=embed_dim, reduction=0, module='head')]
        self.head = nn.Linear(embed_dim, num_classes) if num_classes > 0 else nn.Identity()

        trunc_normal_(self.pos_embed, std=.02)
        trunc_normal_(self.cls_token, std=.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'pos_embed', 'cls_token'}

    def get_classifier(self):
        return self.head
    
    def get_num_layers(self):
        return len(self.blocks)
    
    def reset_classifier(self, num_classes, global_pool=''):
        self.num_classes = num_classes
        self.head = nn.Linear(self.embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward_features(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        
        x = x + self.pos_embed
        
        x = torch.cat((cls_tokens, x), dim=1)
            
        for i , blk in enumerate(self.blocks):
            x = blk(x)
            
        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):

        x = self.forward_features(x)
        
        if self.dropout_rate:
            x = F.dropout(x, p=float(self.dropout_rate), training=self.training)
        x = self.head(x)
        
        return x

# %%
#The below number is 160 because the faces extracted by MTCNN are 160x160.
img_size=160
#The number of names that the model will see (population of romania over 14).
num_classes=data_sizes["train"]
#Variables inside the network. Please check examples that start at line 271 here: 
#https://github.com/facebookresearch/deit/blob/main/models_v2.py
embed_dim=192
depth=12
num_heads=3
mlp_ratio=4

model_fit=vit_models(num_classes=num_classes,img_size=img_size,patch_size=batches,
                     embed_dim=embed_dim,depth=depth,num_heads=num_heads,mlp_ratio=mlp_ratio,
                    norm_layer=partial(nn.LayerNorm,eps=10**(-6)),
                    block_layers=ParallelBlock).to(device)

num_epochs=25
lr=3*10**(-3)
weight_decay=0.01
criterion=nn.CrossEntropyLoss()
#Facebook does AdamW. Please see paper.
#optimizer=optim.SGD(model_fit.parameters(),lr=10**(-2),momentum=0.9)
optimizer=torch.optim.AdamW(model_fit.parameters(),lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=weight_decay)
#lr_decay=lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
lr_decay=torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs)

# %%
best_model_weights=copy.deepcopy(model_fit.state_dict())
best_acc=0
since=time.time()
printing_iter=10**(1)

all_train_losses=[]
all_train_accs=[]
all_eval_losses=[]
all_eval_accs=[]
best_eval_acc=0

for epoch in range(num_epochs):
    print("-"*100)
    print("Training for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    train_losses=[]
    train_accs=[]
    counter=0

    for x, label in dataloaders["train"]:
        x=x.to(device)
        label=label.to(device)
        
        optimizer.zero_grad()
        
        output=model_fit(x)
        loss=criterion(output,label)
        
        output=torch.exp(output)
        _, pred=output.topk(1,dim=1)
        
        loss.backward()
        optimizer.step()
        lr_decay.step()
        
        last_loss=loss.item()
        train_losses.append(last_loss) 
        all_train_losses.append(last_loss)
        pred=pred.cpu()
        label=label.cpu()
        current_acc=100*torch.sum(pred==label.data).double()/batches
        train_accs.append(current_acc)
        all_train_accs.append(current_acc)
        counter+=1

        if counter%printing_iter==0:
            print("Train completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                  %(100*counter*batches/data_sizes["train"],timming(since),np.mean(train_losses),
                    np.mean(train_accs),last_loss))
    
    training_avg_loss=np.mean(train_losses)
    print("-"*100)
    print("Eval for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    eval_losses=[]
    eval_accs=[]
    counter=0
    
    with torch.no_grad():
        for x, label in dataloaders["eval"]:
            x=x.to(device)
            label=label.to(device)
            
            output=model_fit(x)
            loss=criterion(output,label)
            
            output=torch.exp(output)
            _, pred=output.topk(1,dim=1)
            
            
            last_loss=loss.item()
            eval_losses.append(last_loss)
            all_eval_losses.append(last_loss)
            pred=pred.cpu()
            label=label.cpu()
            current_acc=100*torch.sum(pred==label.data).double()/batches
            eval_accs.append(current_acc)
            all_eval_accs.append(current_acc)
            counter+=1
            
            if counter%printing_iter==0:
                print("Eval completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                      %(100*counter*batches/data_sizes["eval"],timming(since),np.mean(eval_losses),
                        np.mean(eval_accs),last_loss))
            
    eval_avg_loss=np.mean(eval_losses)
    if np.mean(eval_accs)>best_eval_acc:
        best_eval_acc=np.mean(eval_accs)
        best_model_wts = copy.deepcopy(model_fit.state_dict())
    
    print("-"*100)
    print("Completed epoch %d/%d in %s, avg train loss: %.2f, avg train acc: %.4f%%, avg eval loss: %.2f, avg eval acc: %.4f"%
          (epoch+1,num_epochs,timming(since),training_avg_loss,np.mean(train_accs),eval_avg_loss,np.mean(eval_accs)))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for epoch 1/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:0.13%, time:0 m:9 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.42
# Train completion:0.26%, time:0 m:17 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.42
# Train completion:0.40%, time:0 m:26 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.43
# Train completion:0.53%, time:0 m:36 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.43
# Train completion:0.66%, time:0 m:45 s, avg loss: 12.38, avg acc:0.0000%, last loss: 12.48
# Train completion:0.79%, time:0 m:55 s, avg loss: 12.38, avg acc:0.0000%, last loss: 12.38
# Train completion:0.92%, time:1 m:4 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.33
# Train completion:1.06%, time:1 m:13 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.37
# Train completion:1.19%, time:1 m:22 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.39
# Train completion:1.32%, time:1 m:31 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.42
# Train completion:1.45%, time:1 m:40 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.30
# Train completion:1.58%, time:1 m:50 s, avg loss: 12.35, avg acc:0.0000%, last loss: 12.20
# Train completion:29.70%, time:38 m:1 s, avg loss: 11.30, avg acc:0.0000%, last loss: 10.39
# Train completion:29.83%, time:38 m:13 s, avg loss: 11.30, avg acc:0.0000%, last loss: 10.27
# Train completion:29.96%, time:38 m:25 s, avg loss: 11.29, avg acc:0.0000%, last loss: 11.24
# Train completion:30.10%, time:38 m:37 s, avg loss: 11.29, avg acc:0.0000%, last loss: 10.35
# Train completion:30.23%, time:38 m:50 s, avg loss: 11.29, avg acc:0.0000%, last loss: 10.65
# Train completion:30.36%, time:39 m:2 s, avg loss: 11.28, avg acc:0.0000%, last loss: 10.50
# Train completion:30.49%, time:39 m:13 s, avg loss: 11.28, avg acc:0.0000%, last loss: 10.32
# Train completion:30.62%, time:39 m:26 s, avg loss: 11.28, avg acc:0.0000%, last loss: 10.55
# Train completion:30.76%, time:39 m:38 s, avg loss: 11.27, avg acc:0.0000%, last loss: 10.68
# Train completion:30.89%, time:39 m:50 s, avg loss: 11.27, avg acc:0.0000%, last loss: 10.46
# Train completion:31.02%, time:40 m:2 s, avg loss: 11.27, avg acc:0.0000%, last loss: 10.57
# Train completion:31.15%, time:40 m:14 s, avg loss: 11.27, avg acc:0.0000%, last loss: 10.60
# Train completion:31.28%, time:40 m:26 s, avg loss: 11.26, avg acc:0.0000%, last loss: 10.57
# Train completion:31.42%, time:40 m:38 s, avg loss: 11.26, avg acc:0.0000%, last loss: 10.81
# Train completion:31.55%, time:40 m:50 s, avg loss: 11.26, avg acc:0.0000%, last loss: 10.52
# Train completion:31.68%, time:41 m:2 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.55
# Train completion:31.81%, time:41 m:14 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.64
# Train completion:31.94%, time:41 m:25 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.97
# Train completion:32.08%, time:41 m:37 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.49
# Train completion:32.21%, time:41 m:49 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.49
# Train completion:32.34%, time:42 m:1 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.80
# Train completion:32.47%, time:42 m:12 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.42
# Train completion:32.60%, time:42 m:23 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.76
# Train completion:32.74%, time:42 m:35 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.43
# Train completion:32.87%, time:42 m:47 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.62
# Train completion:33.00%, time:43 m:0 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.78
# Train completion:33.13%, time:43 m:13 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.35
# Train completion:33.26%, time:43 m:26 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.32
# Train completion:33.40%, time:43 m:38 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.55
# Train completion:33.53%, time:43 m:50 s, avg loss: 11.21, avg acc:0.0394%, last loss: 10.42
# Train completion:33.66%, time:44 m:3 s, avg loss: 11.21, avg acc:0.0392%, last loss: 10.59
# Train completion:33.79%, time:44 m:16 s, avg loss: 11.21, avg acc:0.0391%, last loss: 10.54
# Train completion:33.92%, time:44 m:29 s, avg loss: 11.21, avg acc:0.0389%, last loss: 10.60
# Train completion:34.06%, time:44 m:43 s, avg loss: 11.20, avg acc:0.0388%, last loss: 10.70
# Train completion:34.19%, time:44 m:55 s, avg loss: 11.20, avg acc:0.0386%, last loss: 10.79
# Train completion:34.32%, time:45 m:8 s, avg loss: 11.20, avg acc:0.0385%, last loss: 10.42
# Train completion:34.45%, time:45 m:21 s, avg loss: 11.20, avg acc:0.0383%, last loss: 10.65
# Train completion:34.58%, time:45 m:34 s, avg loss: 11.19, avg acc:0.0382%, last loss: 10.30
# Train completion:34.72%, time:45 m:47 s, avg loss: 11.19, avg acc:0.0380%, last loss: 10.74
# Train completion:34.85%, time:45 m:59 s, avg loss: 11.19, avg acc:0.0379%, last loss: 10.55
# Train completion:42.77%, time:57 m:9 s, avg loss: 11.05, avg acc:0.0617%, last loss: 10.31
# Train completion:42.90%, time:57 m:17 s, avg loss: 11.05, avg acc:0.0615%, last loss: 10.35
# Train completion:43.03%, time:57 m:25 s, avg loss: 11.05, avg acc:0.0613%, last loss: 10.51
# Train completion:43.17%, time:57 m:34 s, avg loss: 11.05, avg acc:0.0612%, last loss: 10.36
# Train completion:43.30%, time:57 m:42 s, avg loss: 11.05, avg acc:0.0610%, last loss: 10.62
# Train completion:43.43%, time:57 m:50 s, avg loss: 11.04, avg acc:0.0608%, last loss: 10.39
# Train completion:43.56%, time:57 m:58 s, avg loss: 11.04, avg acc:0.0606%, last loss: 10.39
# Train completion:43.69%, time:58 m:7 s, avg loss: 11.04, avg acc:0.0604%, last loss: 10.47
# Train completion:43.83%, time:58 m:15 s, avg loss: 11.04, avg acc:0.0602%, last loss: 10.47
# Train completion:43.96%, time:58 m:24 s, avg loss: 11.04, avg acc:0.0601%, last loss: 10.31
# Train completion:44.09%, time:58 m:33 s, avg loss: 11.03, avg acc:0.0599%, last loss: 10.18
# Train completion:44.22%, time:58 m:41 s, avg loss: 11.03, avg acc:0.0597%, last loss: 10.35
# Train completion:44.35%, time:58 m:50 s, avg loss: 11.03, avg acc:0.0595%, last loss: 10.47
# Train completion:44.49%, time:58 m:59 s, avg loss: 11.03, avg acc:0.0593%, last loss: 10.57
# Train completion:44.62%, time:59 m:7 s, avg loss: 11.03, avg acc:0.0592%, last loss: 10.41
# Train completion:44.75%, time:59 m:16 s, avg loss: 11.02, avg acc:0.0590%, last loss: 10.23
# Train completion:44.88%, time:59 m:25 s, avg loss: 11.02, avg acc:0.0588%, last loss: 10.52
# Train completion:45.01%, time:59 m:33 s, avg loss: 11.02, avg acc:0.0587%, last loss: 10.37
# Train completion:45.15%, time:59 m:42 s, avg loss: 11.02, avg acc:0.0585%, last loss: 10.53
# Train completion:45.28%, time:59 m:51 s, avg loss: 11.02, avg acc:0.0583%, last loss: 10.43
# Train completion:45.41%, time:60 m:0 s, avg loss: 11.02, avg acc:0.0581%, last loss: 10.34
# Train completion:45.54%, time:60 m:9 s, avg loss: 11.01, avg acc:0.0580%, last loss: 10.47
# Train completion:45.67%, time:60 m:18 s, avg loss: 11.01, avg acc:0.0578%, last loss: 10.34
# Train completion:45.81%, time:60 m:26 s, avg loss: 11.01, avg acc:0.0576%, last loss: 10.48
# Train completion:45.94%, time:60 m:35 s, avg loss: 11.01, avg acc:0.0575%, last loss: 10.44
# Train completion:46.07%, time:60 m:44 s, avg loss: 11.01, avg acc:0.0573%, last loss: 10.29
# Train completion:46.20%, time:60 m:53 s, avg loss: 11.00, avg acc:0.0571%, last loss: 10.44
# Train completion:46.33%, time:61 m:2 s, avg loss: 11.00, avg acc:0.0570%, last loss: 10.53
# Train completion:46.47%, time:61 m:11 s, avg loss: 11.00, avg acc:0.0568%, last loss: 10.33
# Train completion:46.60%, time:61 m:19 s, avg loss: 11.00, avg acc:0.0567%, last loss: 10.71
# Train completion:46.73%, time:61 m:28 s, avg loss: 11.00, avg acc:0.0565%, last loss: 10.27
# Train completion:46.86%, time:61 m:37 s, avg loss: 11.00, avg acc:0.0563%, last loss: 10.34
# Train completion:46.99%, time:61 m:45 s, avg loss: 10.99, avg acc:0.0562%, last loss: 10.64
# Train completion:47.13%, time:61 m:54 s, avg loss: 10.99, avg acc:0.0560%, last loss: 10.50
# Train completion:47.26%, time:62 m:3 s, avg loss: 10.99, avg acc:0.0559%, last loss: 10.46
# Train completion:47.39%, time:62 m:11 s, avg loss: 10.99, avg acc:0.0557%, last loss: 10.36
# Train completion:47.52%, time:62 m:20 s, avg loss: 10.99, avg acc:0.0556%, last loss: 10.26
# Train completion:47.65%, time:62 m:29 s, avg loss: 10.98, avg acc:0.0554%, last loss: 10.36
# Train completion:47.79%, time:62 m:38 s, avg loss: 10.98, avg acc:0.0552%, last loss: 10.33
# Train completion:47.92%, time:62 m:46 s, avg loss: 10.98, avg acc:0.0551%, last loss: 10.34
# Train completion:48.05%, time:62 m:55 s, avg loss: 10.98, avg acc:0.0549%, last loss: 10.49
# Train completion:48.18%, time:63 m:4 s, avg loss: 10.98, avg acc:0.0548%, last loss: 10.39
# Train completion:48.31%, time:63 m:12 s, avg loss: 10.98, avg acc:0.0546%, last loss: 10.14
# Train completion:48.45%, time:63 m:21 s, avg loss: 10.97, avg acc:0.0545%, last loss: 10.19
# Train completion:48.58%, time:63 m:30 s, avg loss: 10.97, avg acc:0.0543%, last loss: 10.44
# Train completion:48.71%, time:63 m:39 s, avg loss: 10.97, avg acc:0.0542%, last loss: 10.37
# Train completion:48.84%, time:63 m:48 s, avg loss: 10.97, avg acc:0.0541%, last loss: 10.18
# Train completion:48.97%, time:63 m:56 s, avg loss: 10.97, avg acc:0.0539%, last loss: 10.39
# Train completion:49.11%, time:64 m:5 s, avg loss: 10.97, avg acc:0.0538%, last loss: 10.15
# Train completion:49.24%, time:64 m:13 s, avg loss: 10.96, avg acc:0.0536%, last loss: 10.59
# Train completion:49.37%, time:64 m:22 s, avg loss: 10.96, avg acc:0.0535%, last loss: 10.22
# Train completion:49.50%, time:64 m:31 s, avg loss: 10.96, avg acc:0.0533%, last loss: 10.27
# Train completion:49.63%, time:64 m:39 s, avg loss: 10.96, avg acc:0.0532%, last loss: 10.41
# Train completion:49.77%, time:64 m:48 s, avg loss: 10.96, avg acc:0.0531%, last loss: 10.39
# Train completion:49.90%, time:64 m:56 s, avg loss: 10.96, avg acc:0.0529%, last loss: 10.26
# Train completion:50.03%, time:65 m:5 s, avg loss: 10.96, avg acc:0.0528%, last loss: 10.25
# Train completion:50.16%, time:65 m:14 s, avg loss: 10.95, avg acc:0.0526%, last loss: 10.41
# Train completion:50.29%, time:65 m:22 s, avg loss: 10.95, avg acc:0.0525%, last loss: 10.33
# Train completion:50.43%, time:65 m:31 s, avg loss: 10.95, avg acc:0.0524%, last loss: 10.31
# Train completion:50.56%, time:65 m:39 s, avg loss: 10.95, avg acc:0.0522%, last loss: 10.23
# Train completion:50.69%, time:65 m:49 s, avg loss: 10.95, avg acc:0.0521%, last loss: 10.40
# Train completion:50.82%, time:65 m:57 s, avg loss: 10.95, avg acc:0.0519%, last loss: 10.46
# Train completion:50.95%, time:66 m:6 s, avg loss: 10.94, avg acc:0.0518%, last loss: 10.50
# Train completion:51.09%, time:66 m:14 s, avg loss: 10.94, avg acc:0.0517%, last loss: 10.24
# Train completion:51.22%, time:66 m:24 s, avg loss: 10.94, avg acc:0.0515%, last loss: 10.38
# Train completion:51.35%, time:66 m:33 s, avg loss: 10.94, avg acc:0.0514%, last loss: 10.37
# Train completion:51.48%, time:66 m:42 s, avg loss: 10.94, avg acc:0.0513%, last loss: 10.43
# Train completion:51.61%, time:66 m:51 s, avg loss: 10.94, avg acc:0.0512%, last loss: 10.34
# Train completion:51.75%, time:67 m:0 s, avg loss: 10.94, avg acc:0.0510%, last loss: 10.63
# Train completion:51.88%, time:67 m:8 s, avg loss: 10.93, avg acc:0.0509%, last loss: 10.32
# Train completion:52.01%, time:67 m:17 s, avg loss: 10.93, avg acc:0.0508%, last loss: 10.56
# Train completion:52.14%, time:67 m:26 s, avg loss: 10.93, avg acc:0.0506%, last loss: 10.24
# Train completion:52.27%, time:67 m:34 s, avg loss: 10.93, avg acc:0.0505%, last loss: 10.37
# Train completion:52.41%, time:67 m:43 s, avg loss: 10.93, avg acc:0.0504%, last loss: 10.24
# Train completion:52.54%, time:67 m:51 s, avg loss: 10.93, avg acc:0.0503%, last loss: 10.23
# Train completion:52.67%, time:68 m:0 s, avg loss: 10.93, avg acc:0.0501%, last loss: 10.32
# Train completion:52.80%, time:68 m:9 s, avg loss: 10.92, avg acc:0.0500%, last loss: 10.29
# Train completion:52.93%, time:68 m:18 s, avg loss: 10.92, avg acc:0.0499%, last loss: 10.46
# Train completion:53.07%, time:68 m:26 s, avg loss: 10.92, avg acc:0.0498%, last loss: 10.40
# Train completion:53.20%, time:68 m:35 s, avg loss: 10.92, avg acc:0.0496%, last loss: 10.47
# Train completion:53.33%, time:68 m:44 s, avg loss: 10.92, avg acc:0.0495%, last loss: 10.58
# Train completion:53.46%, time:68 m:52 s, avg loss: 10.92, avg acc:0.0494%, last loss: 10.21
# Train completion:53.59%, time:69 m:1 s, avg loss: 10.91, avg acc:0.0493%, last loss: 10.28
# Train completion:53.73%, time:69 m:10 s, avg loss: 10.91, avg acc:0.0491%, last loss: 10.29
# Train completion:53.86%, time:69 m:18 s, avg loss: 10.91, avg acc:0.0490%, last loss: 10.30
# Train completion:53.99%, time:69 m:27 s, avg loss: 10.91, avg acc:0.0489%, last loss: 10.43
# Train completion:54.12%, time:69 m:36 s, avg loss: 10.91, avg acc:0.0488%, last loss: 10.16
# Train completion:54.25%, time:69 m:44 s, avg loss: 10.91, avg acc:0.0487%, last loss: 10.28
# Train completion:54.39%, time:69 m:53 s, avg loss: 10.91, avg acc:0.0485%, last loss: 10.18
# Train completion:54.52%, time:70 m:2 s, avg loss: 10.90, avg acc:0.0484%, last loss: 10.20
# Train completion:54.65%, time:70 m:11 s, avg loss: 10.90, avg acc:0.0483%, last loss: 10.27
# Train completion:54.78%, time:70 m:19 s, avg loss: 10.90, avg acc:0.0482%, last loss: 10.31
# Train completion:54.91%, time:70 m:27 s, avg loss: 10.90, avg acc:0.0481%, last loss: 10.41
# Train completion:55.05%, time:70 m:36 s, avg loss: 10.90, avg acc:0.0480%, last loss: 10.18
# Train completion:55.18%, time:70 m:44 s, avg loss: 10.90, avg acc:0.0478%, last loss: 10.48
# Train completion:55.31%, time:70 m:53 s, avg loss: 10.90, avg acc:0.0477%, last loss: 10.33
# Train completion:55.44%, time:71 m:1 s, avg loss: 10.90, avg acc:0.0476%, last loss: 10.31
# Train completion:55.57%, time:71 m:10 s, avg loss: 10.89, avg acc:0.0475%, last loss: 10.31
# Train completion:55.71%, time:71 m:19 s, avg loss: 10.89, avg acc:0.0474%, last loss: 10.18
# Train completion:55.84%, time:71 m:28 s, avg loss: 10.89, avg acc:0.0473%, last loss: 10.63
# Train completion:55.97%, time:71 m:36 s, avg loss: 10.89, avg acc:0.0472%, last loss: 10.18
# Train completion:56.10%, time:71 m:45 s, avg loss: 10.89, avg acc:0.0471%, last loss: 10.23
# Train completion:56.23%, time:71 m:54 s, avg loss: 10.89, avg acc:0.0469%, last loss: 10.55
# Train completion:56.37%, time:72 m:3 s, avg loss: 10.89, avg acc:0.0468%, last loss: 10.33
# Train completion:56.50%, time:72 m:11 s, avg loss: 10.88, avg acc:0.0467%, last loss: 10.45
# Train completion:56.63%, time:72 m:20 s, avg loss: 10.88, avg acc:0.0466%, last loss: 10.47
# Train completion:56.76%, time:72 m:29 s, avg loss: 10.88, avg acc:0.0465%, last loss: 10.40
# Train completion:56.89%, time:72 m:38 s, avg loss: 10.88, avg acc:0.0464%, last loss: 10.31
# Train completion:57.03%, time:72 m:46 s, avg loss: 10.88, avg acc:0.0463%, last loss: 10.33
# Train completion:57.16%, time:72 m:55 s, avg loss: 10.88, avg acc:0.0462%, last loss: 10.32
# Train completion:57.29%, time:73 m:4 s, avg loss: 10.88, avg acc:0.0461%, last loss: 10.19
# Train completion:57.42%, time:73 m:13 s, avg loss: 10.88, avg acc:0.0460%, last loss: 10.25
# Train completion:57.55%, time:73 m:21 s, avg loss: 10.87, avg acc:0.0459%, last loss: 10.28
# Train completion:57.69%, time:73 m:29 s, avg loss: 10.87, avg acc:0.0458%, last loss: 10.35
# Train completion:57.82%, time:73 m:38 s, avg loss: 10.87, avg acc:0.0457%, last loss: 10.18
# Train completion:57.95%, time:73 m:46 s, avg loss: 10.87, avg acc:0.0456%, last loss: 10.28
# Train completion:58.08%, time:73 m:55 s, avg loss: 10.87, avg acc:0.0455%, last loss: 10.23
# Train completion:58.21%, time:74 m:4 s, avg loss: 10.87, avg acc:0.0454%, last loss: 10.21
# Train completion:58.35%, time:74 m:13 s, avg loss: 10.87, avg acc:0.0452%, last loss: 10.31
# Train completion:58.48%, time:74 m:21 s, avg loss: 10.87, avg acc:0.0451%, last loss: 10.15
# Train completion:58.61%, time:74 m:30 s, avg loss: 10.86, avg acc:0.0450%, last loss: 10.21
# Train completion:58.74%, time:74 m:39 s, avg loss: 10.86, avg acc:0.0449%, last loss: 10.39
# Train completion:58.87%, time:74 m:47 s, avg loss: 10.86, avg acc:0.0448%, last loss: 10.31
# Train completion:59.01%, time:74 m:56 s, avg loss: 10.86, avg acc:0.0447%, last loss: 10.25
# Train completion:59.14%, time:75 m:5 s, avg loss: 10.86, avg acc:0.0446%, last loss: 10.50
# Train completion:59.27%, time:75 m:14 s, avg loss: 10.86, avg acc:0.0445%, last loss: 10.52
# Train completion:59.40%, time:75 m:22 s, avg loss: 10.86, avg acc:0.0444%, last loss: 10.22
# Train completion:59.53%, time:75 m:31 s, avg loss: 10.86, avg acc:0.0443%, last loss: 10.35
# Train completion:59.67%, time:75 m:40 s, avg loss: 10.86, avg acc:0.0442%, last loss: 10.34
# Train completion:59.80%, time:75 m:48 s, avg loss: 10.85, avg acc:0.0442%, last loss: 10.56
# Train completion:59.93%, time:75 m:57 s, avg loss: 10.85, avg acc:0.0441%, last loss: 10.17
# Train completion:60.06%, time:76 m:5 s, avg loss: 10.85, avg acc:0.0440%, last loss: 10.53
# Train completion:60.19%, time:76 m:14 s, avg loss: 10.85, avg acc:0.0439%, last loss: 10.36
# Train completion:60.33%, time:76 m:23 s, avg loss: 10.85, avg acc:0.0438%, last loss: 10.39
# Train completion:60.46%, time:76 m:31 s, avg loss: 10.85, avg acc:0.0437%, last loss: 10.23
# Train completion:60.59%, time:76 m:40 s, avg loss: 10.85, avg acc:0.0436%, last loss: 10.28
# Train completion:60.72%, time:76 m:49 s, avg loss: 10.85, avg acc:0.0435%, last loss: 10.20
# Train completion:60.85%, time:76 m:57 s, avg loss: 10.84, avg acc:0.0434%, last loss: 10.42
# Train completion:60.99%, time:77 m:6 s, avg loss: 10.84, avg acc:0.0433%, last loss: 10.31
# Train completion:61.12%, time:77 m:14 s, avg loss: 10.84, avg acc:0.0432%, last loss: 10.21
# Train completion:61.25%, time:77 m:23 s, avg loss: 10.84, avg acc:0.0431%, last loss: 10.29
# Train completion:61.38%, time:77 m:32 s, avg loss: 10.84, avg acc:0.0430%, last loss: 10.33
# Train completion:61.51%, time:77 m:40 s, avg loss: 10.84, avg acc:0.0429%, last loss: 10.36
# Train completion:61.65%, time:77 m:49 s, avg loss: 10.84, avg acc:0.0428%, last loss: 10.27
# Train completion:61.78%, time:77 m:58 s, avg loss: 10.84, avg acc:0.0427%, last loss: 10.33
# Train completion:61.91%, time:78 m:7 s, avg loss: 10.84, avg acc:0.0426%, last loss: 10.26
# Train completion:62.04%, time:78 m:15 s, avg loss: 10.83, avg acc:0.0426%, last loss: 10.34
# Train completion:62.17%, time:78 m:24 s, avg loss: 10.83, avg acc:0.0425%, last loss: 10.43
# Train completion:62.31%, time:78 m:33 s, avg loss: 10.83, avg acc:0.0424%, last loss: 10.40
# Train completion:62.44%, time:78 m:41 s, avg loss: 10.83, avg acc:0.0423%, last loss: 10.26
# Train completion:62.57%, time:78 m:50 s, avg loss: 10.83, avg acc:0.0422%, last loss: 10.19
# Train completion:62.70%, time:78 m:59 s, avg loss: 10.83, avg acc:0.0421%, last loss: 10.47
# Train completion:62.83%, time:79 m:7 s, avg loss: 10.83, avg acc:0.0420%, last loss: 10.36
# Train completion:62.97%, time:79 m:16 s, avg loss: 10.83, avg acc:0.0419%, last loss: 10.24
# Train completion:63.10%, time:79 m:25 s, avg loss: 10.83, avg acc:0.0418%, last loss: 10.37
# Train completion:63.23%, time:79 m:34 s, avg loss: 10.82, avg acc:0.0418%, last loss: 10.27
# Train completion:63.36%, time:79 m:42 s, avg loss: 10.82, avg acc:0.0417%, last loss: 10.26
# Train completion:63.49%, time:79 m:51 s, avg loss: 10.82, avg acc:0.0416%, last loss: 10.35
# Train completion:63.63%, time:80 m:0 s, avg loss: 10.82, avg acc:0.0415%, last loss: 10.36
# Train completion:63.76%, time:80 m:8 s, avg loss: 10.82, avg acc:0.0414%, last loss: 10.40
# Train completion:63.89%, time:80 m:17 s, avg loss: 10.82, avg acc:0.0413%, last loss: 10.33
# Train completion:64.02%, time:80 m:25 s, avg loss: 10.82, avg acc:0.0412%, last loss: 10.29
# Train completion:64.15%, time:80 m:34 s, avg loss: 10.82, avg acc:0.0412%, last loss: 10.26
# Train completion:64.29%, time:80 m:43 s, avg loss: 10.82, avg acc:0.0411%, last loss: 10.28
# Train completion:64.42%, time:80 m:52 s, avg loss: 10.81, avg acc:0.0410%, last loss: 10.29
# Train completion:64.55%, time:81 m:0 s, avg loss: 10.81, avg acc:0.0409%, last loss: 10.36
# Train completion:64.68%, time:81 m:9 s, avg loss: 10.81, avg acc:0.0408%, last loss: 10.47
# Train completion:64.81%, time:81 m:18 s, avg loss: 10.81, avg acc:0.0407%, last loss: 10.39
# Train completion:64.95%, time:81 m:27 s, avg loss: 10.81, avg acc:0.0407%, last loss: 10.25
# Train completion:65.08%, time:81 m:35 s, avg loss: 10.81, avg acc:0.0406%, last loss: 10.28
# Train completion:65.21%, time:81 m:44 s, avg loss: 10.81, avg acc:0.0405%, last loss: 10.32
# Train completion:65.34%, time:81 m:53 s, avg loss: 10.81, avg acc:0.0404%, last loss: 10.33
# Train completion:65.47%, time:82 m:3 s, avg loss: 10.81, avg acc:0.0403%, last loss: 10.42
# Train completion:65.61%, time:82 m:12 s, avg loss: 10.81, avg acc:0.0402%, last loss: 10.43
# Train completion:65.74%, time:82 m:20 s, avg loss: 10.80, avg acc:0.0402%, last loss: 10.22
# Train completion:65.87%, time:82 m:29 s, avg loss: 10.80, avg acc:0.0401%, last loss: 10.30
# Train completion:66.00%, time:82 m:37 s, avg loss: 10.80, avg acc:0.0400%, last loss: 10.14
# Train completion:66.13%, time:82 m:46 s, avg loss: 10.80, avg acc:0.0399%, last loss: 10.27
# Train completion:66.27%, time:82 m:54 s, avg loss: 10.80, avg acc:0.0398%, last loss: 10.27
# Train completion:66.40%, time:83 m:3 s, avg loss: 10.80, avg acc:0.0398%, last loss: 10.36
# Train completion:66.53%, time:83 m:11 s, avg loss: 10.80, avg acc:0.0397%, last loss: 10.26
# Train completion:66.66%, time:83 m:20 s, avg loss: 10.80, avg acc:0.0396%, last loss: 10.28
# Train completion:66.79%, time:83 m:28 s, avg loss: 10.80, avg acc:0.0395%, last loss: 10.54
# Train completion:66.93%, time:83 m:37 s, avg loss: 10.80, avg acc:0.0394%, last loss: 10.29
# Train completion:67.06%, time:83 m:45 s, avg loss: 10.79, avg acc:0.0394%, last loss: 10.32
# Train completion:67.19%, time:83 m:54 s, avg loss: 10.79, avg acc:0.0393%, last loss: 10.26
# Train completion:67.32%, time:84 m:3 s, avg loss: 10.79, avg acc:0.0392%, last loss: 10.35
# Train completion:67.45%, time:84 m:12 s, avg loss: 10.79, avg acc:0.0391%, last loss: 10.21
# Train completion:67.59%, time:84 m:20 s, avg loss: 10.79, avg acc:0.0391%, last loss: 10.22
# Train completion:67.72%, time:84 m:29 s, avg loss: 10.79, avg acc:0.0390%, last loss: 10.35
# Train completion:67.85%, time:84 m:38 s, avg loss: 10.79, avg acc:0.0389%, last loss: 10.44
# Train completion:67.98%, time:84 m:46 s, avg loss: 10.79, avg acc:0.0388%, last loss: 10.24
# Train completion:68.11%, time:84 m:55 s, avg loss: 10.79, avg acc:0.0388%, last loss: 10.50
# Train completion:68.25%, time:85 m:4 s, avg loss: 10.79, avg acc:0.0387%, last loss: 10.33
# Train completion:68.38%, time:85 m:12 s, avg loss: 10.79, avg acc:0.0386%, last loss: 10.20
# Train completion:68.51%, time:85 m:21 s, avg loss: 10.78, avg acc:0.0385%, last loss: 10.28
# Train completion:68.64%, time:85 m:30 s, avg loss: 10.78, avg acc:0.0385%, last loss: 10.29
# Train completion:68.77%, time:85 m:39 s, avg loss: 10.78, avg acc:0.0384%, last loss: 10.27
# ...
# Train completion:80.79%, time:98 m:53 s, avg loss: 10.71, avg acc:0.0327%, last loss: 10.41
# Train completion:80.92%, time:99 m:2 s, avg loss: 10.71, avg acc:0.0326%, last loss: 10.13
# Train completion:81.05%, time:99 m:10 s, avg loss: 10.71, avg acc:0.0326%, last loss: 10.22
# Train completion:81.18%, time:99 m:19 s, avg loss: 10.71, avg acc:0.0325%, last loss: 10.29
# Train completion:81.31%, time:99 m:28 s, avg loss: 10.70, avg acc:0.0325%, last loss: 10.19
# Train completion:81.45%, time:99 m:36 s, avg loss: 10.70, avg acc:0.0324%, last loss: 10.35
# Train completion:81.58%, time:99 m:44 s, avg loss: 10.70, avg acc:0.0324%, last loss: 10.14
# Train completion:81.71%, time:99 m:53 s, avg loss: 10.70, avg acc:0.0323%, last loss: 10.16
# Train completion:81.84%, time:100 m:1 s, avg loss: 10.70, avg acc:0.0323%, last loss: 10.32
# Train completion:81.97%, time:100 m:10 s, avg loss: 10.70, avg acc:0.0322%, last loss: 10.25
# Train completion:82.11%, time:100 m:18 s, avg loss: 10.70, avg acc:0.0322%, last loss: 10.18
# Train completion:82.24%, time:100 m:27 s, avg loss: 10.70, avg acc:0.0321%, last loss: 10.21
# Train completion:82.37%, time:100 m:35 s, avg loss: 10.70, avg acc:0.0321%, last loss: 10.43
# Train completion:82.50%, time:100 m:43 s, avg loss: 10.70, avg acc:0.0320%, last loss: 10.18
# Train completion:82.63%, time:100 m:51 s, avg loss: 10.70, avg acc:0.0319%, last loss: 10.19
# Train completion:82.77%, time:101 m:0 s, avg loss: 10.70, avg acc:0.0319%, last loss: 10.19
# Train completion:82.90%, time:101 m:9 s, avg loss: 10.70, avg acc:0.0318%, last loss: 10.48
# Train completion:83.03%, time:101 m:17 s, avg loss: 10.70, avg acc:0.0318%, last loss: 10.16
# Train completion:83.16%, time:101 m:26 s, avg loss: 10.69, avg acc:0.0317%, last loss: 10.15
# Train completion:83.29%, time:101 m:34 s, avg loss: 10.69, avg acc:0.0317%, last loss: 10.23
# Train completion:83.43%, time:101 m:42 s, avg loss: 10.69, avg acc:0.0316%, last loss: 10.21
# Train completion:83.56%, time:101 m:51 s, avg loss: 10.69, avg acc:0.0316%, last loss: 10.18
# Train completion:83.69%, time:102 m:0 s, avg loss: 10.69, avg acc:0.0315%, last loss: 10.31
# Train completion:83.82%, time:102 m:9 s, avg loss: 10.69, avg acc:0.0315%, last loss: 10.25
# Train completion:83.95%, time:102 m:17 s, avg loss: 10.69, avg acc:0.0314%, last loss: 10.43
# Train completion:84.09%, time:102 m:27 s, avg loss: 10.69, avg acc:0.0314%, last loss: 10.17
# Train completion:84.22%, time:102 m:38 s, avg loss: 10.69, avg acc:0.0313%, last loss: 10.19
# Train completion:84.35%, time:102 m:47 s, avg loss: 10.69, avg acc:0.0313%, last loss: 10.18
# Train completion:84.48%, time:102 m:56 s, avg loss: 10.69, avg acc:0.0312%, last loss: 10.24
# Train completion:84.61%, time:103 m:5 s, avg loss: 10.69, avg acc:0.0312%, last loss: 10.27
# Train completion:84.75%, time:103 m:14 s, avg loss: 10.69, avg acc:0.0312%, last loss: 10.23
# Train completion:84.88%, time:103 m:22 s, avg loss: 10.69, avg acc:0.0311%, last loss: 10.22
# Train completion:85.01%, time:103 m:31 s, avg loss: 10.69, avg acc:0.0311%, last loss: 10.18
# Train completion:85.14%, time:103 m:39 s, avg loss: 10.68, avg acc:0.0310%, last loss: 10.24
# Train completion:85.27%, time:103 m:48 s, avg loss: 10.68, avg acc:0.0310%, last loss: 10.26
# Train completion:85.41%, time:103 m:56 s, avg loss: 10.68, avg acc:0.0309%, last loss: 10.29
# Train completion:85.54%, time:104 m:5 s, avg loss: 10.68, avg acc:0.0309%, last loss: 10.12
# Train completion:85.67%, time:104 m:14 s, avg loss: 10.68, avg acc:0.0308%, last loss: 10.17
# Train completion:85.80%, time:104 m:22 s, avg loss: 10.68, avg acc:0.0308%, last loss: 10.20
# Train completion:93.72%, time:112 m:58 s, avg loss: 10.64, avg acc:0.0282%, last loss: 10.36
# Train completion:93.85%, time:113 m:7 s, avg loss: 10.64, avg acc:0.0281%, last loss: 10.35
# Train completion:93.99%, time:113 m:16 s, avg loss: 10.64, avg acc:0.0281%, last loss: 10.24
# Train completion:94.12%, time:113 m:24 s, avg loss: 10.64, avg acc:0.0281%, last loss: 10.16
# Train completion:94.25%, time:113 m:34 s, avg loss: 10.64, avg acc:0.0280%, last loss: 10.28
# Train completion:94.38%, time:113 m:42 s, avg loss: 10.64, avg acc:0.0280%, last loss: 10.21
# Train completion:94.51%, time:113 m:51 s, avg loss: 10.64, avg acc:0.0279%, last loss: 10.25
# Train completion:94.65%, time:113 m:59 s, avg loss: 10.64, avg acc:0.0279%, last loss: 10.16
# Train completion:94.78%, time:114 m:8 s, avg loss: 10.64, avg acc:0.0279%, last loss: 10.27
# Train completion:94.91%, time:114 m:16 s, avg loss: 10.64, avg acc:0.0278%, last loss: 10.28
# Train completion:95.04%, time:114 m:25 s, avg loss: 10.64, avg acc:0.0278%, last loss: 10.24
# Train completion:95.17%, time:114 m:34 s, avg loss: 10.64, avg acc:0.0277%, last loss: 10.17
# Train completion:95.31%, time:114 m:42 s, avg loss: 10.64, avg acc:0.0277%, last loss: 10.20
# Train completion:95.44%, time:114 m:51 s, avg loss: 10.64, avg acc:0.0277%, last loss: 10.31
# Train completion:95.57%, time:115 m:0 s, avg loss: 10.64, avg acc:0.0276%, last loss: 10.26
# Train completion:95.70%, time:115 m:9 s, avg loss: 10.64, avg acc:0.0276%, last loss: 10.24
# Train completion:95.83%, time:115 m:19 s, avg loss: 10.64, avg acc:0.0275%, last loss: 10.22
# Train completion:95.97%, time:115 m:27 s, avg loss: 10.64, avg acc:0.0275%, last loss: 10.19
# Train completion:96.10%, time:115 m:36 s, avg loss: 10.63, avg acc:0.0275%, last loss: 10.26
# Train completion:96.23%, time:115 m:45 s, avg loss: 10.63, avg acc:0.0274%, last loss: 10.23
# Train completion:96.36%, time:115 m:53 s, avg loss: 10.63, avg acc:0.0274%, last loss: 10.20
# Train completion:96.49%, time:116 m:2 s, avg loss: 10.63, avg acc:0.0274%, last loss: 10.40
# Train completion:96.63%, time:116 m:12 s, avg loss: 10.63, avg acc:0.0273%, last loss: 10.40
# Train completion:96.76%, time:116 m:21 s, avg loss: 10.63, avg acc:0.0273%, last loss: 10.17
# Train completion:96.89%, time:116 m:29 s, avg loss: 10.63, avg acc:0.0272%, last loss: 10.23
# Train completion:97.02%, time:116 m:38 s, avg loss: 10.63, avg acc:0.0272%, last loss: 10.27
# Train completion:97.15%, time:116 m:46 s, avg loss: 10.63, avg acc:0.0272%, last loss: 10.23
# Train completion:97.29%, time:116 m:54 s, avg loss: 10.63, avg acc:0.0271%, last loss: 10.22
# Train completion:97.42%, time:117 m:2 s, avg loss: 10.63, avg acc:0.0271%, last loss: 10.25
# Train completion:97.55%, time:117 m:11 s, avg loss: 10.63, avg acc:0.0271%, last loss: 10.29
# Train completion:97.68%, time:117 m:20 s, avg loss: 10.63, avg acc:0.0270%, last loss: 10.20
# Train completion:97.81%, time:117 m:29 s, avg loss: 10.63, avg acc:0.0270%, last loss: 10.22
# Train completion:97.95%, time:117 m:37 s, avg loss: 10.63, avg acc:0.0270%, last loss: 10.22
# Train completion:98.08%, time:117 m:46 s, avg loss: 10.63, avg acc:0.0269%, last loss: 10.17
# Train completion:98.21%, time:117 m:55 s, avg loss: 10.63, avg acc:0.0269%, last loss: 10.21
# Train completion:98.34%, time:118 m:5 s, avg loss: 10.63, avg acc:0.0268%, last loss: 10.20
# Train completion:98.47%, time:118 m:13 s, avg loss: 10.63, avg acc:0.0268%, last loss: 10.49
# Train completion:98.61%, time:118 m:22 s, avg loss: 10.62, avg acc:0.0268%, last loss: 10.19
# Train completion:98.74%, time:118 m:31 s, avg loss: 10.62, avg acc:0.0267%, last loss: 10.28
# Train completion:98.87%, time:118 m:39 s, avg loss: 10.62, avg acc:0.0267%, last loss: 10.20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 12>()
#      31 _, pred=output.topk(1,dim=1)
#      33 loss.backward()
# ---> 34 optimizer.step()
#      35 lr_decay.step()
#      37 last_loss=loss.item()
#
# File ~\Anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:65, in _LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      63 instance._step_count += 1
#      64 wrapped = func.__get__(instance, cls)
# ---> 65 return wrapped(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\optimizer.py:109, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     107 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     108 with torch.autograd.profiler.record_function(profile_name):
# --> 109     return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:161, in AdamW.step(self, closure)
#     157             max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     159         state_steps.append(state['step'])
# --> 161     adamw(params_with_grad,
#     162           grads,
#     163           exp_avgs,
#     164           exp_avg_sqs,
#     165           max_exp_avg_sqs,
#     166           state_steps,
#     167           amsgrad=amsgrad,
#     168           beta1=beta1,
#     169           beta2=beta2,
#     170           lr=group['lr'],
#     171           weight_decay=group['weight_decay'],
#     172           eps=group['eps'],
#     173           maximize=group['maximize'],
#     174           foreach=group['foreach'],
#     175           capturable=group['capturable'])
#     177 return loss
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:218, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     215 else:
#     216     func = _single_tensor_adamw
# --> 218 func(params,
#     219      grads,
#     220      exp_avgs,
#     221      exp_avg_sqs,
#     222      max_exp_avg_sqs,
#     223      state_steps,
#     224      amsgrad=amsgrad,
#     225      beta1=beta1,
#     226      beta2=beta2,
#     227      lr=lr,
#     228      weight_decay=weight_decay,
#     229      eps=eps,
#     230      maximize=maximize,
#     231      capturable=capturable)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:268, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     265 param.mul_(1 - lr * weight_decay)
#     267 # Decay the first and second moment running average coefficient
# --> 268 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     269 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     271 if capturable:
#
# KeyboardInterrupt:

# %%
save_model_path=r"C:\Users\mihnea.andrei\Work\facial_recognition\saved_models"
save_file="/ViTm)ImplicitAttn,embedded=%d,depth=%d,eval_loss=%.4f,eval_acc=%d%%.pt"%(
    embed_dim,depth,np.mean(all_eval_losses),np.mean(all_eval_accs))

torch.save(model_fit,save_model_path+save_file)

# %%
plt.figure(figsize=(10,5))
plt.title("Train losses")
plt.plot(all_train_losses,label="train losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Evaluation losses")
plt.plot(all_eval_losses,label="eval losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Train accuracies")
plt.plot(all_train_accs,label="train accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Eval accuracies")
plt.plot(all_train_accs,label="eval accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()
