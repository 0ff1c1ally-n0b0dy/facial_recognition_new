# %%
#####################
#FB and GOOG face recognition combined (most kept from FB and included some ideas from GOOG).
#FB
#Facebook transformer for image classification: https://github.com/facebookresearch/deit/blob/main/models_v2.py
#Go to line 269 for examples for different models with different inputs.
#The paper with details on learning rate, optimizer type etc is: https://arxiv.org/pdf/2012.12877.pdf
#GOOG
#Google transformer for image classification: https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#The paper is at the following link: https://arxiv.org/pdf/2010.11929.pdf
#Implementation that generalizes Layer_scale_init_Block and adds ScaledLayers, following Google's idea for ParallelBlock.
#Implementation of attention from the original well known paperȘ Attention is all you need: 
#https://nlp.seas.harvard.edu/2018/04/03/attention.html
#####################
from google.colab import drive
drive.mount('/content/drive')

from torch import nn, optim, as_tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.nn.init import *
from torchvision import transforms, utils, datasets, models
import cv2
from PIL import Image
from pdb import set_trace
import time
import copy
from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import io, transform
from tqdm import trange, tqdm
import csv 
import glob 
import dlib
import pandas as pd
import numpy as np
from functools import partial
from collections import OrderedDict

# !pip install timm
from timm.models.vision_transformer import Mlp, PatchEmbed , _cfg
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model


#Imports inside facenet scripts that need to be loaded here on google colab.
import requests
from requests.adapters import HTTPAdapter
import torch
import hashlib
import shutil
import tempfile
from urllib.request import urlopen, Request

use_cuda=torch.cuda.is_available()
device=torch.device("cuda" if use_cuda else "cpu")
print(device)

#####################
#Global valriables
####################
#The following variable determines how many pictures are fed at once into the NN (this is made for speed). 
#Facebook does 4096.
batches=32   
#The following path points to the folder that contains the images with faces only.
data_dir="/content/drive/MyDrive/facial_recognition/images_faces"

def imshow(inp,title=None):
  ############
  #Imshow for tensor
  #############
    inp=inp.numpy().transpose([1,2,0])
    mean=np.array([0.485, 0.456, 0.406])
    std=np.array([0.229, 0.224, 0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.0001)

#The following function times the NN.
def timming(since):
    time_elapsed=time.time()-since
    minutes=time_elapsed // 60
    seconds=time_elapsed%60
    return "%d m:%d s"%(minutes,seconds)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.5-py3-none-any.whl (512 kB)
#      |████████████████████████████████| 512 kB 4.7 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.13.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Installing collected packages: timm
# Successfully installed timm-0.6.5
# cuda

# %%
#If you use the MTCNN code that does the random transformations also, you do not need all those transformations again 
#(maybe) except the horizonta flip - the angle from which the picture is taken.
data_transforms={
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),  
        #transforms.ColorJitter(brightness=0.5,contrast=0.5),
        #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(3, 7)),
        #transforms.RandomAdjustSharpness(sharpness_factor=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'eval': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])
}
phases=list(data_transforms.keys())
image_datasets={x:datasets.ImageFolder(os.path.join(data_dir,x),data_transforms[x]) for x in list(data_transforms.keys())}
dataloaders={x:torch.utils.data.DataLoader(image_datasets[x],batch_size=batches,shuffle=True) for x in list(data_transforms.keys())}
data_sizes={x:len(image_datasets[x]) for x in list(data_transforms.keys())}
class_names=image_datasets['train'].classes 

inputs, classes = next(iter(dataloaders['train']))
out=utils.make_grid(inputs)
imshow(out,title=",".join([class_names[i] for i in classes.tolist()]))

# %%
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])
def attention(query, key, value, mask=None, dropout=None):
    "Compute 'Scaled Dot Product Attention'"
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn
class MultiHeadedAttention(nn.Module):
    def __init__(self, dim, num_heads=8, dropout=0.1):
        "Take in model size and number of heads."
        super(MultiHeadedAttention, self).__init__()
        assert dim % num_heads == 0
        # We assume d_v always equals d_k
        self.d_k = dim // num_heads
        self.h = num_heads
        self.linears = clones(nn.Linear(dim, dim), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        "Implements Figure 2"
        nbatches = query.size(0)
        
        # 1) Do all the linear projections in batch from d_model => h x d_k 
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
        
        # 2) Apply attention on all the projected vectors in batch. 
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        # 3) "Concat" using a view and apply a final linear. 
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
#LayerScale from Google
class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma

# %%
#Original Block class from FB to which I try to add the extra layers that Google has
#Can be passed to block_layers parameter in main class.
class Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,
                 Attention_block = MultiHeadedAttention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        
        self.attn = Attention_block(dim=dim, num_heads=num_heads, dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        #Below, I add the LayerScale that Google has.
        self.ls1=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        #Below I add another LayerScale that Google has
        self.ls2=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        

    def forward(self, x):
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x),self.norm1(x),self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
#Take class from below from FB     
#Can be passed to block_layers parameter in main class.
class Layer_scale_init_Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    # with slight modifications
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm,Attention_block = MultiHeadedAttention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        #self.norm1 = norm_layer(dim)
        #self.norm12 = norm_layer(dim)
        #self.norm13 = norm_layer(dim)
        self.attn = Attention_block(dim=dim, num_heads=num_heads, dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        self.gamma_1 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)
        self.gamma_2 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)

    def forward(self, x):
        x = x + self.drop_path(self.gamma_1 * self.attn(x,x,x))
        x = x + self.drop_path(self.gamma_2 * self.mlp(self.norm2(x)))
        return x

# %%
#Can be passed to block_layers parameter in main class.
#Implementation that generalizes Layer_scale_init_Block following Google's idea for ParallelBlock.
class ParallelLayer_scale_init_Block(nn.Module):
    def __init__(self,dim,num_heads,mlp_ratio=4,dropout=0,drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,
                 Attention_block=MultiHeadedAttention,Mlp_block=Mlp,init_values=10**(-4),num_parallel=2):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        #self.norm2=norm_layer(dim)
        #self.norm3=norm_layer(dim)
        
        #####################3
        #do not know how to multiply by gammas since those are just compositions of functions basically.
        #hopefully it does not matter since gammas are parameters and maybe it will be better if num_parameters>2
        #could add LayerScale to both attention and forward feed.
        ############################
        mlp_hidden_dim = int(dim * mlp_ratio)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim,num_heads=num_heads,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp_block(in_features=dim,hidden_features=mlp_hidden_dim,act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm1(x),self.norm1(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Use the generalized implementation that Google has for FB's Block_paralx2 (num_parallel=2 here for FB's implementation).
#Can be passed to block_layers parameter in main class.
class ParallelBlock(nn.Module):
    def __init__(self,dim,num_heads,num_parallel=2,mlp_ratio=4,init_values=10**(-4),dropout=0,drop_path=0,act_layer=nn.GELU,
                 norm_layer=nn.LayerNorm,Attention_block=MultiHeadedAttention,Mlp_block=Mlp):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        self.norm2=norm_layer(dim)
        self.norm3=norm_layer(dim)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim,num_heads=num_heads,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity()) 
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp(dim,hidden_features=int(dim*mlp_ratio),act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path", DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm2(x),self.norm3(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Copy class from below from FB
class hMLP_stem(nn.Module):
    """ hMLP_stem: https://arxiv.org/pdf/2203.09795.pdf
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=224,  patch_size=16, in_chans=3, embed_dim=768,norm_layer=nn.SyncBatchNorm):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.proj = torch.nn.Sequential(*[nn.Conv2d(in_chans, embed_dim//4, kernel_size=4, stride=4),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim//4, kernel_size=2, stride=2),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim, kernel_size=2, stride=2),
                                          norm_layer(embed_dim),
                                         ])
        

    def forward(self, x):
        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

# %%
#Copy class from below from FB
class vit_models(nn.Module):
    """ Vision Transformer with LayerScale (https://arxiv.org/abs/2103.17239) support
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=224,  patch_size=16, in_chans=3, num_classes=1000, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., drop_rate=0.,
                 drop_path_rate=0., norm_layer=nn.LayerNorm, global_pool=None,
                 block_layers = Block,
                 Patch_layer=PatchEmbed,act_layer=nn.GELU,
                 Attention_block = MultiHeadedAttention, Mlp_block=Mlp,
                dpr_constant=True,init_scale=1e-4,
                mlp_ratio_clstk = 4.0):
        super().__init__()
        
        self.dropout_rate = drop_rate

            
        self.num_classes = num_classes
        self.num_features = self.embed_dim = embed_dim

        self.patch_embed = Patch_layer(
                img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))

        dpr = [drop_path_rate for i in range(depth)]
        self.blocks = nn.ModuleList([
            block_layers(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio,
                dropout=0.0, drop_path=dpr[i], norm_layer=norm_layer,
                act_layer=act_layer,Attention_block=Attention_block,Mlp_block=Mlp_block,init_values=init_scale)
            for i in range(depth)])
        

        
            
        self.norm = norm_layer(embed_dim)

        self.feature_info = [dict(num_chs=embed_dim, reduction=0, module='head')]
        self.head = nn.Linear(embed_dim, num_classes) if num_classes > 0 else nn.Identity()

        trunc_normal_(self.pos_embed, std=.02)
        trunc_normal_(self.cls_token, std=.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'pos_embed', 'cls_token'}

    def get_classifier(self):
        return self.head
    
    def get_num_layers(self):
        return len(self.blocks)
    
    def reset_classifier(self, num_classes, global_pool=''):
        self.num_classes = num_classes
        self.head = nn.Linear(self.embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward_features(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        
        x = x + self.pos_embed
        
        x = torch.cat((cls_tokens, x), dim=1)
            
        for i , blk in enumerate(self.blocks):
            x = blk(x)
            
        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):

        x = self.forward_features(x)
        
        if self.dropout_rate:
            x = F.dropout(x, p=float(self.dropout_rate), training=self.training)
        x = self.head(x)
        
        return x

# %%
#The below number is 160 because the faces extracted by MTCNN are 160x160.
img_size=160
#The number of names that the model will see (population of romania over 14).
num_classes=data_sizes["train"]
#Variables inside the network. Please check examples that start at line 271 here: 
#https://github.com/facebookresearch/deit/blob/main/models_v2.py
embed_dim=192
depth=12
num_heads=3
mlp_ratio=4

model_fit=vit_models(num_classes=num_classes,img_size=img_size,patch_size=batches,
                     embed_dim=embed_dim,depth=depth,num_heads=num_heads,mlp_ratio=mlp_ratio,
                    norm_layer=partial(nn.LayerNorm,eps=10**(-6)),
                    block_layers=Block).to(device)

num_epochs=25
lr=3*10**(-3)
weight_decay=0.01
criterion=nn.CrossEntropyLoss()
#Facebook does AdamW. Please see paper.
#optimizer=optim.SGD(model_fit.parameters(),lr=10**(-2),momentum=0.9)
optimizer=torch.optim.AdamW(model_fit.parameters(),lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=weight_decay)
#lr_decay=lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
lr_decay=torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs)

# %%
best_model_weights=copy.deepcopy(model_fit.state_dict())
best_acc=0
since=time.time()
printing_iter=10**(1)

all_train_losses=[]
all_train_avg_accs=[]
all_eval_losses=[]
all_eval_avg_accs=[]
best_eval_acc=0

for epoch in range(num_epochs):
    print("-"*100)
    print("Training for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    counter=0
    running_corrects=0
    train_losses=[]

    for x, label in dataloaders["train"]:
        x=x.to(device)
        label=label.to(device)
        
        optimizer.zero_grad()
        
        output=model_fit(x)
        loss=criterion(output,label)
        
        output=torch.exp(output)
        _, pred=output.topk(1,dim=1)
        
        loss.backward()
        optimizer.step()
        lr_decay.step()
        
        last_loss=loss.item()
        train_losses.append(last_loss) 
        all_train_losses.append(last_loss)
        running_corrects+=torch.sum(pred==label.data).double()
        counter+=1
        all_train_avg_accs.append(100*running_corrects/(counter*inputs.size(0)))

        if counter%printing_iter==0:
            print("Train completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                  %(100*counter*batches/data_sizes["train"],timming(since),np.mean(train_losses),
                    all_train_avg_accs[-1],last_loss))
    
    training_avg_loss=np.mean(train_losses)
    print("-"*100)
    print("Eval for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    counter=0
    running_corrects=0
    eval_losses=[]
    
    with torch.no_grad():
        for x, label in dataloaders["eval"]:
            x=x.to(device)
            label=label.to(device)
            
            output=model_fit(x)
            loss=criterion(output,label)
            
            output=torch.exp(output)
            _, pred=output.topk(1,dim=1)
            
            
            last_loss=loss.item()
            eval_losses.append(last_loss)
            all_eval_losses.append(last_loss)
            running_corrects+=torch.sum(pred==label.data).double()
            counter+=1
            all_eval_avg_accs.append(100*running_corrects/(counter*inputs.size(0)))
            
            if counter%printing_iter==0:
                print("Eval completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                      %(100*counter/data_sizes["eval"],timming(since),np.mean(eval_losses),
                        all_eval_avg_accs[-1],last_loss))
            
    eval_avg_loss=np.mean(eval_losses)
    if all_eval_avg_accs[-1]>best_eval_acc:
        best_eval_acc=all_eval_avg_accs[-1]
        best_model_wts = copy.deepcopy(model_fit.state_dict())
    
    print("-"*100)
    print("Completed epoch %d/%d in %s, avg train loss: %.2f, avg train acc: %.4f%%, avg eval loss: %.2f, avg eval acc: %.4f"%
          (epoch+1,num_epochs,timming(since),training_avg_loss,all_train_avg_accs[-1],eval_avg_loss,all_eval_avg_accs[-1]))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for epoch 1/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:0 m:1 s, avg loss: 4.72, avg acc:11.2500%, last loss: 5.45
# Train completion:10.12%, time:0 m:2 s, avg loss: 5.10, avg acc:10.4688%, last loss: 5.35
# Train completion:15.17%, time:0 m:3 s, avg loss: 5.19, avg acc:9.4792%, last loss: 5.01
# Train completion:20.23%, time:0 m:4 s, avg loss: 5.20, avg acc:8.9844%, last loss: 5.58
# Train completion:25.29%, time:0 m:6 s, avg loss: 5.13, avg acc:8.9375%, last loss: 4.87
# Train completion:30.35%, time:0 m:7 s, avg loss: 5.06, avg acc:9.0625%, last loss: 4.88
# Train completion:35.40%, time:0 m:8 s, avg loss: 4.98, avg acc:9.1964%, last loss: 4.36
# Train completion:40.46%, time:0 m:9 s, avg loss: 4.92, avg acc:9.6875%, last loss: 4.48
# Train completion:45.52%, time:0 m:11 s, avg loss: 4.87, avg acc:9.8611%, last loss: 4.62
# Train completion:50.58%, time:0 m:12 s, avg loss: 4.83, avg acc:9.7812%, last loss: 4.51
# Train completion:55.63%, time:0 m:13 s, avg loss: 4.79, avg acc:9.8864%, last loss: 4.17
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 2/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:0 m:55 s, avg loss: 10.95, avg acc:5.0000%, last loss: 11.16
# Eval completion:1.12%, time:0 m:56 s, avg loss: 10.85, avg acc:5.4688%, last loss: 10.48
# Eval completion:1.68%, time:0 m:57 s, avg loss: 11.02, avg acc:5.5208%, last loss: 10.83
# Eval completion:2.24%, time:0 m:58 s, avg loss: 11.00, avg acc:5.8594%, last loss: 11.59
# Eval completion:2.80%, time:0 m:59 s, avg loss: 11.06, avg acc:6.2500%, last loss: 11.95
# ----------------------------------------------------------------------------------------------------
# Completed epoch 2/25 in 0 m:59 s, avg train loss: 3.13, avg train acc: 33.2702%, avg eval loss: 11.10, avg eval acc: 6.2500
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 3/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:1 m:1 s, avg loss: 2.44, avg acc:48.7500%, last loss: 2.53
# Train completion:10.12%, time:1 m:2 s, avg loss: 2.53, avg acc:45.0000%, last loss: 2.92
# Train completion:15.17%, time:1 m:3 s, avg loss: 2.53, avg acc:46.0417%, last loss: 2.12
# Train completion:20.23%, time:1 m:4 s, avg loss: 2.49, avg acc:47.8125%, last loss: 2.50
# Train completion:25.29%, time:1 m:6 s, avg loss: 2.46, avg acc:48.8125%, last loss: 2.20
# Train completion:30.35%, time:1 m:7 s, avg loss: 2.44, avg acc:50.1562%, last loss: 2.77
# Train completion:35.40%, time:1 m:8 s, avg loss: 2.46, avg acc:49.3304%, last loss: 2.38
# Train completion:40.46%, time:1 m:9 s, avg loss: 2.48, avg acc:48.7500%, last loss: 2.52
# Train completion:45.52%, time:1 m:10 s, avg loss: 2.46, avg acc:48.5417%, last loss: 2.01
# Train completion:50.58%, time:1 m:12 s, avg loss: 2.45, avg acc:48.9375%, last loss: 2.02
# Train completion:55.63%, time:1 m:13 s, avg loss: 2.42, avg acc:49.5170%, last loss: 2.20
# Train completion:60.69%, time:1 m:14 s, avg loss: 2.41, avg acc:49.5052%, last loss: 2.33
# Train completion:65.75%, time:1 m:15 s, avg loss: 2.38, avg acc:49.9519%, last loss: 2.07
# Train completion:70.81%, time:1 m:17 s, avg loss: 2.36, avg acc:50.2232%, last loss: 1.90
# Train completion:75.87%, time:1 m:18 s, avg loss: 2.32, avg acc:51.1667%, last loss: 2.61
# Train completion:80.92%, time:1 m:19 s, avg loss: 2.29, avg acc:51.8359%, last loss: 2.08
# Train completion:85.98%, time:1 m:20 s, avg loss: 2.29, avg acc:51.9301%, last loss: 2.01
# Train completion:91.04%, time:1 m:22 s, avg loss: 2.27, avg acc:52.1181%, last loss: 1.87
# Train completion:96.10%, time:1 m:23 s, avg loss: 2.24, avg acc:52.7303%, last loss: 1.83
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 3/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time
25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:1 m:59 s, avg loss: 1.06, avg acc:77.8125%, last loss: 0.91
# Train completion:10.12%, time:2 m:0 s, avg loss: 1.13, avg acc:75.0000%, last loss: 1.50
# Train completion:15.17%, time:2 m:1 s, avg loss: 1.22, avg acc:72.7083%, last loss: 1.41
# Train completion:20.23%, time:2 m:2 s, avg loss: 1.23, avg acc:73.9062%, last loss: 1.24
# Train completion:25.29%, time:2 m:4 s, avg loss: 1.24, avg acc:74.3750%, last loss: 1.45
# Train completion:30.35%, time:2 m:5 s, avg loss: 1.20, avg acc:75.7292%, last loss: 1.29
# Train completion:35.40%, time:2 m:6 s, avg loss: 1.23, avg acc:74.6875%, last loss: 1.00
# Train completion:40.46%, time:2 m:7 s, avg loss: 1.22, avg acc:74.5703%, last loss: 0.61
# Train completion:45.52%, time:2 m:9 s, avg loss: 1.23, avg acc:74.2708%, last loss: 0.82
# Train completion:50.58%, time:2 m:10 s, avg loss: 1.22, avg acc:74.6875%, last loss: 0.93
# Train completion:55.63%, time:2 m:11 s, avg loss: 1.20, avg acc:75.3125%, last loss: 0.93
# Train completion:60.69%, time:2 m:12 s, avg loss: 1.21, avg acc:75.2344%, last loss: 1.41
# Train completion:65.75%, time:2 m:14 s, avg loss: 1.21, avg acc:75.1923%, last loss: 1.80
# Train completion:70.81%, time:2 m:15 s, avg loss: 1.21, avg acc:75.0670%, last loss: 1.66
# Train completion:75.87%, time:2 m:16 s, avg loss: 1.20, avg acc:75.2708%, last loss: 0.84
# Train completion:80.92%, time:2 m:18 s, avg loss: 1.19, avg acc:75.2539%, last loss: 0.68
# Train completion:85.98%, time:2 m:19 s, avg loss: 1.19, avg acc:75.4779%, last loss: 1.01
# Train completion:91.04%, time:2 m:20 s, avg loss: 1.19, avg acc:75.4514%, last loss: 0.67
# Train completion:96.10%, time:2 m:21 s, avg loss: 1.18, avg acc:75.4441%, last loss: 0.91
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 5/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:2 m:24 s, avg loss: 13.75, avg acc:3.1250%, last loss: 13.58
# Eval completion:1.12%, time:2 m:25 s, avg loss: 14.17, avg acc:2.9688%, last loss: 13.88
# Eval completion:1.68%, time:2 m:25 s, avg loss: 14.09, avg acc:3.5417%, last loss: 12.53
# Eval completion:2.24%, time:2 m:26 s, avg loss: 14.09, avg acc:3.7500%, last loss: 14.21
# Eval completion:2.80%, time:2 m:27 s, avg loss: 14.12, avg acc:3.5625%, last loss: 14.40
# ----------------------------------------------------------------------------------------------------
# Completed epoch 5/25 in 2 m:28 s, avg train loss: 1.18, avg train acc: 75.6787%, avg eval loss: 14.16, avg eval acc: 3.7388
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 6/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:2 m:29 s, avg loss: 0.78, avg acc:86.5625%, last loss: 1.40
# Train completion:10.12%, time:2 m:30 s, avg loss: 0.83, avg acc:87.6562%, last loss: 1.19
# Train completion:15.17%, time:2 m:31 s, avg loss: 0.84, avg acc:84.7917%, last loss: 1.01
# Train completion:20.23%, time:2 m:33 s, avg loss: 0.86, avg acc:83.8281%, last loss: 1.51
# Train completion:25.29%, time:2 m:34 s, avg loss: 0.86, avg acc:84.0625%, last loss: 0.49
# Train completion:30.35%, time:2 m:35 s, avg loss: 0.87, avg acc:84.6354%, last loss: 0.78
# Train completion:35.40%, time:2 m:36 s, avg loss: 0.90, avg acc:83.4375%, last loss: 1.48
# Train completion:40.46%, time:2 m:37 s, avg loss: 0.92, avg acc:82.2656%, last loss: 1.09
# Train completion:45.52%, time:2 m:39 s, avg loss: 0.93, avg acc:81.7361%, last loss: 1.21
# Train completion:50.58%, time:2 m:40 s, avg loss: 0.92, avg acc:81.9062%, last loss: 1.02
# Train completion:55.63%, time:2 m:41 s, avg loss: 0.91, avg acc:82.2159%, last loss: 0.64
# Train completion:60.69%, time:2 m:42 s, avg loss: 0.91, avg acc:82.0312%, last loss: 0.93
# Train completion:65.75%, time:2 m:43 s, avg loss: 0.91, avg acc:81.8990%, last loss: 0.60
# Train completion:70.81%, time:2 m:45 s, avg loss: 0.91, avg acc:82.0536%, last loss: 1.09
# Train completion:75.87%, time:2 m:46 s, avg loss: 0.90, avg acc:82.2292%, last loss: 0.60
# Train completion:80.92%, time:2 m:47 s, avg loss: 0.90, avg acc:82.2656%, last loss: 0.91
# Train completion:85.98%, time:2 m:48 s, avg loss: 0.89, avg acc:82.5368%, last loss: 1.04
# Train completion:91.04%, time:2 m:50 s, avg loss: 0.89, avg acc:82.5347%, last loss: 0.46
# Train completion:96.10%, time:2 m:51 s, avg loss: 0.89, avg acc:82.5000%, last loss: 0.78
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 6/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:2 m:53 s, avg loss: 14.55, avg acc:5.9375%, last loss: 14.38
# Eval completion:1.12%, time:2 m:53 s, avg loss: 14.61, avg acc:6.0938%, last loss: 15.28
# Eval completion:1.68%, time:2 m:54 s, avg loss: 14.51, avg acc:5.9375%, last loss: 13.90
# Eval completion:2.24%, time:2 m:55 s, avg loss: 14.53, avg acc:6.1719%, last loss: 13.37
# Eval completion:2.80%, time:2 m:56 s, avg loss: 14.63, avg acc:5.3750%, last loss: 13.93
# ----------------------------------------------------------------------------------------------------
# Completed epoch 6/25 in 2 m:57 s, avg train loss: 0.89, avg train acc: 82.3390%, avg eval loss: 14.65, avg eval acc: 5.3013
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 7/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:2 m:58 s, avg loss: 0.60, avg acc:89.6875%, last loss: 0.57
# Train completion:10.12%, time:2 m:59 s, avg loss: 0.61, avg acc:90.6250%, last loss: 0.74
# Train completion:15.17%, time:3 m:0 s, avg loss: 0.70, avg acc:87.6042%, last loss: 0.96
# Train completion:20.23%, time:3 m:2 s, avg loss: 0.71, avg acc:87.4219%, last loss: 0.86
# Train completion:25.29%, time:3 m:3 s, avg loss: 0.72, avg acc:86.8125%, last loss: 0.61
# Train completion:30.35%, time:3 m:4 s, avg loss: 0.72, avg acc:86.8750%, last loss: 0.42
# Train completion:35.40%, time:3 m:5 s, avg loss: 0.71, avg acc:87.6786%, last loss: 0.36
# Train completion:40.46%, time:3 m:6 s, avg loss: 0.72, avg acc:87.3047%, last loss: 0.57
# Train completion:45.52%, time:3 m:8 s, avg loss: 0.72, avg acc:86.7708%, last loss: 0.78
# Train completion:50.58%, time:3 m:9 s, avg loss: 0.71, avg acc:87.3125%, last loss: 0.50
# Train completion:55.63%, time:3 m:10 s, avg loss: 0.70, avg acc:87.6420%, last loss: 0.59
# Train completion:60.69%, time:3 m:11 s, avg loss: 0.69, avg acc:88.2031%, last loss: 0.41
25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:4 m:54 s, avg loss: 0.26, avg acc:97.5000%, last loss: 0.17
# Train completion:10.12%, time:4 m:55 s, avg loss: 0.25, avg acc:99.8438%, last loss: 0.19
# Train completion:15.17%, time:4 m:57 s, avg loss: 0.26, avg acc:100.3125%, last loss: 0.55
# Train completion:20.23%, time:4 m:58 s, avg loss: 0.29, avg acc:98.2812%, last loss: 0.35
# Train completion:25.29%, time:4 m:59 s, avg loss: 0.29, avg acc:97.6875%, last loss: 0.21
# Train completion:30.35%, time:5 m:0 s, avg loss: 0.30, avg acc:97.8125%, last loss: 0.16
# Train completion:35.40%, time:5 m:2 s, avg loss: 0.30, avg acc:97.5000%, last loss: 0.19
# Train completion:40.46%, time:5 m:3 s, avg loss: 0.30, avg acc:97.3047%, last loss: 0.54
# Train completion:45.52%, time:5 m:4 s, avg loss: 0.32, avg acc:96.6319%, last loss: 0.35
# Train completion:50.58%, time:5 m:5 s, avg loss: 0.32, avg acc:96.2188%, last loss: 0.27
# Train completion:55.63%, time:5 m:6 s, avg loss: 0.32, avg acc:96.2216%, last loss: 0.16
# Train completion:60.69%, time:5 m:8 s, avg loss: 0.32, avg acc:96.1979%, last loss: 0.12
# Train completion:65.75%, time:5 m:9 s, avg loss: 0.32, avg acc:96.4183%, last loss: 0.28
# Train completion:70.81%, time:5 m:10 s, avg loss: 0.32, avg acc:96.6741%, last loss: 0.20
# Train completion:75.87%, time:5 m:11 s, avg loss: 0.32, avg acc:96.5417%, last loss: 0.58
# Train completion:80.92%, time:5 m:13 s, avg loss: 0.32, avg acc:96.3867%, last loss: 0.25
# Train completion:85.98%, time:5 m:14 s, avg loss: 0.33, avg acc:96.3235%, last loss: 0.25
# Train completion:91.04%, time:5 m:15 s, avg loss: 0.33, avg acc:96.4583%, last loss: 0.64
# Train completion:96.10%, time:5 m:16 s, avg loss: 0.33, avg acc:96.2664%, last loss: 0.38
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 11/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:5 m:18 s, avg loss: 16.88, avg acc:6.8750%, last loss: 17.47
# Eval completion:1.12%, time:5 m:19 s, avg loss: 16.85, avg acc:5.7812%, last loss: 16.74
# Eval completion:1.68%, time:5 m:20 s, avg loss: 16.64, avg acc:5.9375%, last loss: 13.59
# Eval completion:2.24%, time:5 m:21 s, avg loss: 16.76, avg acc:6.0156%, last loss: 17.82
# Eval completion:2.80%, time:5 m:21 s, avg loss: 16.72, avg acc:5.5625%, last loss: 15.40
# ----------------------------------------------------------------------------------------------------
# Completed epoch 11/25 in 5 m:22 s, avg train loss: 0.34, avg train acc: 96.1648%, avg eval loss: 16.71, avg eval acc: 5.6362
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 12/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:5 m:23 s, avg loss: 0.33, avg acc:98.7500%, last loss: 0.43
# Train completion:10.12%, time:5 m:24 s, avg loss: 0.25, avg acc:98.9062%, last loss: 0.16
# Train completion:15.17%, time:5 m:26 s, avg loss: 0.24, avg acc:98.8542%, last loss: 0.24
# Train completion:20.23%, time:5 m:27 s, avg loss: 0.25, avg acc:99.6094%, last loss: 0.23
# Train completion:25.29%, time:5 m:28 s, avg loss: 0.25, avg acc:99.3750%, last loss: 0.18
# Train completion:30.35%, time:5 m:29 s, avg loss: 0.25, avg acc:99.4271%, last loss: 0.22
# Train completion:35.40%, time:5 m:30 s, avg loss: 0.25, avg acc:99.2857%, last loss: 0.05
# Train completion:40.46%, time:5 m:32 s, avg loss: 0.24, avg acc:99.3750%, last loss: 0.24
# Train completion:45.52%, time:5 m:33 s, avg loss: 0.24, avg acc:98.9931%, last loss: 0.17
# Train completion:50.58%, time:5 m:34 s, avg loss: 0.24, avg acc:98.9062%, last loss: 0.14
# Train completion:55.63%, time:5 m:35 s, avg loss: 0.24, avg acc:98.8920%, last loss: 0.31
# Train completion:60.69%, time:5 m:36 s, avg loss: 0.24, avg acc:99.3229%, last loss: 0.11
# Train completion:65.75%, time:5 m:38 s, avg loss: 0.24, avg acc:99.0385%, last loss: 0.34
# Train completion:70.81%, time:5 m:39 s, avg loss: 0.24, avg acc:98.9062%, last loss: 0.42
# Train completion:75.87%, time:5 m:40 s, avg loss: 0.24, avg acc:99.1042%, last loss: 0.24
# Train completion:80.92%, time:5 m:41 s, avg loss: 0.24, avg acc:99.1406%, last loss: 0.25
# Train completion:85.98%, time:5 m:43 s, avg loss: 0.24, avg acc:99.0993%, last loss: 0.14
# Train completion:91.04%, time:5 m:44 s, avg loss: 0.24, avg acc:99.0278%, last loss: 0.21
# Train completion:96.10%, time:5 m:45 s, avg loss: 0.24, avg acc:99.0789%, last loss: 0.09
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 12/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:5 m:47 s, avg loss: 17.57, avg acc:6.5625%, last loss: 19.51
# Eval completion:1.12%, time:5 m:48 s, avg loss: 17.28, avg acc:6.4062%, last loss: 18.41
# Eval completion:1.68%, time:5 m:48 s, avg loss: 17.33, avg acc:6.1458%, last loss: 15.74
# Eval completion:2.24%, time:5 m:49 s, avg loss: 17.19, avg acc:6.3281%, last loss: 18.45
# Eval completion:2.80%, time:5 m:50 s, avg loss: 17.13, avg acc:5.8125%, last loss: 16.39
# ----------------------------------------------------------------------------------------------------
# Completed epoch 12/25 in 5 m:51 s, avg train loss: 0.24, avg train acc: 98.8952%, avg eval loss: 17.10, avg eval acc: 5.6920
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 13/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:5 m:52 s, avg loss: 0.14, avg acc:101.8750%, last loss: 0.06
# Train completion:10.12%, time:5 m:53 s, avg loss: 0.13, avg acc:101.7188%, last loss: 0.28
# Train completion:15.17%, time:5 m:54 s, avg loss: 0.13, avg acc:101.8750%, last loss: 0.21
# Train completion:20.23%, time:5 m:55 s, avg loss: 0.14, avg acc:101.7188%, last loss: 0.13
# Train completion:25.29%, time:5 m:57 s, avg loss: 0.15, avg acc:101.8125%, last loss: 0.27
# Train completion:30.35%, time:5 m:58 s, avg loss: 0.16, avg acc:101.4583%, last loss: 0.07
# Train completion:35.40%, time:5 m:59 s, avg loss: 0.16, avg acc:101.7411%, last loss: 0.28
# Train completion:40.46%, time:6 m:0 s, avg loss: 0.16, avg acc:101.6016%, last loss: 0.21
# Train completion:45.52%, time:6 m:1 s, avg loss: 0.16, avg acc:101.5278%, last loss: 0.35
# Train completion:50.58%, time:6 m:3 s, avg loss: 0.17, avg acc:101.1875%, last loss: 0.33
# Train completion:55.63%, time:6 m:4 s, avg loss: 0.19, avg acc:100.9375%, last loss: 0.16
# Train completion:60.69%, time:6 m:5 s, avg loss: 0.19, avg acc:100.9896%, last loss: 0.26
# Train completion:65.75%, time:6 m:6 s, avg loss: 0.18, avg acc:101.2981%, last loss: 0.15
# Train completion:70.81%, time:6 m:8 s, avg loss: 0.18, avg acc:101.0938%, last loss: 0.24
# Train completion:75.87%, time:6 m:9 s, avg loss: 0.19, avg acc:100.7500%, last loss: 0.27
# Train completion:80.92%, time:6 m:10 s, avg loss: 0.19, avg acc:100.7227%, last loss: 0.07
# Train completion:85.98%, time:6 m:11 s, avg loss: 0.19, avg acc:100.6985%, last loss: 0.10
# Train completion:91.04%, time:6 m:12 s, avg loss: 0.19, avg acc:100.6771%, last loss: 0.25
# Train completion:96.10%, time:6 m:14 s, avg loss: 0.19, avg acc:100.3783%, last loss: 0.44
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 13/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:6 m:15 s, avg loss: 17.56, avg acc:3.4375%, last loss: 16.45
# Eval completion:1.12%, time:6 m:16 s, avg loss: 17.74, avg acc:4.5312%, last loss: 17.93
# Eval completion:1.68%, time:6 m:17 s, avg loss: 17.76, avg acc:4.7917%, last loss: 19.22
# Eval completion:2.24%, time:6 m:18 s, avg loss: 17.61, avg acc:6.0156%, last loss: 18.49
# Eval completion:2.80%, time:6 m:19 s, avg loss: 17.37, avg acc:6.0625%, last loss: 17.84
# ----------------------------------------------------------------------------------------------------
# Completed epoch 13/25 in 6 m:19 s, avg train loss: 0.19, avg train acc: 100.0000%, avg eval loss: 17.32, avg eval acc: 6.4732
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 14/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:6 m:20 s, avg loss: 0.17, avg acc:101.2500%, last loss: 0.05
# Train completion:10.12%, time:6 m:22 s, avg loss: 0.15, avg acc:101.0938%, last loss: 0.36
# Train completion:15.17%, time:6 m:23 s, avg loss: 0.14, avg acc:100.5208%, last loss: 0.15
# Train completion:20.23%, time:6 m:24 s, avg loss: 0.16, avg acc:100.6250%, last loss: 0.23
# Train completion:25.29%, time:6 m:25 s, avg loss: 0.19, avg acc:100.1250%, last loss: 0.25
# Train completion:30.35%, time:6 m:27 s, avg loss: 0.20, avg acc:99.3229%, last loss: 0.19
# Train completion:35.40%, time:6 m:28 s, avg loss: 0.19, avg acc:99.4643%, last loss: 0.15
# Train completion:40.46%, time:6 m:29 s, avg loss: 0.19, avg acc:99.2969%, last loss: 0.13
# Train completion:45.52%, time:6 m:30 s, avg loss: 0.19, avg acc:99.2014%, last loss: 0.35
# Train completion:50.58%, time:6 m:32 s, avg loss: 0.20, avg acc:98.8750%, last loss: 0.19
# Train completion:55.63%, time:6 m:33 s, avg loss: 0.21, avg acc:99.0341%, last loss: 0.13
# Train completion:60.69%, time:6 m:35 s, avg loss: 0.21, avg acc:98.9844%, last loss: 0.14
# Train completion:65.75%, time:6 m:36 s, avg loss: 0.21, avg acc:99.3510%, last loss: 0.18
# Train completion:70.81%, time:6 m:37 s, avg loss: 0.21, avg acc:99.3304%, last loss: 0.30
# Train completion:75.87%, time:6 m:38 s, avg loss: 0.22, avg acc:99.1250%, last loss: 0.16
# Train completion:80.92%, time:6 m:39 s, avg loss: 0.22, avg acc:98.9453%, last loss: 0.25
# Train completion:85.98%, time:6 m:41 s, avg loss: 0.22, avg acc:98.8235%, last loss: 0.14
# Train completion:91.04%, time:6 m:42 s, avg loss: 0.22, avg acc:98.8368%, last loss: 0.20
# Train completion:96.10%, time:6 m:43 s, avg loss: 0.22, avg acc:98.7171%, last loss: 0.23
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 14/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:0.56%, time:6 m:45 s, avg loss: 17.67, avg acc:7.8125%, last loss: 17.89
# Eval completion:1.12%, time:6 m:46 s, avg loss: 17.82, avg acc:5.6250%, last loss: 19.51
# Eval completion:1.68%, time:6 m:46 s, avg loss: 17.86, avg acc:6.2500%, last loss: 19.25
# Eval completion:2.24%, time:6 m:47 s, avg loss: 17.79, avg acc:6.7188%, last loss: 18.69
# Eval completion:2.80%, time:6 m:48 s, avg loss: 17.70, avg acc:6.5625%, last loss: 17.38
# ----------------------------------------------------------------------------------------------------
# Completed epoch 14/25 in 6 m:49 s, avg train loss: 0.23, avg train acc: 98.3270%, avg eval loss: 17.77, avg eval acc: 6.3616
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 15/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:5.06%, time:6 m:50 s, avg loss: 0.19, avg acc:99.0625%, last loss: 0.11
# Train completion:10.12%, time:6 m:51 s, avg loss: 0.19, avg acc:99.5312%, last loss: 0.39
# Train completion:15.17%, time:6 m:52 s, avg loss: 0.18, avg acc:99.8958%, last loss: 0.04
# Train completion:20.23%, time:6 m:53 s, avg loss: 0.18, avg acc:99.5312%, last loss: 0.18
# Train completion:25.29%, time:6 m:55 s, avg loss: 0.18, avg acc:99.6875%, last loss: 0.19
# Train completion:30.35%, time:6 m:56 s, avg loss: 0.19, avg acc:99.5833%, last loss: 0.16
# Train completion:35.40%, time:6 m:57 s, avg loss: 0.18, avg acc:99.7321%, last loss: 0.20
# Train completion:40.46%, time:6 m:58 s, avg loss: 0.18, avg acc:99.7656%, last loss: 0.30
# Train completion:45.52%, time:7 m:0 s, avg loss: 0.18, avg acc:99.5833%, last loss: 0.27
# Train completion:50.58%, time:7 m:1 s, avg loss: 0.18, avg acc:99.4062%, last loss: 0.13
# Train completion:55.63%, time:7 m:2 s, avg loss: 0.18, avg acc:99.4886%, last loss: 0.14
# Train completion:60.69%, time:7 m:3 s, avg loss: 0.18, avg acc:99.5833%, last loss: 0.08
# Train completion:65.75%, time:7 m:4 s, avg loss: 0.18, avg acc:99.6154%, last loss: 0.11
# Train completion:70.81%, time:7 m:6 s, avg loss: 0.19, avg acc:99.1964%, last loss: 0.46
# Train completion:75.87%, time:7 m:7 s, avg loss: 0.21, avg acc:98.7083%, last loss: 0.37
# Train completion:80.92%, time:7 m:8 s, avg loss: 0.21, avg acc:98.4180%, last loss: 0.22
# Train completion:85.98%, time:7 m:9 s, avg loss: 0.22, avg acc:98.4007%, last loss: 0.08
# Train completion:91.04%, time:7 m:10 s, avg loss: 0.22, avg acc:98.4549%, last loss: 0.17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3c31ab47eb27> in <module>()
#      19     train_losses=[]
#      20
# ---> 21     for x, label in dataloaders["train"]:
#      22         x=x.to(device)
#      23         label=label.to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     650                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651                 self._reset()  # type: ignore[call-arg]
# --> 652             data = self._next_data()
#     653             self._num_yielded += 1
#     654             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     690     def _next_data(self):
#     691         index = self._next_index()  # may raise StopIteration
# --> 692         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     693         if self._pin_memory:
#     694             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     228         """
#     229         path, target = self.samples[index]
# --> 230         sample = self.loader(path)
#     231         if self.transform is not None:
#     232             sample = self.transform(sample)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     267         return accimage_loader(path)
#     268     else:
# --> 269         return pil_loader(path)
#     270
#     271
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     245 def pil_loader(path: str) -> Image.Image:
#     246     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
# --> 247     with open(path, "rb") as f:
#     248         img = Image.open(f)
#     249         return img.convert("RGB")
#
# KeyboardInterrupt:
