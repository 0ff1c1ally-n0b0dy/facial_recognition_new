# %%
#####################
#FB and GOOG face recognition combined (most kept from FB and included some ideas from GOOG).
#FB
#Facebook transformer for image classification: https://github.com/facebookresearch/deit/blob/main/models_v2.py
#Go to line 269 for examples for different models with different inputs.
#The paper with details on learning rate, optimizer type etc is: https://arxiv.org/pdf/2012.12877.pdf
#GOOG
#Google transformer for image classification: https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#The paper is at the following link: https://arxiv.org/pdf/2010.11929.pdf
#Implementation that generalizes Layer_scale_init_Block and adds ScaledLayers, following Google's idea for ParallelBlock.
#Implementation of attention from the original well known paperȘ Attention is all you need: 
#https://nlp.seas.harvard.edu/2018/04/03/attention.html
#####################
from torch import nn, optim, as_tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.nn.init import *
from torchvision import transforms, utils, datasets, models
import cv2
from PIL import Image
from pdb import set_trace
import time
import copy
from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import io, transform
from tqdm import trange, tqdm
import csv 
import glob 
import dlib
import pandas as pd
import numpy as np
from functools import partial
from collections import OrderedDict

# !pip install timm
from timm.models.vision_transformer import Mlp, PatchEmbed , _cfg
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model


#Imports inside facenet scripts that need to be loaded here on google colab.
import requests
from requests.adapters import HTTPAdapter
import torch
import hashlib
import shutil
import tempfile
from urllib.request import urlopen, Request

use_cuda=torch.cuda.is_available()
device=torch.device("cuda" if use_cuda else "cpu")
print(device)

#####################
#Global valriables
####################
#The following variable determines how many pictures are fed at once into the NN (this is made for speed). 
#Facebook does 4096.
batches=32   
#The following path points to the folder that contains the images with faces only.
data_dir=r"C:\Users\mihnea.andrei\Work\facial_recognition\faces_images"

def imshow(inp,title=None):
  ############
  #Imshow for tensor
  #############
    inp=inp.numpy().transpose([1,2,0])
    mean=np.array([0.485, 0.456, 0.406])
    std=np.array([0.229, 0.224, 0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.0001)

#The following function times the NN.
def timming(since):
    time_elapsed=time.time()-since
    minutes=time_elapsed // 60
    seconds=time_elapsed%60
    return "%d m:%d s"%(minutes,seconds)
# Out:
# Requirement already satisfied: timm in c:\users\mihnea.andrei\anaconda3\lib\site-packages (0.6.7)
# Requirement already satisfied: torch>=1.4 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (1.12.0)
# Requirement already satisfied: torchvision in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (0.13.0)
# Requirement already satisfied: typing_extensions in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: numpy in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (1.21.5)
# Requirement already satisfied: requests in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (9.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2.0.4)
# cpu

# %%
#If you use the MTCNN code that does the random transformations also, you do not need all those transformations again 
#(maybe) except the horizonta flip - the angle from which the picture is taken.
data_transforms={
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),  
        #transforms.ColorJitter(brightness=0.5,contrast=0.5),
        #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(3, 7)),
        #transforms.RandomAdjustSharpness(sharpness_factor=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'eval': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])
}
phases=list(data_transforms.keys())
image_datasets={x:datasets.ImageFolder(os.path.join(data_dir,x),data_transforms[x]) for x in list(data_transforms.keys())}
dataloaders={x:torch.utils.data.DataLoader(image_datasets[x],batch_size=batches,shuffle=True) for x in list(data_transforms.keys())}
data_sizes={x:len(image_datasets[x]) for x in list(data_transforms.keys())}
class_names=image_datasets['train'].classes 

inputs, classes = next(iter(dataloaders['train']))
out=utils.make_grid(inputs)
imshow(out,title=",".join([class_names[i] for i in classes.tolist()]))

# %%
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])
def attention(query, key, value, mask=None, dropout=None):
    "Compute 'Scaled Dot Product Attention'"
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn
class MultiHeadedAttention(nn.Module):
    def __init__(self, dim, num_heads=8, dropout=0.1):
        "Take in model size and number of heads."
        super(MultiHeadedAttention, self).__init__()
        assert dim % num_heads == 0
        # We assume d_v always equals d_k
        self.d_k = dim // num_heads
        self.h = num_heads
        self.linears = clones(nn.Linear(dim, dim), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        "Implements Figure 2"
        nbatches = query.size(0)
        
        # 1) Do all the linear projections in batch from d_model => h x d_k 
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
        
        # 2) Apply attention on all the projected vectors in batch. 
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        # 3) "Concat" using a view and apply a final linear. 
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
#LayerScale from Google
class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma

# %%
#Original Block class from FB to which I try to add the extra layers that Google has
#Can be passed to block_layers parameter in main class.
class Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,
                 Attention_block = MultiHeadedAttention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        
        self.attn = Attention_block(dim=dim, num_heads=num_heads, dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        #Below, I add the LayerScale that Google has.
        self.ls1=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        #Below I add another LayerScale that Google has
        self.ls2=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        

    def forward(self, x):
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x),self.norm1(x),self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
#Take class from below from FB     
#Can be passed to block_layers parameter in main class.
class Layer_scale_init_Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    # with slight modifications
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm,Attention_block = MultiHeadedAttention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        #self.norm1 = norm_layer(dim)
        #self.norm12 = norm_layer(dim)
        #self.norm13 = norm_layer(dim)
        self.attn = Attention_block(dim=dim, num_heads=num_heads, dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        self.gamma_1 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)
        self.gamma_2 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)

    def forward(self, x):
        x = x + self.drop_path(self.gamma_1 * self.attn(x,x,x))
        x = x + self.drop_path(self.gamma_2 * self.mlp(self.norm2(x)))
        return x

# %%
###################1#########################
#Can be passed to block_layers parameter in main class.
#Implementation that generalizes Layer_scale_init_Block following Google's idea for ParallelBlock.
#############################################
class ParallelLayer_scale_init_Block(nn.Module):
    def __init__(self,dim,num_heads,mlp_ratio=4,dropout=0,drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,
                 Attention_block=MultiHeadedAttention,Mlp_block=Mlp,init_values=10**(-4),num_parallel=2):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        #self.norm2=norm_layer(dim)
        #self.norm3=norm_layer(dim)
        
        #####################3
        #do not know how to multiply by gammas since those are just compositions of functions basically.
        #hopefully it does not matter since gammas are parameters and maybe it will be better if num_parameters>2
        #could add LayerScale to both attention and forward feed.
        ############################
        mlp_hidden_dim = int(dim * mlp_ratio)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim,num_heads=num_heads,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp_block(in_features=dim,hidden_features=mlp_hidden_dim,act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm1(x),self.norm1(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#####################2##########################
#Use the generalized implementation that Google has for FB's Block_paralx2 (num_parallel=2 here for FB's implementation).
#Can be passed to block_layers parameter in main class.
################################################
class ParallelBlock(nn.Module):
    def __init__(self,dim,num_heads,num_parallel=4,mlp_ratio=4,init_values=10**(-4),dropout=0,drop_path=0,act_layer=nn.GELU,
                 norm_layer=nn.LayerNorm,Attention_block=MultiHeadedAttention,Mlp_block=Mlp):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        self.norm2=norm_layer(dim)
        self.norm3=norm_layer(dim)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim,num_heads=num_heads,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity()) 
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp(dim,hidden_features=int(dim*mlp_ratio),act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path", DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    x=f(self.norm1(x),self.norm2(x),self.norm3(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Copy class from below from FB
class hMLP_stem(nn.Module):
    """ hMLP_stem: https://arxiv.org/pdf/2203.09795.pdf
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, embed_dim=768,norm_layer=nn.SyncBatchNorm):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.proj = torch.nn.Sequential(*[nn.Conv2d(in_chans, embed_dim//4, kernel_size=4, stride=4),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim//4, kernel_size=2, stride=2),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim, kernel_size=2, stride=2),
                                          norm_layer(embed_dim),
                                         ])
        

    def forward(self, x):
        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

# %%
#Copy class from below from FB
class vit_models(nn.Module):
    """ Vision Transformer with LayerScale (https://arxiv.org/abs/2103.17239) support
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, num_classes=1000, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., drop_rate=0.,
                 drop_path_rate=0., norm_layer=nn.LayerNorm, global_pool=None,
                 block_layers = Block,
                 Patch_layer=PatchEmbed,act_layer=nn.GELU,
                 Attention_block = MultiHeadedAttention, Mlp_block=Mlp,
                dpr_constant=True,init_scale=1e-4,
                mlp_ratio_clstk = 4.0):
        super().__init__()
        
        self.dropout_rate = drop_rate

            
        self.num_classes = num_classes
        self.num_features = self.embed_dim = embed_dim

        self.patch_embed = Patch_layer(
                img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))

        dpr = [drop_path_rate for i in range(depth)]
        self.blocks = nn.ModuleList([
            block_layers(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio,
                dropout=0.0, drop_path=dpr[i], norm_layer=norm_layer,
                act_layer=act_layer,Attention_block=Attention_block,Mlp_block=Mlp_block,init_values=init_scale)
            for i in range(depth)])
        

        
            
        self.norm = norm_layer(embed_dim)

        self.feature_info = [dict(num_chs=embed_dim, reduction=0, module='head')]
        self.head = nn.Linear(embed_dim, num_classes) if num_classes > 0 else nn.Identity()

        trunc_normal_(self.pos_embed, std=.02)
        trunc_normal_(self.cls_token, std=.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'pos_embed', 'cls_token'}

    def get_classifier(self):
        return self.head
    
    def get_num_layers(self):
        return len(self.blocks)
    
    def reset_classifier(self, num_classes, global_pool=''):
        self.num_classes = num_classes
        self.head = nn.Linear(self.embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward_features(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        
        x = x + self.pos_embed
        
        x = torch.cat((cls_tokens, x), dim=1)
            
        for i , blk in enumerate(self.blocks):
            x = blk(x)
            
        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):

        x = self.forward_features(x)
        
        if self.dropout_rate:
            x = F.dropout(x, p=float(self.dropout_rate), training=self.training)
        x = self.head(x)
        
        return x

# %%
#The below number is 160 because the faces extracted by MTCNN are 160x160.
img_size=160
#The number of names that the model will see (population of romania over 14).
num_classes=data_sizes["train"]
#Variables inside the network. Please check examples that start at line 271 here: 
#https://github.com/facebookresearch/deit/blob/main/models_v2.py
embed_dim=192
depth=12
num_heads=3
mlp_ratio=4

model_fit=vit_models(num_classes=num_classes,img_size=img_size,patch_size=batches,
                     embed_dim=embed_dim,depth=depth,num_heads=num_heads,mlp_ratio=mlp_ratio,
                    norm_layer=partial(nn.LayerNorm,eps=10**(-6)),
                    block_layers=ParallelBlock).to(device)

num_epochs=25
lr=3*10**(-3)
weight_decay=0.01
criterion=nn.CrossEntropyLoss()
#Facebook does AdamW. Please see paper.
#optimizer=optim.SGD(model_fit.parameters(),lr=10**(-2),momentum=0.9)
optimizer=torch.optim.AdamW(model_fit.parameters(),lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=weight_decay)
#lr_decay=lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
lr_decay=torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs)

# %%
best_model_weights=copy.deepcopy(model_fit.state_dict())
best_acc=0
since=time.time()
printing_iter=10**(1)

all_train_losses=[]
all_train_accs=[]
all_eval_losses=[]
all_eval_accs=[]
best_eval_acc=0

for epoch in range(num_epochs):
    print("-"*100)
    print("Training for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    train_losses=[]
    train_accs=[]
    counter=0

    for x, label in dataloaders["train"]:
        x=x.to(device)
        label=label.to(device)
        
        optimizer.zero_grad()
        
        output=model_fit(x)
        loss=criterion(output,label)
        
        output=torch.exp(output)
        _, pred=output.topk(1,dim=1)
        
        loss.backward()
        optimizer.step()
        lr_decay.step()
        
        last_loss=loss.item()
        train_losses.append(last_loss) 
        all_train_losses.append(last_loss)
        pred=pred.cpu()
        label=label.cpu()
        current_acc=100*torch.sum(pred==label.data).double()/batches
        train_accs.append(current_acc)
        all_train_accs.append(current_acc)
        counter+=1

        if counter%printing_iter==0:
            print("Train completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                  %(100*counter*batches/data_sizes["train"],timming(since),np.mean(train_losses),
                    np.mean(train_accs),last_loss))
    
    training_avg_loss=np.mean(train_losses)
    print("-"*100)
    print("Eval for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    eval_losses=[]
    eval_accs=[]
    counter=0
    
    with torch.no_grad():
        for x, label in dataloaders["eval"]:
            x=x.to(device)
            label=label.to(device)
            
            output=model_fit(x)
            loss=criterion(output,label)
            
            output=torch.exp(output)
            _, pred=output.topk(1,dim=1)
            
            
            last_loss=loss.item()
            eval_losses.append(last_loss)
            all_eval_losses.append(last_loss)
            pred=pred.cpu()
            label=label.cpu()
            current_acc=100*torch.sum(pred==label.data).double()/batches
            eval_accs.append(current_acc)
            all_eval_accs.append(current_acc)
            counter+=1
            
            if counter%printing_iter==0:
                print("Eval completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                      %(100*counter*batches/data_sizes["eval"],timming(since),np.mean(eval_losses),
                        np.mean(eval_accs),last_loss))
            
    eval_avg_loss=np.mean(eval_losses)
    if np.mean(eval_accs)>best_eval_acc:
        best_eval_acc=np.mean(eval_accs)
        best_model_wts = copy.deepcopy(model_fit.state_dict())
    
    print("-"*100)
    print("Completed epoch %d/%d in %s, avg train loss: %.2f, avg train acc: %.4f%%, avg eval loss: %.2f, avg eval acc: %.4f"%
          (epoch+1,num_epochs,timming(since),training_avg_loss,np.mean(train_accs),eval_avg_loss,np.mean(eval_accs)))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for epoch 1/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:0.13%, time:0 m:17 s, avg loss: 12.41, avg acc:0.0000%, last loss: 12.43
# Train completion:0.26%, time:0 m:38 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.44
# Train completion:0.40%, time:1 m:0 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.31
# Train completion:0.53%, time:1 m:21 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.34
# Train completion:0.66%, time:1 m:44 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.34
# Train completion:0.79%, time:2 m:13 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.45
# Train completion:0.92%, time:2 m:45 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.34
# Train completion:1.06%, time:3 m:16 s, avg loss: 12.38, avg acc:0.0000%, last loss: 12.38
# Train completion:1.19%, time:3 m:47 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.22
# Train completion:1.32%, time:4 m:20 s, avg loss: 12.38, avg acc:0.0000%, last loss: 12.35
# Train completion:1.45%, time:4 m:54 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.38
# Train completion:1.58%, time:5 m:27 s, avg loss: 12.36, avg acc:0.0000%, last loss: 12.26
# Train completion:1.72%, time:6 m:1 s, avg loss: 12.35, avg acc:0.0000%, last loss: 12.18
# Train completion:1.85%, time:6 m:34 s, avg loss: 12.34, avg acc:0.0000%, last loss: 12.31
# Train completion:1.98%, time:7 m:6 s, avg loss: 12.34, avg acc:0.0000%, last loss: 12.28
# Train completion:2.11%, time:7 m:39 s, avg loss: 12.33, avg acc:0.0000%, last loss: 12.12
# Train completion:2.24%, time:8 m:11 s, avg loss: 12.32, avg acc:0.0000%, last loss: 12.04
# Train completion:2.38%, time:8 m:43 s, avg loss: 12.32, avg acc:0.0000%, last loss: 12.19
# Train completion:2.51%, time:9 m:15 s, avg loss: 12.31, avg acc:0.0000%, last loss: 12.12
# Train completion:2.64%, time:9 m:46 s, avg loss: 12.31, avg acc:0.0000%, last loss: 11.96
# Train completion:2.77%, time:10 m:18 s, avg loss: 12.30, avg acc:0.0000%, last loss: 11.85
# Train completion:2.90%, time:10 m:49 s, avg loss: 12.28, avg acc:0.0000%, last loss: 11.89
# Train completion:3.04%, time:11 m:21 s, avg loss: 12.27, avg acc:0.0000%, last loss: 12.22
# Train completion:3.17%, time:11 m:52 s, avg loss: 12.27, avg acc:0.0000%, last loss: 12.26
# Train completion:3.30%, time:12 m:24 s, avg loss: 12.26, avg acc:0.0000%, last loss: 12.06
# Train completion:43.03%, time:196 m:59 s, avg loss: 11.05, avg acc:0.0920%, last loss: 10.40
# Train completion:43.17%, time:197 m:44 s, avg loss: 11.05, avg acc:0.0917%, last loss: 10.55
# Train completion:43.30%, time:198 m:27 s, avg loss: 11.05, avg acc:0.0915%, last loss: 10.30
# Train completion:43.43%, time:199 m:13 s, avg loss: 11.05, avg acc:0.0912%, last loss: 10.45
# Train completion:43.56%, time:200 m:3 s, avg loss: 11.04, avg acc:0.0909%, last loss: 10.60
# Train completion:43.69%, time:200 m:50 s, avg loss: 11.04, avg acc:0.0906%, last loss: 10.34
# Train completion:43.83%, time:201 m:35 s, avg loss: 11.04, avg acc:0.0904%, last loss: 10.42
# Train completion:43.96%, time:202 m:21 s, avg loss: 11.04, avg acc:0.0901%, last loss: 10.34
# Train completion:44.09%, time:203 m:5 s, avg loss: 11.04, avg acc:0.0898%, last loss: 10.13
# Train completion:44.22%, time:203 m:52 s, avg loss: 11.03, avg acc:0.0896%, last loss: 10.37
# Train completion:44.35%, time:204 m:37 s, avg loss: 11.03, avg acc:0.0893%, last loss: 10.27
# Train completion:44.49%, time:205 m:20 s, avg loss: 11.03, avg acc:0.0890%, last loss: 10.39
# Train completion:44.62%, time:206 m:6 s, avg loss: 11.03, avg acc:0.0888%, last loss: 10.54
# Train completion:44.75%, time:206 m:51 s, avg loss: 11.03, avg acc:0.0885%, last loss: 10.45
# Train completion:44.88%, time:207 m:35 s, avg loss: 11.02, avg acc:0.0882%, last loss: 10.40
# Train completion:45.01%, time:208 m:20 s, avg loss: 11.02, avg acc:0.0880%, last loss: 10.42
# Train completion:45.15%, time:209 m:4 s, avg loss: 11.02, avg acc:0.0877%, last loss: 10.39
# Train completion:45.28%, time:209 m:50 s, avg loss: 11.02, avg acc:0.0875%, last loss: 10.57
# Train completion:45.41%, time:210 m:37 s, avg loss: 11.02, avg acc:0.0872%, last loss: 10.21
# Train completion:45.54%, time:211 m:22 s, avg loss: 11.01, avg acc:0.0870%, last loss: 10.47
# Train completion:45.67%, time:212 m:6 s, avg loss: 11.01, avg acc:0.0867%, last loss: 10.37
# Train completion:45.81%, time:212 m:50 s, avg loss: 11.01, avg acc:0.0865%, last loss: 10.30
# Train completion:45.94%, time:213 m:33 s, avg loss: 11.01, avg acc:0.0862%, last loss: 10.15
# Train completion:46.07%, time:214 m:18 s, avg loss: 11.01, avg acc:0.0860%, last loss: 10.29
# Train completion:46.20%, time:215 m:4 s, avg loss: 11.01, avg acc:0.0857%, last loss: 10.28
# Train completion:46.33%, time:215 m:50 s, avg loss: 11.00, avg acc:0.0855%, last loss: 10.42
# Train completion:46.47%, time:216 m:35 s, avg loss: 11.00, avg acc:0.0852%, last loss: 10.57
# Train completion:46.60%, time:217 m:19 s, avg loss: 11.00, avg acc:0.0850%, last loss: 10.33
# Train completion:46.73%, time:218 m:5 s, avg loss: 11.00, avg acc:0.0847%, last loss: 10.46
# Train completion:46.86%, time:218 m:51 s, avg loss: 11.00, avg acc:0.0845%, last loss: 10.32
# Train completion:46.99%, time:219 m:36 s, avg loss: 11.00, avg acc:0.0843%, last loss: 10.98
# Train completion:47.13%, time:220 m:22 s, avg loss: 10.99, avg acc:0.0840%, last loss: 10.23
# Train completion:47.26%, time:221 m:8 s, avg loss: 10.99, avg acc:0.0838%, last loss: 10.51
# Train completion:47.39%, time:221 m:54 s, avg loss: 10.99, avg acc:0.0836%, last loss: 10.54
# Train completion:47.52%, time:222 m:39 s, avg loss: 10.99, avg acc:0.0833%, last loss: 10.32
# Train completion:47.65%, time:223 m:22 s, avg loss: 10.99, avg acc:0.0831%, last loss: 10.43
# Train completion:47.79%, time:224 m:6 s, avg loss: 10.98, avg acc:0.0829%, last loss: 10.43
# Train completion:47.92%, time:224 m:51 s, avg loss: 10.98, avg acc:0.0826%, last loss: 10.43
# Train completion:48.05%, time:225 m:36 s, avg loss: 10.98, avg acc:0.0824%, last loss: 10.23
# Train completion:48.18%, time:226 m:20 s, avg loss: 10.98, avg acc:0.0822%, last loss: 10.33
# Train completion:48.31%, time:227 m:3 s, avg loss: 10.98, avg acc:0.0820%, last loss: 10.26
# Train completion:48.45%, time:227 m:47 s, avg loss: 10.98, avg acc:0.0817%, last loss: 10.41
# Train completion:48.58%, time:228 m:33 s, avg loss: 10.98, avg acc:0.0815%, last loss: 10.32
# Train completion:48.71%, time:229 m:19 s, avg loss: 10.97, avg acc:0.0813%, last loss: 10.56
# Train completion:48.84%, time:230 m:3 s, avg loss: 10.97, avg acc:0.0811%, last loss: 10.22
# Train completion:48.97%, time:230 m:48 s, avg loss: 10.97, avg acc:0.0809%, last loss: 10.35
# Train completion:49.11%, time:231 m:34 s, avg loss: 10.97, avg acc:0.0806%, last loss: 10.44
# Train completion:49.24%, time:232 m:18 s, avg loss: 10.97, avg acc:0.0804%, last loss: 10.18
# Train completion:49.37%, time:233 m:3 s, avg loss: 10.96, avg acc:0.0802%, last loss: 10.39
# Train completion:49.50%, time:233 m:47 s, avg loss: 10.96, avg acc:0.0800%, last loss: 10.40
# Train completion:49.63%, time:234 m:31 s, avg loss: 10.96, avg acc:0.0798%, last loss: 10.33
# Train completion:49.77%, time:235 m:14 s, avg loss: 10.96, avg acc:0.0796%, last loss: 10.54
# Train completion:49.90%, time:235 m:59 s, avg loss: 10.96, avg acc:0.0794%, last loss: 10.26
# Train completion:50.03%, time:236 m:43 s, avg loss: 10.96, avg acc:0.0792%, last loss: 10.34
# Train completion:50.16%, time:237 m:27 s, avg loss: 10.95, avg acc:0.0789%, last loss: 10.38
# Train completion:50.29%, time:238 m:12 s, avg loss: 10.95, avg acc:0.0787%, last loss: 10.40
# Train completion:50.43%, time:238 m:57 s, avg loss: 10.95, avg acc:0.0785%, last loss: 10.26
# Train completion:50.56%, time:239 m:42 s, avg loss: 10.95, avg acc:0.0783%, last loss: 10.36
# Train completion:50.69%, time:240 m:27 s, avg loss: 10.95, avg acc:0.0781%, last loss: 10.29
# Train completion:50.82%, time:241 m:10 s, avg loss: 10.95, avg acc:0.0779%, last loss: 10.25
# Train completion:54.91%, time:263 m:59 s, avg loss: 10.90, avg acc:0.0721%, last loss: 10.25
# Train completion:55.05%, time:264 m:40 s, avg loss: 10.90, avg acc:0.0719%, last loss: 10.22
# Train completion:55.18%, time:265 m:21 s, avg loss: 10.90, avg acc:0.0718%, last loss: 10.42
# Train completion:55.31%, time:266 m:2 s, avg loss: 10.90, avg acc:0.0716%, last loss: 10.44
# Train completion:55.44%, time:266 m:42 s, avg loss: 10.90, avg acc:0.0714%, last loss: 10.33
# Train completion:55.57%, time:267 m:21 s, avg loss: 10.89, avg acc:0.0713%, last loss: 10.27
# Train completion:55.71%, time:267 m:59 s, avg loss: 10.89, avg acc:0.0711%, last loss: 10.43
# Train completion:55.84%, time:268 m:38 s, avg loss: 10.89, avg acc:0.0709%, last loss: 10.19
# Train completion:55.97%, time:269 m:17 s, avg loss: 10.89, avg acc:0.0708%, last loss: 10.72
# Train completion:56.10%, time:269 m:58 s, avg loss: 10.89, avg acc:0.0706%, last loss: 10.29
# Train completion:56.23%, time:270 m:41 s, avg loss: 10.89, avg acc:0.0704%, last loss: 10.24
# Train completion:56.37%, time:271 m:22 s, avg loss: 10.89, avg acc:0.0703%, last loss: 10.32
# Train completion:56.50%, time:272 m:3 s, avg loss: 10.89, avg acc:0.0701%, last loss: 10.29
# Train completion:56.63%, time:272 m:43 s, avg loss: 10.88, avg acc:0.0699%, last loss: 10.27
# Train completion:56.76%, time:273 m:22 s, avg loss: 10.88, avg acc:0.0698%, last loss: 10.23
# Train completion:56.89%, time:274 m:2 s, avg loss: 10.88, avg acc:0.0696%, last loss: 10.32
# Train completion:57.03%, time:274 m:41 s, avg loss: 10.88, avg acc:0.0694%, last loss: 10.34
# Train completion:57.16%, time:275 m:21 s, avg loss: 10.88, avg acc:0.0693%, last loss: 10.21
# Train completion:57.29%, time:276 m:2 s, avg loss: 10.88, avg acc:0.0691%, last loss: 10.48
# Train completion:57.42%, time:276 m:43 s, avg loss: 10.88, avg acc:0.0690%, last loss: 10.35
# Train completion:57.55%, time:277 m:26 s, avg loss: 10.87, avg acc:0.0688%, last loss: 10.31
# Train completion:57.69%, time:278 m:7 s, avg loss: 10.87, avg acc:0.0686%, last loss: 10.20
# Train completion:57.82%, time:278 m:48 s, avg loss: 10.87, avg acc:0.0685%, last loss: 10.44
# Train completion:57.95%, time:279 m:29 s, avg loss: 10.87, avg acc:0.0683%, last loss: 10.33
# Train completion:58.08%, time:280 m:9 s, avg loss: 10.87, avg acc:0.0682%, last loss: 10.22
# Train completion:58.21%, time:280 m:47 s, avg loss: 10.87, avg acc:0.0680%, last loss: 10.69
# Train completion:58.35%, time:281 m:28 s, avg loss: 10.87, avg acc:0.0679%, last loss: 10.19
# Train completion:58.48%, time:282 m:10 s, avg loss: 10.87, avg acc:0.0677%, last loss: 10.26
# Train completion:58.61%, time:282 m:53 s, avg loss: 10.86, avg acc:0.0901%, last loss: 10.31
# Train completion:58.74%, time:283 m:35 s, avg loss: 10.86, avg acc:0.0899%, last loss: 10.22
# Train completion:66.79%, time:333 m:14 s, avg loss: 10.80, avg acc:0.1186%, last loss: 10.28
# Train completion:66.93%, time:333 m:59 s, avg loss: 10.79, avg acc:0.1183%, last loss: 10.29
# Train completion:67.06%, time:334 m:47 s, avg loss: 10.79, avg acc:0.1181%, last loss: 10.60
# Train completion:67.19%, time:335 m:33 s, avg loss: 10.79, avg acc:0.1179%, last loss: 10.26
# Train completion:67.32%, time:336 m:21 s, avg loss: 10.79, avg acc:0.1176%, last loss: 10.33
# Train completion:67.45%, time:337 m:8 s, avg loss: 10.79, avg acc:0.1174%, last loss: 10.29
# Train completion:67.59%, time:337 m:53 s, avg loss: 10.79, avg acc:0.1172%, last loss: 10.35
# Train completion:67.72%, time:338 m:38 s, avg loss: 10.79, avg acc:0.1170%, last loss: 10.27
# Train completion:67.85%, time:339 m:23 s, avg loss: 10.79, avg acc:0.1167%, last loss: 10.28
# Train completion:67.98%, time:340 m:10 s, avg loss: 10.79, avg acc:0.1165%, last loss: 10.29
# Train completion:68.11%, time:340 m:57 s, avg loss: 10.79, avg acc:0.1163%, last loss: 10.21
# Train completion:68.25%, time:341 m:45 s, avg loss: 10.79, avg acc:0.1161%, last loss: 10.21
# ...
# Eval completion:50.93%, time:529 m:2 s, avg loss: 10.26, avg acc:0.2703%, last loss: 10.31
# Eval completion:52.31%, time:529 m:8 s, avg loss: 10.26, avg acc:0.2632%, last loss: 10.29
# Eval completion:53.68%, time:529 m:14 s, avg loss: 10.26, avg acc:0.2564%, last loss: 10.23
# Eval completion:55.06%, time:529 m:20 s, avg loss: 10.26, avg acc:0.2500%, last loss: 10.17
# Eval completion:56.44%, time:529 m:26 s, avg loss: 10.26, avg acc:0.2439%, last loss: 10.14
# Eval completion:57.81%, time:529 m:32 s, avg loss: 10.26, avg acc:0.2381%, last loss: 10.19
# Eval completion:59.19%, time:529 m:38 s, avg loss: 10.26, avg acc:0.2326%, last loss: 10.28
# Eval completion:60.57%, time:529 m:44 s, avg loss: 10.26, avg acc:0.2273%, last loss: 10.17
# Eval completion:61.94%, time:529 m:50 s, avg loss: 10.26, avg acc:0.2222%, last loss: 10.22
# Eval completion:63.32%, time:529 m:56 s, avg loss: 10.26, avg acc:0.2174%, last loss: 10.28
# Eval completion:64.70%, time:530 m:2 s, avg loss: 10.26, avg acc:0.2128%, last loss: 10.42
# Eval completion:66.07%, time:530 m:7 s, avg loss: 10.26, avg acc:0.2083%, last loss: 10.15
# Eval completion:67.45%, time:530 m:14 s, avg loss: 10.26, avg acc:0.2041%, last loss: 10.15
# Eval completion:68.83%, time:530 m:19 s, avg loss: 10.26, avg acc:0.2000%, last loss: 10.45
# Eval completion:70.20%, time:530 m:26 s, avg loss: 10.26, avg acc:0.1961%, last loss: 10.15
# Eval completion:71.58%, time:530 m:31 s, avg loss: 10.26, avg acc:0.1923%, last loss: 10.18
# Eval completion:72.96%, time:530 m:37 s, avg loss: 10.26, avg acc:0.1887%, last loss: 10.25
# Eval completion:74.33%, time:530 m:43 s, avg loss: 10.26, avg acc:0.1852%, last loss: 10.27
# Eval completion:75.71%, time:530 m:49 s, avg loss: 10.26, avg acc:0.1818%, last loss: 10.11
# Eval completion:77.09%, time:530 m:55 s, avg loss: 10.26, avg acc:0.1786%, last loss: 10.30
# Eval completion:78.46%, time:531 m:1 s, avg loss: 10.26, avg acc:0.1754%, last loss: 10.26
# Eval completion:79.84%, time:531 m:7 s, avg loss: 10.26, avg acc:0.1724%, last loss: 10.23
# Eval completion:81.21%, time:531 m:13 s, avg loss: 10.26, avg acc:0.1695%, last loss: 10.20
# Eval completion:82.59%, time:531 m:19 s, avg loss: 10.25, avg acc:0.1667%, last loss: 10.17
# Eval completion:83.97%, time:531 m:25 s, avg loss: 10.25, avg acc:0.1639%, last loss: 10.28
# Eval completion:85.34%, time:531 m:31 s, avg loss: 10.25, avg acc:0.1613%, last loss: 10.33
# Eval completion:86.72%, time:531 m:37 s, avg loss: 10.25, avg acc:0.1587%, last loss: 10.56
# Eval completion:88.10%, time:531 m:43 s, avg loss: 10.25, avg acc:0.1562%, last loss: 10.15
# Eval completion:89.47%, time:531 m:49 s, avg loss: 10.25, avg acc:0.1538%, last loss: 10.19
# Eval completion:90.85%, time:531 m:55 s, avg loss: 10.25, avg acc:0.1515%, last loss: 10.36
# Eval completion:92.23%, time:532 m:1 s, avg loss: 10.25, avg acc:0.1493%, last loss: 10.29
# Eval completion:93.60%, time:532 m:7 s, avg loss: 10.25, avg acc:0.1471%, last loss: 10.19
# Eval completion:94.98%, time:532 m:13 s, avg loss: 10.25, avg acc:0.1449%, last loss: 10.22
# Eval completion:96.36%, time:532 m:19 s, avg loss: 10.25, avg acc:0.1429%, last loss: 10.10
# Eval completion:97.73%, time:532 m:25 s, avg loss: 10.25, avg acc:0.1408%, last loss: 10.20
# Eval completion:99.11%, time:532 m:31 s, avg loss: 10.25, avg acc:0.1389%, last loss: 10.40
# ----------------------------------------------------------------------------------------------------
# Completed epoch 1/25 in 532 m:35 s, avg train loss: 10.62, avg train acc: 0.0924%, avg eval loss: 10.25, avg eval acc: 0.1376
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 2/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:0.13%, time:533 m:21 s, avg loss: 10.19, avg acc:0.0000%, last loss: 10.12
# Train completion:0.26%, time:534 m:5 s, avg loss: 10.17, avg acc:0.0000%, last loss: 10.12
# Train completion:0.40%, time:534 m:51 s, avg loss: 10.17, avg acc:0.0000%, last loss: 10.08
# Train completion:0.53%, time:535 m:37 s, avg loss: 10.17, avg acc:0.0000%, last loss: 10.12
# Train completion:0.66%, time:536 m:23 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.11
# Train completion:0.79%, time:537 m:9 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.09
# Train completion:0.92%, time:537 m:56 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.17
# Train completion:1.06%, time:538 m:43 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.11
# Train completion:1.19%, time:539 m:31 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.05
# Train completion:1.32%, time:540 m:18 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.11
# Train completion:1.45%, time:541 m:5 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.17
# Train completion:1.58%, time:541 m:52 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:1.72%, time:542 m:39 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.19
# Train completion:1.85%, time:543 m:26 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.06
# Train completion:1.98%, time:544 m:12 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.17
# Train completion:2.11%, time:545 m:1 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:2.24%, time:545 m:50 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.13
# Train completion:2.38%, time:546 m:38 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.24
# Train completion:2.51%, time:547 m:26 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.32
# Train completion:2.64%, time:548 m:13 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.08
# Train completion:2.77%, time:548 m:59 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.10
# Train completion:2.90%, time:549 m:47 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.09
# Train completion:3.04%, time:550 m:33 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.19
# Train completion:3.17%, time:551 m:21 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.24
# Train completion:3.30%, time:552 m:9 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.34
# Train completion:3.43%, time:552 m:58 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:3.56%, time:553 m:46 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:3.70%, time:554 m:33 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.30
# Train completion:3.83%, time:555 m:21 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.16
# Train completion:3.96%, time:556 m:10 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.19
# Train completion:4.09%, time:556 m:58 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.14
# Train completion:4.22%, time:557 m:44 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:4.36%, time:558 m:32 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.13
# Train completion:4.49%, time:559 m:20 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.32
# Train completion:4.62%, time:560 m:7 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:4.75%, time:560 m:55 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.14
# Train completion:4.88%, time:561 m:44 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.18
# Train completion:5.02%, time:562 m:31 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:5.15%, time:563 m:18 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.17
# Train completion:5.28%, time:564 m:5 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.13
# Train completion:5.41%, time:564 m:51 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:5.54%, time:565 m:38 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.09
# Train completion:5.68%, time:566 m:26 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.09
# Train completion:5.81%, time:567 m:15 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.15
# Train completion:5.94%, time:568 m:4 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.11
# Train completion:6.07%, time:568 m:52 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.21
# Train completion:6.20%, time:569 m:40 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.06
# Train completion:6.34%, time:570 m:28 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.09
# Train completion:6.47%, time:571 m:15 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.11
# Train completion:6.60%, time:572 m:3 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.04
# Train completion:6.73%, time:572 m:53 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.10
# Train completion:6.86%, time:573 m:43 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:7.00%, time:574 m:32 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:7.13%, time:575 m:22 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.18
# Train completion:7.26%, time:576 m:9 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.17
# Train completion:7.39%, time:576 m:58 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.19
# Train completion:7.52%, time:577 m:48 s, avg loss: 10.16, avg acc:0.1754%, last loss: 10.08
# Train completion:7.66%, time:578 m:38 s, avg loss: 10.16, avg acc:0.1724%, last loss: 10.15
# Train completion:7.79%, time:579 m:27 s, avg loss: 10.16, avg acc:0.1695%, last loss: 10.20
# Train completion:7.92%, time:580 m:18 s, avg loss: 10.16, avg acc:0.1667%, last loss: 10.14
# Train completion:8.05%, time:581 m:8 s, avg loss: 10.16, avg acc:0.1639%, last loss: 10.19
# Train completion:8.18%, time:581 m:56 s, avg loss: 10.16, avg acc:0.1613%, last loss: 10.21
# Train completion:8.32%, time:582 m:44 s, avg loss: 10.16, avg acc:0.1587%, last loss: 10.11
# Train completion:8.45%, time:583 m:30 s, avg loss: 10.16, avg acc:0.1562%, last loss: 10.17
# Train completion:8.58%, time:584 m:16 s, avg loss: 10.16, avg acc:0.1538%, last loss: 10.11
# Train completion:8.71%, time:585 m:4 s, avg loss: 10.16, avg acc:0.1515%, last loss: 10.13
# Train completion:8.84%, time:585 m:51 s, avg loss: 10.16, avg acc:0.1493%, last loss: 10.13
# Train completion:8.98%, time:586 m:38 s, avg loss: 10.16, avg acc:0.1471%, last loss: 10.19
# Train completion:9.11%, time:587 m:26 s, avg loss: 10.16, avg acc:0.1449%, last loss: 10.18
# Train completion:9.24%, time:588 m:14 s, avg loss: 10.16, avg acc:0.1429%, last loss: 10.14
# Train completion:9.37%, time:589 m:1 s, avg loss: 10.16, avg acc:0.1408%, last loss: 10.20
# Train completion:9.50%, time:589 m:48 s, avg loss: 10.16, avg acc:0.1389%, last loss: 10.35
# Train completion:9.64%, time:590 m:35 s, avg loss: 10.16, avg acc:0.1370%, last loss: 10.18
# Train completion:9.77%, time:591 m:24 s, avg loss: 10.16, avg acc:0.1351%, last loss: 10.14
# Train completion:9.90%, time:592 m:12 s, avg loss: 10.16, avg acc:0.1333%, last loss: 10.20
# Train completion:10.03%, time:593 m:1 s, avg loss: 10.16, avg acc:0.1316%, last loss: 10.10
# Train completion:10.16%, time:593 m:49 s, avg loss: 10.16, avg acc:0.1299%, last loss: 10.10
# Train completion:10.30%, time:594 m:38 s, avg loss: 10.16, avg acc:0.2564%, last loss: 10.13
# Train completion:10.43%, time:595 m:26 s, avg loss: 10.16, avg acc:0.2532%, last loss: 10.07
# Train completion:10.56%, time:596 m:14 s, avg loss: 10.16, avg acc:0.2500%, last loss: 10.20
# Train completion:10.69%, time:597 m:3 s, avg loss: 10.16, avg acc:0.2469%, last loss: 10.13
# Train completion:10.82%, time:597 m:52 s, avg loss: 10.16, avg acc:0.2439%, last loss: 10.19
# Train completion:10.96%, time:598 m:42 s, avg loss: 10.16, avg acc:0.2410%, last loss: 10.21
# Train completion:11.09%, time:599 m:29 s, avg loss: 10.16, avg acc:0.2381%, last loss: 10.04
# Train completion:11.22%, time:600 m:18 s, avg loss: 10.16, avg acc:0.2353%, last loss: 10.15
# Train completion:11.35%, time:601 m:17 s, avg loss: 10.16, avg acc:0.2326%, last loss: 10.18
# Train completion:11.48%, time:602 m:6 s, avg loss: 10.16, avg acc:0.2299%, last loss: 10.17
# Train completion:11.62%, time:602 m:55 s, avg loss: 10.16, avg acc:0.2273%, last loss: 10.12
# Train completion:11.75%, time:603 m:42 s, avg loss: 10.16, avg acc:0.2247%, last loss: 10.09
# Train completion:11.88%, time:604 m:31 s, avg loss: 10.16, avg acc:0.2222%, last loss: 10.19
# Train completion:12.01%, time:605 m:19 s, avg loss: 10.16, avg acc:0.2198%, last loss: 10.23
# Train completion:12.14%, time:606 m:7 s, avg loss: 10.16, avg acc:0.2174%, last loss: 10.21
# Train completion:12.28%, time:606 m:59 s, avg loss: 10.16, avg acc:0.2151%, last loss: 10.14
# Train completion:12.41%, time:608 m:3 s, avg loss: 10.16, avg acc:0.2128%, last loss: 10.13
# Train completion:12.54%, time:608 m:52 s, avg loss: 10.16, avg acc:0.2105%, last loss: 10.13
# Train completion:12.67%, time:610 m:1 s, avg loss: 10.16, avg acc:0.2083%, last loss: 10.15
# Train completion:12.80%, time:611 m:0 s, avg loss: 10.16, avg acc:0.2062%, last loss: 10.21
# Train completion:12.94%, time:611 m:49 s, avg loss: 10.16, avg acc:0.2041%, last loss: 10.14
# Train completion:13.07%, time:612 m:39 s, avg loss: 10.16, avg acc:0.2020%, last loss: 10.19
# Train completion:13.20%, time:613 m:28 s, avg loss: 10.16, avg acc:0.2000%, last loss: 10.13
# Train completion:13.33%, time:614 m:13 s, avg loss: 10.16, avg acc:0.1980%, last loss: 10.25
# Train completion:13.46%, time:615 m:0 s, avg loss: 10.16, avg acc:0.1961%, last loss: 10.09
# Train completion:13.60%, time:615 m:46 s, avg loss: 10.16, avg acc:0.1942%, last loss: 10.16
# Train completion:13.73%, time:616 m:32 s, avg loss: 10.16, avg acc:0.1923%, last loss: 10.15
# Train completion:13.86%, time:617 m:18 s, avg loss: 10.16, avg acc:0.1905%, last loss: 10.14
# Train completion:13.99%, time:618 m:6 s, avg loss: 10.16, avg acc:0.1887%, last loss: 10.24
# Train completion:14.12%, time:618 m:54 s, avg loss: 10.16, avg acc:0.1869%, last loss: 10.17
# Train completion:14.26%, time:619 m:42 s, avg loss: 10.16, avg acc:0.1852%, last loss: 10.22
# Train completion:14.39%, time:620 m:35 s, avg loss: 10.16, avg acc:0.1835%, last loss: 10.26
# Train completion:14.52%, time:621 m:36 s, avg loss: 10.16, avg acc:0.1818%, last loss: 10.24
# Train completion:14.65%, time:622 m:22 s, avg loss: 10.16, avg acc:0.1802%, last loss: 10.18
# Train completion:14.78%, time:623 m:9 s, avg loss: 10.16, avg acc:0.1786%, last loss: 10.09
# Train completion:14.92%, time:623 m:59 s, avg loss: 10.16, avg acc:0.1770%, last loss: 10.20
# Train completion:15.05%, time:625 m:1 s, avg loss: 10.16, avg acc:0.1754%, last loss: 10.09
# Train completion:15.18%, time:626 m:2 s, avg loss: 10.16, avg acc:0.1739%, last loss: 10.13
# Train completion:15.31%, time:627 m:5 s, avg loss: 10.16, avg acc:0.1724%, last loss: 10.23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 12>()
#      30 output=torch.exp(output)
#      31 _, pred=output.topk(1,dim=1)
# ---> 33 loss.backward()
#      34 optimizer.step()
#      35 lr_decay.step()
#
# File ~\Anaconda3\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\Anaconda3\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
save_model_path=r"C:\Users\mihnea.andrei\Work\facial_recognition\saved_models"
save_file="/ViTm,embedded=%d,depth=%d,num_heads=%d,eval_loss=%.4f,eval_acc=%d%%.pt"%(
    embed_dim,depth,num_heads,np.mean(all_eval_losses),np.mean(all_eval_accs))

torch.save(model_fit,save_model_path+save_file)

# %%
plt.figure(figsize=(10,5))
plt.title("Train losses")
plt.plot(all_train_losses,label="train losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Evaluation losses")
plt.plot(all_eval_losses,label="eval losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Train accuracies")
plt.plot(all_train_accs,label="train accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Eval accuracies")
plt.plot(all_train_accs,label="eval accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()
