# %%
#####################
#FB and GOOG face recognition combined (most kept from FB and included some ideas from GOOG).
#FB
#Facebook transformer for image classification: https://github.com/facebookresearch/deit/blob/main/models_v2.py
#Go to line 269 for examples for different models with different inputs.
#The paper with details on learning rate, optimizer type etc is: https://arxiv.org/pdf/2012.12877.pdf
#GOOG
#Google transformer for image classification: https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#The paper is at the following link: https://arxiv.org/pdf/2010.11929.pdf
#Implementation that generalizes Layer_scale_init_Block and adds ScaledLayers, following Google's idea for ParallelBlock.
#Implementation of attention from the original well known paperȘ Attention is all you need: 
#https://nlp.seas.harvard.edu/2018/04/03/attention.html
#####################
###########################
#Use implicit layers in attention with different formulas. Idk what works. I am trying linear(old formula) or 
#linear(old formula)+linear(old formula**2).
############################
from torch import nn, optim, as_tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.nn.init import *
from torchvision import transforms, utils, datasets, models
import cv2
from PIL import Image
from pdb import set_trace
import time
import copy
from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import io, transform
from tqdm import trange, tqdm
import csv 
import glob 
import dlib
import pandas as pd
import numpy as np
from functools import partial
from collections import OrderedDict

# !pip install timm
from timm.models.vision_transformer import Mlp, PatchEmbed , _cfg
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model


#Imports inside facenet scripts that need to be loaded here on google colab.
import requests
from requests.adapters import HTTPAdapter
import torch
import hashlib
import shutil
import tempfile
from urllib.request import urlopen, Request

use_cuda=torch.cuda.is_available()
device=torch.device("cuda" if use_cuda else "cpu")
print(device)

#####################
#Global valriables
####################
#The following variable determines how many pictures are fed at once into the NN (this is made for speed). 
#Facebook does 4096.
batches=32   
#The following path points to the folder that contains the images with faces only.
data_dir=r"C:\Users\mihnea.andrei\Work\facial_recognition\faces_images"

def imshow(inp,title=None):
  ############
  #Imshow for tensor
  #############
    inp=inp.numpy().transpose([1,2,0])
    mean=np.array([0.485, 0.456, 0.406])
    std=np.array([0.229, 0.224, 0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.0001)

#The following function times the NN.
def timming(since):
    time_elapsed=time.time()-since
    minutes=time_elapsed // 60
    seconds=time_elapsed%60
    return "%d m:%d s"%(minutes,seconds)
# Out:
# Requirement already satisfied: timm in c:\users\mihnea.andrei\anaconda3\lib\site-packages (0.6.7)
# Requirement already satisfied: torchvision in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (0.13.0)
# Requirement already satisfied: torch>=1.4 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from timm) (1.12.0)
# Requirement already satisfied: typing_extensions in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: numpy in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (1.21.5)
# Requirement already satisfied: requests in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from torchvision->timm) (9.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mihnea.andrei\anaconda3\lib\site-packages (from requests->torchvision->timm) (2.0.4)
# cpu

# %%
#If you use the MTCNN code that does the random transformations also, you do not need all those transformations again 
#(maybe) except the horizonta flip - the angle from which the picture is taken.
data_transforms={
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),  
        #transforms.ColorJitter(brightness=0.5,contrast=0.5),
        #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(3, 7)),
        #transforms.RandomAdjustSharpness(sharpness_factor=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'eval': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])
}
phases=list(data_transforms.keys())
image_datasets={x:datasets.ImageFolder(os.path.join(data_dir,x),data_transforms[x]) for x in list(data_transforms.keys())}
dataloaders={x:torch.utils.data.DataLoader(image_datasets[x],batch_size=batches,shuffle=True) for x in list(data_transforms.keys())}
data_sizes={x:len(image_datasets[x]) for x in list(data_transforms.keys())}
class_names=image_datasets['train'].classes 

inputs, classes = next(iter(dataloaders['train']))
out=utils.make_grid(inputs)
imshow(out,title=",".join([class_names[i] for i in classes.tolist()]))

# %%
def attention(query, key, value, mask=None, dropout=None):
    "Compute 'Scaled Dot Product Attention'"
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value)


def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class impl_attention(nn.Module):
    def __init__(self,dim, mask=None, dropout=None,tol=10**(-4),max_iter=50):
    #def __init__(self,query, key, value, dim, mask=None, dropout=None,tol=10**(-4),max_iter=50):
        super().__init__()
        #self.query=query
        #self.key=key
        #self.value=value
        self.mask=mask
        self.dropout=dropout
        self.tol=tol
        self.max_iter=max_iter
        self.softmax=nn.Softmax(dim=-1)
        self.tanh=nn.Tanh()
        self.relu=nn.ReLU()
        
        self.linear1=nn.Linear(dim,dim)
        self.linear2=nn.Linear(dim,dim)
        self.linear3=nn.Linear(dim,dim)
        
        if dropout is not None:
            self.dropout_nn=nn.Dropout(dropout)
        
        
    def forward(self,x):
        x_next=torch.zeros_like(x)
        self.iterations=0
        while self.iterations<=self.max_iter:
            x_hat=self.linear1(x)
            attn_in=self.linear2(x)+x_hat
            x_next=self.linear3(self.tanh(self.linear2(attention(attn_in,attn_in,attn_in))))
            self.err=torch.norm(x_next-x)
            x=x_next
            self.iterations+=1
            
            if self.err<=self.tol:
                break
            
        out=x
        if self.dropout is not None:
            out=self.dropout_nn(out)
        
        return out
        
#LayerScale from Google
class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma

# %%
#Original Block class from FB to which I try to add the extra layers that Google has
#Can be passed to block_layers parameter in main class.
class Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,
                 Attention_block = impl_attention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        
        self.attn = Attention_block(dim=dim,dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        #Below, I add the LayerScale that Google has.
        self.ls1=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        #Below I add another LayerScale that Google has
        self.ls2=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        

    def forward(self, x):
        #x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x),self.norm1(x),self.norm1(x))))
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
#Take class from below from FB     
#Can be passed to block_layers parameter in main class.
class Layer_scale_init_Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    # with slight modifications
    def __init__(self, dim, num_heads, mlp_ratio=4., dropout=0.,drop_path=0., act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm,Attention_block = impl_attention,Mlp_block=Mlp,init_values=1e-4):
        super().__init__()
        self.attn = Attention_block(dim=dim,dropout=dropout)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=dropout)
        self.gamma_1 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)
        self.gamma_2 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)

    def forward(self, x):
        #x = x + self.drop_path(self.gamma_1 * self.attn(x,x,x))
        x = x + self.drop_path(self.gamma_1 * self.attn(x))
        x = x + self.drop_path(self.gamma_2 * self.mlp(self.norm2(x)))
        return x

# %%
###################1#########################
#Can be passed to block_layers parameter in main class.
#Implementation that generalizes Layer_scale_init_Block following Google's idea for ParallelBlock.
#############################################
class ParallelLayer_scale_init_Block(nn.Module):
    def __init__(self,dim,num_heads,mlp_ratio=4,dropout=0,drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,
                 Attention_block=impl_attention,Mlp_block=Mlp,init_values=10**(-4),num_parallel=2):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        
        #####################3
        #do not know how to multiply by gammas since those are just compositions of functions basically.
        #hopefully it does not matter since gammas are parameters and maybe it will be better if num_parameters>2
        #could add LayerScale to both attention and forward feed.
        ############################
        mlp_hidden_dim = int(dim * mlp_ratio)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim=dim,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp_block(in_features=dim,hidden_features=mlp_hidden_dim,act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    #x=f(self.norm1(x),self.norm1(x),self.norm1(x))
                    x=f(self.norm1(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#####################2##########################
#Use the generalized implementation that Google has for FB's Block_paralx2 (num_parallel=2 here for FB's implementation).
#Can be passed to block_layers parameter in main class.
################################################
class ParallelBlock(nn.Module):
    def __init__(self,dim,num_heads,num_parallel=2,mlp_ratio=4,init_values=10**(-4),dropout=0,drop_path=0,act_layer=nn.GELU,
                 norm_layer=nn.LayerNorm,Attention_block=impl_attention,Mlp_block=Mlp):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        
        self.norm1=norm_layer(dim)
        self.norm2=norm_layer(dim)
        self.norm3=norm_layer(dim)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim=dim,dropout=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity()) 
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp(dim,hidden_features=int(dim*mlp_ratio),act_layer=act_layer,drop=dropout)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path", DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    def forward(self,x):
        s=0
        for attn in self.attns:
            counter=0
            for f in attn:
                if counter!=1:
                    x=f(x)
                else:
                    #x=f(self.norm1(x),self.norm2(x),self.norm3(x))
                    x=f(self.norm1(x))
                counter+=1
            s+=x
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Copy class from below from FB
class hMLP_stem(nn.Module):
    """ hMLP_stem: https://arxiv.org/pdf/2203.09795.pdf
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, embed_dim=768,norm_layer=nn.SyncBatchNorm):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.proj = torch.nn.Sequential(*[nn.Conv2d(in_chans, embed_dim//4, kernel_size=4, stride=4),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim//4, kernel_size=2, stride=2),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim, kernel_size=2, stride=2),
                                          norm_layer(embed_dim),
                                         ])
        

    def forward(self, x):
        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

# %%
#Copy class from below from FB
class vit_models(nn.Module):
    """ Vision Transformer with LayerScale (https://arxiv.org/abs/2103.17239) support
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=160,  patch_size=16, in_chans=3, num_classes=1000, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., drop_rate=0.,
                 drop_path_rate=0., norm_layer=nn.LayerNorm, global_pool=None,
                 block_layers = Block,
                 Patch_layer=PatchEmbed,act_layer=nn.GELU,
                 Attention_block = impl_attention, Mlp_block=Mlp,
                dpr_constant=True,init_scale=1e-4,
                mlp_ratio_clstk = 4.0):
        super().__init__()
        
        self.dropout_rate = drop_rate

            
        self.num_classes = num_classes
        self.num_features = self.embed_dim = embed_dim

        self.patch_embed = Patch_layer(
                img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))

        dpr = [drop_path_rate for i in range(depth)]
        self.blocks = nn.ModuleList([
            block_layers(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio,
                dropout=0.0, drop_path=dpr[i], norm_layer=norm_layer,
                act_layer=act_layer,Attention_block=Attention_block,Mlp_block=Mlp_block,init_values=init_scale)
            for i in range(depth)])
        

        
            
        self.norm = norm_layer(embed_dim)

        self.feature_info = [dict(num_chs=embed_dim, reduction=0, module='head')]
        self.head = nn.Linear(embed_dim, num_classes) if num_classes > 0 else nn.Identity()

        trunc_normal_(self.pos_embed, std=.02)
        trunc_normal_(self.cls_token, std=.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'pos_embed', 'cls_token'}

    def get_classifier(self):
        return self.head
    
    def get_num_layers(self):
        return len(self.blocks)
    
    def reset_classifier(self, num_classes, global_pool=''):
        self.num_classes = num_classes
        self.head = nn.Linear(self.embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward_features(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        
        x = x + self.pos_embed
        
        x = torch.cat((cls_tokens, x), dim=1)
            
        for i , blk in enumerate(self.blocks):
            x = blk(x)
            
        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):

        x = self.forward_features(x)
        
        if self.dropout_rate:
            x = F.dropout(x, p=float(self.dropout_rate), training=self.training)
        x = self.head(x)
        
        return x

# %%
#The below number is 160 because the faces extracted by MTCNN are 160x160.
img_size=160
#The number of names that the model will see (population of romania over 14).
num_classes=data_sizes["train"]
#Variables inside the network. Please check examples that start at line 271 here: 
#https://github.com/facebookresearch/deit/blob/main/models_v2.py
embed_dim=192
depth=12
num_heads=3
mlp_ratio=4

model_fit=vit_models(num_classes=num_classes,img_size=img_size,patch_size=batches,
                     embed_dim=embed_dim,depth=depth,num_heads=num_heads,mlp_ratio=mlp_ratio,
                    norm_layer=partial(nn.LayerNorm,eps=10**(-6)),
                    block_layers=ParallelBlock).to(device)

num_epochs=25
lr=3*10**(-3)
weight_decay=0.01
criterion=nn.CrossEntropyLoss()
#Facebook does AdamW. Please see paper.
#optimizer=optim.SGD(model_fit.parameters(),lr=10**(-2),momentum=0.9)
optimizer=torch.optim.AdamW(model_fit.parameters(),lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=weight_decay)
#lr_decay=lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
lr_decay=torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs)

# %%
best_model_weights=copy.deepcopy(model_fit.state_dict())
best_acc=0
since=time.time()
printing_iter=10**(1)

all_train_losses=[]
all_train_accs=[]
all_eval_losses=[]
all_eval_accs=[]
best_eval_acc=0

for epoch in range(num_epochs):
    print("-"*100)
    print("Training for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    train_losses=[]
    train_accs=[]
    counter=0

    for x, label in dataloaders["train"]:
        x=x.to(device)
        label=label.to(device)
        
        optimizer.zero_grad()
        
        output=model_fit(x)
        loss=criterion(output,label)
        
        output=torch.exp(output)
        _, pred=output.topk(1,dim=1)
        
        loss.backward()
        optimizer.step()
        lr_decay.step()
        
        last_loss=loss.item()
        train_losses.append(last_loss) 
        all_train_losses.append(last_loss)
        pred=pred.cpu()
        label=label.cpu()
        current_acc=100*torch.sum(pred==label.data).double()/batches
        train_accs.append(current_acc)
        all_train_accs.append(current_acc)
        counter+=1

        if counter%printing_iter==0:
            print("Train completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                  %(100*counter*batches/data_sizes["train"],timming(since),np.mean(train_losses),
                    np.mean(train_accs),last_loss))
    
    training_avg_loss=np.mean(train_losses)
    print("-"*100)
    print("Eval for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    eval_losses=[]
    eval_accs=[]
    counter=0
    
    with torch.no_grad():
        for x, label in dataloaders["eval"]:
            x=x.to(device)
            label=label.to(device)
            
            output=model_fit(x)
            loss=criterion(output,label)
            
            output=torch.exp(output)
            _, pred=output.topk(1,dim=1)
            
            
            last_loss=loss.item()
            eval_losses.append(last_loss)
            all_eval_losses.append(last_loss)
            pred=pred.cpu()
            label=label.cpu()
            current_acc=100*torch.sum(pred==label.data).double()/batches
            eval_accs.append(current_acc)
            all_eval_accs.append(current_acc)
            counter+=1
            
            if counter%printing_iter==0:
                print("Eval completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.4f%%, last loss: %.2f"
                      %(100*counter*batches/data_sizes["eval"],timming(since),np.mean(eval_losses),
                        np.mean(eval_accs),last_loss))
            
    eval_avg_loss=np.mean(eval_losses)
    if np.mean(eval_accs)>best_eval_acc:
        best_eval_acc=np.mean(eval_accs)
        best_model_wts = copy.deepcopy(model_fit.state_dict())
    
    print("-"*100)
    print("Completed epoch %d/%d in %s, avg train loss: %.2f, avg train acc: %.4f%%, avg eval loss: %.2f, avg eval acc: %.4f"%
          (epoch+1,num_epochs,timming(since),training_avg_loss,np.mean(train_accs),eval_avg_loss,np.mean(eval_accs)))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for epoch 1/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:0.13%, time:0 m:32 s, avg loss: 12.41, avg acc:0.0000%, last loss: 12.40
# Train completion:0.26%, time:1 m:11 s, avg loss: 12.42, avg acc:0.0000%, last loss: 12.43
# Train completion:0.40%, time:1 m:46 s, avg loss: 12.43, avg acc:0.0000%, last loss: 12.44
# Train completion:0.53%, time:2 m:23 s, avg loss: 12.42, avg acc:0.0000%, last loss: 12.36
# Train completion:0.66%, time:2 m:57 s, avg loss: 12.42, avg acc:0.0000%, last loss: 12.55
# Train completion:0.79%, time:3 m:27 s, avg loss: 12.41, avg acc:0.0000%, last loss: 12.37
# Train completion:0.92%, time:3 m:55 s, avg loss: 12.41, avg acc:0.0000%, last loss: 12.51
# Train completion:1.06%, time:4 m:24 s, avg loss: 12.40, avg acc:0.0000%, last loss: 12.34
# Train completion:1.19%, time:4 m:56 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.44
# Train completion:1.32%, time:5 m:29 s, avg loss: 12.39, avg acc:0.0000%, last loss: 12.39
# Train completion:1.45%, time:6 m:0 s, avg loss: 12.38, avg acc:0.0000%, last loss: 12.14
# Train completion:1.58%, time:6 m:32 s, avg loss: 12.37, avg acc:0.0000%, last loss: 12.39
# Train completion:1.72%, time:7 m:6 s, avg loss: 12.36, avg acc:0.0000%, last loss: 12.04
# Train completion:1.85%, time:7 m:37 s, avg loss: 12.35, avg acc:0.0000%, last loss: 11.93
# Train completion:1.98%, time:8 m:7 s, avg loss: 12.34, avg acc:0.0000%, last loss: 11.93
# Train completion:2.11%, time:8 m:34 s, avg loss: 12.33, avg acc:0.0000%, last loss: 12.49
# Train completion:2.24%, time:9 m:1 s, avg loss: 12.33, avg acc:0.0000%, last loss: 12.56
# Train completion:2.38%, time:9 m:28 s, avg loss: 12.33, avg acc:0.0000%, last loss: 12.14
# Train completion:2.51%, time:9 m:55 s, avg loss: 12.32, avg acc:0.0000%, last loss: 12.25
# Train completion:2.64%, time:10 m:22 s, avg loss: 12.32, avg acc:0.0000%, last loss: 12.32
# Train completion:2.77%, time:10 m:49 s, avg loss: 12.31, avg acc:0.0000%, last loss: 12.16
# Train completion:2.90%, time:11 m:16 s, avg loss: 12.30, avg acc:0.0000%, last loss: 12.20
# Train completion:3.04%, time:11 m:42 s, avg loss: 12.30, avg acc:0.0000%, last loss: 12.01
# Train completion:3.17%, time:12 m:8 s, avg loss: 12.29, avg acc:0.0000%, last loss: 12.09
s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.49
# Train completion:31.68%, time:108 m:55 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.64
# Train completion:31.81%, time:109 m:21 s, avg loss: 11.25, avg acc:0.0000%, last loss: 10.50
# Train completion:31.94%, time:109 m:48 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.84
# Train completion:32.08%, time:110 m:14 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.33
# Train completion:32.21%, time:110 m:40 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.47
# Train completion:32.34%, time:111 m:6 s, avg loss: 11.24, avg acc:0.0000%, last loss: 10.84
# Train completion:32.47%, time:111 m:31 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.38
# Train completion:32.60%, time:111 m:58 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.64
# Train completion:32.74%, time:112 m:25 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.46
# Train completion:32.87%, time:112 m:52 s, avg loss: 11.23, avg acc:0.0000%, last loss: 10.69
# Train completion:33.00%, time:113 m:18 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.49
# Train completion:33.13%, time:113 m:45 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.69
# Train completion:33.26%, time:114 m:11 s, avg loss: 11.22, avg acc:0.0000%, last loss: 10.87
# Train completion:33.40%, time:114 m:38 s, avg loss: 11.21, avg acc:0.0000%, last loss: 10.60
# Train completion:33.53%, time:115 m:4 s, avg loss: 11.21, avg acc:0.0000%, last loss: 11.06
# Train completion:33.66%, time:115 m:30 s, avg loss: 11.21, avg acc:0.0000%, last loss: 10.65
# Train completion:33.79%, time:115 m:56 s, avg loss: 11.21, avg acc:0.0000%, last loss: 10.68
# Train completion:33.92%, time:116 m:22 s, avg loss: 11.20, avg acc:0.0000%, last loss: 10.36
# Train completion:34.06%, time:116 m:48 s, avg loss: 11.20, avg acc:0.0000%, last loss: 10.71
# Train completion:34.19%, time:117 m:14 s, avg loss: 11.20, avg acc:0.0000%, last loss: 10.41
# Train completion:34.32%, time:117 m:41 s, avg loss: 11.20, avg acc:0.0000%, last loss: 10.54
# Train completion:34.45%, time:118 m:8 s, avg loss: 11.19, avg acc:0.0000%, last loss: 10.40
# Train completion:34.58%, time:118 m:41 s, avg loss: 11.19, avg acc:0.0382%, last loss: 10.57
# Train completion:34.72%, time:119 m:13 s, avg loss: 11.19, avg acc:0.0380%, last loss: 10.74
# Train completion:34.85%, time:119 m:42 s, avg loss: 11.19, avg acc:0.0379%, last loss: 10.51
# Train completion:34.98%, time:120 m:9 s, avg loss: 11.18, avg acc:0.0377%, last loss: 10.76
# Train completion:35.11%, time:120 m:36 s, avg loss: 11.18, avg acc:0.0376%, last loss: 10.64
# Train completion:35.24%, time:121 m:3 s, avg loss: 11.18, avg acc:0.0375%, last loss: 10.53
# Train completion:35.38%, time:121 m:29 s, avg loss: 11.17, avg acc:0.0373%, last loss: 10.34
# Train completion:35.51%, time:121 m:55 s, avg loss: 11.17, avg acc:0.0372%, last loss: 10.69
# Train completion:35.64%, time:122 m:22 s, avg loss: 11.17, avg acc:0.0370%, last loss: 10.42
# Train completion:35.77%, time:122 m:48 s, avg loss: 11.17, avg acc:0.0369%, last loss: 10.56
# Train completion:35.90%, time:123 m:14 s, avg loss: 11.17, avg acc:0.0368%, last loss: 10.60
# Train completion:36.04%, time:123 m:40 s, avg loss: 11.16, avg acc:0.0366%, last loss: 10.57
# Train completion:36.17%, time:124 m:7 s, avg loss: 11.16, avg acc:0.0365%, last loss: 10.71
# Train completion:36.30%, time:124 m:34 s, avg loss: 11.16, avg acc:0.0364%, last loss: 10.49
# Train completion:36.43%, time:125 m:1 s, avg loss: 11.16, avg acc:0.0362%, last loss: 10.46
# Train completion:36.56%, time:125 m:27 s, avg loss: 11.15, avg acc:0.0361%, last loss: 10.51
# Train completion:36.70%, time:125 m:54 s, avg loss: 11.15, avg acc:0.0360%, last loss: 10.41
# Train completion:36.83%, time:126 m:20 s, avg loss: 11.15, avg acc:0.0358%, last loss: 10.35
# Train completion:36.96%, time:126 m:47 s, avg loss: 11.15, avg acc:0.0357%, last loss: 10.47
# Train completion:37.09%, time:127 m:13 s, avg loss: 11.14, avg acc:0.0356%, last loss: 10.35
# Train completion:37.22%, time:127 m:39 s, avg loss: 11.14, avg acc:0.0355%, last loss: 10.37
# Train completion:37.36%, time:128 m:5 s, avg loss: 11.14, avg acc:0.0353%, last loss: 10.79
# Train completion:37.49%, time:128 m:32 s, avg loss: 11.14, avg acc:0.0352%, last loss: 10.50
# Train completion:37.62%, time:128 m:59 s, avg loss: 11.13, avg acc:0.0351%, last loss: 10.45
# Train completion:37.75%, time:129 m:27 s, avg loss: 11.13, avg acc:0.0350%, last loss: 10.58
# Train completion:37.88%, time:129 m:56 s, avg loss: 11.13, avg acc:0.0348%, last loss: 10.52
# Train completion:38.02%, time:130 m:22 s, avg loss: 11.13, avg acc:0.0347%, last loss: 10.41
# Train completion:38.15%, time:130 m:49 s, avg loss: 11.12, avg acc:0.0346%, last loss: 10.69
# Train completion:38.28%, time:131 m:16 s, avg loss: 11.12, avg acc:0.0345%, last loss: 10.69
# Train completion:38.41%, time:131 m:43 s, avg loss: 11.12, avg acc:0.0344%, last loss: 10.49
# Train completion:38.54%, time:132 m:11 s, avg loss: 11.12, avg acc:0.0342%, last loss: 10.58
# Train completion:38.68%, time:132 m:39 s, avg loss: 11.12, avg acc:0.0341%, last loss: 10.44
# Train completion:38.81%, time:133 m:5 s, avg loss: 11.11, avg acc:0.0340%, last loss: 10.86
# Train completion:38.94%, time:133 m:31 s, avg loss: 11.11, avg acc:0.0339%, last loss: 10.25
# Train completion:39.07%, time:133 m:57 s, avg loss: 11.11, avg acc:0.0338%, last loss: 10.60
# Train completion:39.21%, time:134 m:23 s, avg loss: 11.11, avg acc:0.0337%, last loss: 10.33
# Train completion:39.34%, time:134 m:50 s, avg loss: 11.10, avg acc:0.0336%, last loss: 10.45
# Train completion:39.47%, time:135 m:16 s, avg loss: 11.10, avg acc:0.0334%, last loss: 10.56
# Train completion:39.60%, time:135 m:42 s, avg loss: 11.10, avg acc:0.0333%, last loss: 10.55
# Train completion:39.73%, time:136 m:8 s, avg loss: 11.10, avg acc:0.0332%, last loss: 10.54
# Train completion:39.87%, time:136 m:35 s, avg loss: 11.10, avg acc:0.0331%, last loss: 10.80
# Train completion:40.00%, time:137 m:1 s, avg loss: 11.09, avg acc:0.0330%, last loss: 10.40
# Train completion:40.13%, time:137 m:28 s, avg loss: 11.09, avg acc:0.0329%, last loss: 10.42
# Train completion:40.26%, time:137 m:54 s, avg loss: 11.09, avg acc:0.0328%, last loss: 10.48
# Train completion:40.39%, time:138 m:20 s, avg loss: 11.09, avg acc:0.0327%, last loss: 10.42
# Train completion:40.53%, time:138 m:45 s, avg loss: 11.08, avg acc:0.0326%, last loss: 10.41
# Train completion:40.66%, time:139 m:12 s, avg loss: 11.08, avg acc:0.0325%, last loss: 10.46
# Train completion:40.79%, time:139 m:38 s, avg loss: 11.08, avg acc:0.0324%, last loss: 10.56
# Train completion:40.92%, time:140 m:5 s, avg loss: 11.08, avg acc:0.0323%, last loss: 10.50
# Train completion:41.05%, time:140 m:31 s, avg loss: 11.08, avg acc:0.0322%, last loss: 10.43
# Train completion:41.19%, time:140 m:57 s, avg loss: 11.07, avg acc:0.0321%, last loss: 10.21
# Train completion:41.32%, time:141 m:24 s, avg loss: 11.07, avg acc:0.0319%, last loss: 10.31
# Train completion:41.45%, time:141 m:51 s, avg loss: 11.07, avg acc:0.0318%, last loss: 10.26
# Train completion:41.58%, time:142 m:16 s, avg loss: 11.07, avg acc:0.0317%, last loss: 10.40
# Train completion:41.71%, time:142 m:42 s, avg loss: 11.07, avg acc:0.0316%, last loss: 10.49
# Train completion:41.85%, time:143 m:9 s, avg loss: 11.06, avg acc:0.0315%, last loss: 10.50
# Train completion:41.98%, time:143 m:35 s, avg loss: 11.06, avg acc:0.0314%, last loss: 10.54
# Train completion:42.11%, time:144 m:2 s, avg loss: 11.06, avg acc:0.0313%, last loss: 10.11
# Train completion:42.24%, time:144 m:28 s, avg loss: 11.06, avg acc:0.0312%, last loss: 10.43
# Train completion:42.37%, time:144 m:56 s, avg loss: 11.06, avg acc:0.0312%, last loss: 10.39
# Train completion:42.51%, time:145 m:23 s, avg loss: 11.05, avg acc:0.0311%, last loss: 10.41
# Train completion:42.64%, time:145 m:48 s, avg loss: 11.05, avg acc:0.0310%, last loss: 10.31
# Train completion:42.77%, time:146 m:15 s, avg loss: 11.05, avg acc:0.0309%, last loss: 10.45
# Train completion:42.90%, time:146 m:42 s, avg loss: 11.05, avg acc:0.0308%, last loss: 10.21
# Train completion:43.03%, time:147 m:8 s, avg loss: 11.05, avg acc:0.0307%, last loss: 10.61
# Train completion:43.17%, time:147 m:33 s, avg loss: 11.04, avg acc:0.0306%, last loss: 10.21
# Train completion:43.30%, time:147 m:58 s, avg loss: 11.04, avg acc:0.0305%, last loss: 10.50
# Train completion:43.43%, time:148 m:24 s, avg loss: 11.04, avg acc:0.0304%, last loss: 10.37
# Train completion:43.56%, time:148 m:49 s, avg loss: 11.04, avg acc:0.0303%, last loss: 10.65
# Train completion:43.69%, time:149 m:15 s, avg loss: 11.04, avg acc:0.0302%, last loss: 10.23
# Train completion:43.83%, time:149 m:40 s, avg loss: 11.04, avg acc:0.0301%, last loss: 10.28
# Train completion:47.92%, time:162 m:47 s, avg loss: 10.98, avg acc:0.0551%, last loss: 10.27
# Train completion:48.05%, time:163 m:12 s, avg loss: 10.98, avg acc:0.0549%, last loss: 10.43
# Train completion:48.18%, time:163 m:37 s, avg loss: 10.98, avg acc:0.0548%, last loss: 10.55
# Train completion:48.31%, time:164 m:3 s, avg loss: 10.97, avg acc:0.0546%, last loss: 10.41
# Train completion:48.45%, time:164 m:28 s, avg loss: 10.97, avg acc:0.0545%, last loss: 10.33
# Train completion:48.58%, time:164 m:54 s, avg loss: 10.97, avg acc:0.0543%, last loss: 10.42
# Train completion:48.71%, time:165 m:18 s, avg loss: 10.97, avg acc:0.0542%, last loss: 10.27
# Train completion:48.84%, time:165 m:44 s, avg loss: 10.97, avg acc:0.0541%, last loss: 10.57
# Train completion:48.97%, time:166 m:8 s, avg loss: 10.97, avg acc:0.0539%, last loss: 10.43
# Train completion:49.11%, time:166 m:34 s, avg loss: 10.96, avg acc:0.0538%, last loss: 10.47
# Train completion:49.24%, time:166 m:58 s, avg loss: 10.96, avg acc:0.0536%, last loss: 10.48
# Train completion:49.37%, time:167 m:24 s, avg loss: 10.96, avg acc:0.0535%, last loss: 10.61
# Train completion:49.50%, time:167 m:49 s, avg loss: 10.96, avg acc:0.0533%, last loss: 10.35
# Train completion:49.63%, time:168 m:15 s, avg loss: 10.96, avg acc:0.0532%, last loss: 10.41
# Train completion:49.77%, time:168 m:41 s, avg loss: 10.96, avg acc:0.0531%, last loss: 10.32
# Train completion:49.90%, time:169 m:8 s, avg loss: 10.95, avg acc:0.0529%, last loss: 10.22
# Train completion:50.03%, time:169 m:32 s, avg loss: 10.95, avg acc:0.0528%, last loss: 10.43
# Train completion:50.16%, time:169 m:58 s, avg loss: 10.95, avg acc:0.0526%, last loss: 10.10
# Train completion:50.29%, time:170 m:22 s, avg loss: 10.95, avg acc:0.0525%, last loss: 10.27
# Train completion:50.43%, time:170 m:48 s, avg loss: 10.95, avg acc:0.0524%, last loss: 10.21
# Train completion:50.56%, time:171 m:12 s, avg loss: 10.95, avg acc:0.0522%, last loss: 10.60
# Train completion:50.69%, time:171 m:36 s, avg loss: 10.94, avg acc:0.0521%, last loss: 10.42
# Train completion:50.82%, time:172 m:2 s, avg loss: 10.94, avg acc:0.0519%, last loss: 10.49
# Train completion:50.95%, time:172 m:27 s, avg loss: 10.94, avg acc:0.0518%, last loss: 10.23
# Train completion:51.09%, time:172 m:53 s, avg loss: 10.94, avg acc:0.0517%, last loss: 10.25
# Train completion:51.22%, time:173 m:18 s, avg loss: 10.94, avg acc:0.0515%, last loss: 10.43
# Train completion:51.35%, time:173 m:43 s, avg loss: 10.94, avg acc:0.0514%, last loss: 10.43
# Train completion:51.48%, time:174 m:10 s, avg loss: 10.94, avg acc:0.0513%, last loss: 10.60
# Train completion:51.61%, time:174 m:36 s, avg loss: 10.93, avg acc:0.0512%, last loss: 10.31
# Train completion:51.75%, time:175 m:2 s, avg loss: 10.93, avg acc:0.0510%, last loss: 10.32
# Train completion:51.88%, time:175 m:28 s, avg loss: 10.93, avg acc:0.0509%, last loss: 10.42
# Train completion:52.01%, time:175 m:54 s, avg loss: 10.93, avg acc:0.0508%, last loss: 10.47
# Train completion:52.14%, time:176 m:19 s, avg loss: 10.93, avg acc:0.0506%, last loss: 10.55
# Train completion:52.27%, time:176 m:45 s, avg loss: 10.93, avg acc:0.0505%, last loss: 10.45
# Train completion:52.41%, time:177 m:12 s, avg loss: 10.93, avg acc:0.0504%, last loss: 10.30
# Train completion:52.54%, time:177 m:39 s, avg loss: 10.92, avg acc:0.0503%, last loss: 10.33
# Train completion:52.67%, time:178 m:5 s, avg loss: 10.92, avg acc:0.0501%, last loss: 10.41
# Train completion:52.80%, time:178 m:31 s, avg loss: 10.92, avg acc:0.0500%, last loss: 10.20
# Train completion:52.93%, time:178 m:58 s, avg loss: 10.92, avg acc:0.0499%, last loss: 10.31
# Train completion:53.07%, time:179 m:23 s, avg loss: 10.92, avg acc:0.0498%, last loss: 10.45
# Train completion:53.20%, time:179 m:47 s, avg loss: 10.92, avg acc:0.0496%, last loss: 10.32
# Train completion:53.33%, time:180 m:13 s, avg loss: 10.92, avg acc:0.0495%, last loss: 10.44
# Train completion:53.46%, time:180 m:38 s, avg loss: 10.91, avg acc:0.0494%, last loss: 10.37
# Train completion:53.59%, time:181 m:4 s, avg loss: 10.91, avg acc:0.0493%, last loss: 10.16
# Train completion:53.73%, time:181 m:29 s, avg loss: 10.91, avg acc:0.0491%, last loss: 10.51
# Train completion:53.86%, time:181 m:54 s, avg loss: 10.91, avg acc:0.0490%, last loss: 10.27
# Train completion:53.99%, time:182 m:19 s, avg loss: 10.91, avg acc:0.0489%, last loss: 10.26
# Train completion:54.12%, time:182 m:44 s, avg loss: 10.91, avg acc:0.0488%, last loss: 10.35
# Train completion:54.25%, time:183 m:11 s, avg loss: 10.91, avg acc:0.0487%, last loss: 10.35
# Train completion:54.39%, time:183 m:36 s, avg loss: 10.90, avg acc:0.0485%, last loss: 10.22
# Train completion:54.52%, time:184 m:1 s, avg loss: 10.90, avg acc:0.0484%, last loss: 10.22
# Train completion:54.65%, time:184 m:27 s, avg loss: 10.90, avg acc:0.0483%, last loss: 10.27
# Train completion:54.78%, time:184 m:53 s, avg loss: 10.90, avg acc:0.0482%, last loss: 10.35
# Train completion:54.91%, time:185 m:19 s, avg loss: 10.90, avg acc:0.0481%, last loss: 10.35
# Train completion:55.05%, time:185 m:45 s, avg loss: 10.90, avg acc:0.0480%, last loss: 10.40
# Train completion:55.18%, time:186 m:10 s, avg loss: 10.90, avg acc:0.0478%, last loss: 10.32
# Train completion:55.31%, time:186 m:36 s, avg loss: 10.89, avg acc:0.0477%, last loss: 10.29
# Train completion:55.44%, time:187 m:2 s, avg loss: 10.89, avg acc:0.0476%, last loss: 10.21
# Train completion:55.57%, time:187 m:27 s, avg loss: 10.89, avg acc:0.0475%, last loss: 10.30
# Train completion:55.71%, time:187 m:52 s, avg loss: 10.89, avg acc:0.0474%, last loss: 10.18
# Train completion:55.84%, time:188 m:18 s, avg loss: 10.89, avg acc:0.0473%, last loss: 10.26
# Train completion:55.97%, time:188 m:44 s, avg loss: 10.89, avg acc:0.0472%, last loss: 10.26
# Train completion:56.10%, time:189 m:11 s, avg loss: 10.89, avg acc:0.0471%, last loss: 10.45
# Train completion:56.23%, time:189 m:37 s, avg loss: 10.89, avg acc:0.0469%, last loss: 10.53
# Train completion:56.37%, time:190 m:5 s, avg loss: 10.88, avg acc:0.0468%, last loss: 10.24
# Train completion:56.50%, time:190 m:31 s, avg loss: 10.88, avg acc:0.0467%, last loss: 10.34
# Train completion:56.63%, time:190 m:57 s, avg loss: 10.88, avg acc:0.0466%, last loss: 10.29
# Train completion:56.76%, time:191 m:22 s, avg loss: 10.88, avg acc:0.0465%, last loss: 10.36
# Train completion:56.89%, time:191 m:48 s, avg loss: 10.88, avg acc:0.0464%, last loss: 10.28
# Train completion:57.03%, time:192 m:14 s, avg loss: 10.88, avg acc:0.0463%, last loss: 10.23
# Train completion:57.16%, time:192 m:40 s, avg loss: 10.88, avg acc:0.0462%, last loss: 10.54
# Train completion:57.29%, time:193 m:5 s, avg loss: 10.87, avg acc:0.0461%, last loss: 10.37
# Train completion:57.42%, time:193 m:31 s, avg loss: 10.87, avg acc:0.0460%, last loss: 10.32
# Train completion:57.55%, time:193 m:56 s, avg loss: 10.87, avg acc:0.0459%, last loss: 10.24
# Train completion:57.69%, time:194 m:22 s, avg loss: 10.87, avg acc:0.0458%, last loss: 10.12
# Train completion:57.82%, time:194 m:48 s, avg loss: 10.87, avg acc:0.0457%, last loss: 10.31
# Train completion:57.95%, time:195 m:12 s, avg loss: 10.87, avg acc:0.0456%, last loss: 10.36
# Train completion:58.08%, time:195 m:39 s, avg loss: 10.87, avg acc:0.0455%, last loss: 10.42
# Train completion:58.21%, time:196 m:6 s, avg loss: 10.87, avg acc:0.0454%, last loss: 10.39
# Train completion:58.35%, time:196 m:35 s, avg loss: 10.86, avg acc:0.0452%, last loss: 10.69
# Train completion:58.48%, time:197 m:3 s, avg loss: 10.86, avg acc:0.0451%, last loss: 10.15
# Train completion:58.61%, time:197 m:31 s, avg loss: 10.86, avg acc:0.0450%, last loss: 10.21
# Train completion:58.74%, time:198 m:0 s, avg loss: 10.86, avg acc:0.0449%, last loss: 10.15
# Train completion:58.87%, time:198 m:27 s, avg loss: 10.86, avg acc:0.0448%, last loss: 10.47
# Train completion:59.01%, time:198 m:56 s, avg loss: 10.86, avg acc:0.0447%, last loss: 10.49
# Train completion:59.14%, time:199 m:24 s, avg loss: 10.86, avg acc:0.0446%, last loss: 10.28
# Train completion:59.27%, time:199 m:51 s, avg loss: 10.86, avg acc:0.0445%, last loss: 10.32
# Train completion:59.40%, time:200 m:16 s, avg loss: 10.86, avg acc:0.0444%, last loss: 10.60
# Train completion:59.53%, time:200 m:44 s, avg loss: 10.85, avg acc:0.0443%, last loss: 10.29
# Train completion:59.67%, time:201 m:12 s, avg loss: 10.85, avg acc:0.0442%, last loss: 10.33
# Train completion:59.80%, time:201 m:38 s, avg loss: 10.85, avg acc:0.0442%, last loss: 10.29
# Train completion:59.93%, time:202 m:7 s, avg loss: 10.85, avg acc:0.0441%, last loss: 10.31
# Train completion:60.06%, time:202 m:34 s, avg loss: 10.85, avg acc:0.0440%, last loss: 10.19
# Train completion:60.19%, time:203 m:0 s, avg loss: 10.85, avg acc:0.0439%, last loss: 10.11
# Train completion:60.33%, time:203 m:27 s, avg loss: 10.85, avg acc:0.0438%, last loss: 10.25
# Train completion:60.46%, time:203 m:53 s, avg loss: 10.85, avg acc:0.0437%, last loss: 10.17
# Train completion:60.59%, time:204 m:19 s, avg loss: 10.84, avg acc:0.0436%, last loss: 10.27
# Train completion:60.72%, time:204 m:47 s, avg loss: 10.84, avg acc:0.0435%, last loss: 10.37
# Train completion:60.85%, time:205 m:14 s, avg loss: 10.84, avg acc:0.0434%, last loss: 10.49
# Train completion:60.99%, time:205 m:41 s, avg loss: 10.84, avg acc:0.0433%, last loss: 10.18
# Train completion:61.12%, time:206 m:7 s, avg loss: 10.84, avg acc:0.0432%, last loss: 10.21
# Train completion:61.25%, time:206 m:34 s, avg loss: 10.84, avg acc:0.0431%, last loss: 10.27
# Train completion:61.38%, time:207 m:1 s, avg loss: 10.84, avg acc:0.0430%, last loss: 10.56
# Train completion:61.51%, time:207 m:27 s, avg loss: 10.84, avg acc:0.0429%, last loss: 10.11
# Train completion:61.65%, time:207 m:53 s, avg loss: 10.84, avg acc:0.0428%, last loss: 10.35
# Train completion:61.78%, time:208 m:20 s, avg loss: 10.83, avg acc:0.0427%, last loss: 10.21
# Train completion:61.91%, time:208 m:46 s, avg loss: 10.83, avg acc:0.0426%, last loss: 10.24
# Train completion:62.04%, time:209 m:11 s, avg loss: 10.83, avg acc:0.0426%, last loss: 10.26
# Train completion:62.17%, time:209 m:38 s, avg loss: 10.83, avg acc:0.0425%, last loss: 10.25
# Train completion:62.31%, time:210 m:4 s, avg loss: 10.83, avg acc:0.0424%, last loss: 10.31
# Train completion:62.44%, time:210 m:29 s, avg loss: 10.83, avg acc:0.0423%, last loss: 10.31
# Train completion:62.57%, time:210 m:55 s, avg loss: 10.83, avg acc:0.0422%, last loss: 10.39
# Train completion:62.70%, time:211 m:21 s, avg loss: 10.83, avg acc:0.0421%, last loss: 10.29
# Train completion:62.83%, time:211 m:47 s, avg loss: 10.83, avg acc:0.0420%, last loss: 10.29
# Train completion:62.97%, time:212 m:13 s, avg loss: 10.82, avg acc:0.0419%, last loss: 10.31
# Train completion:63.10%, time:212 m:38 s, avg loss: 10.82, avg acc:0.0418%, last loss: 10.26
# Train completion:63.23%, time:213 m:3 s, avg loss: 10.82, avg acc:0.0418%, last loss: 10.33
# Train completion:63.36%, time:213 m:30 s, avg loss: 10.82, avg acc:0.0417%, last loss: 10.24
# Train completion:63.49%, time:213 m:57 s, avg loss: 10.82, avg acc:0.0416%, last loss: 10.29
# Train completion:63.63%, time:214 m:24 s, avg loss: 10.82, avg acc:0.0415%, last loss: 10.28
# Train completion:63.76%, time:214 m:50 s, avg loss: 10.82, avg acc:0.0414%, last loss: 10.36
# Train completion:63.89%, time:215 m:15 s, avg loss: 10.82, avg acc:0.0413%, last loss: 10.21
# Train completion:64.02%, time:215 m:42 s, avg loss: 10.82, avg acc:0.0412%, last loss: 10.28
# Train completion:64.15%, time:216 m:8 s, avg loss: 10.81, avg acc:0.0412%, last loss: 10.20
# Train completion:64.29%, time:216 m:35 s, avg loss: 10.81, avg acc:0.0411%, last loss: 10.30
# Train completion:64.42%, time:217 m:2 s, avg loss: 10.81, avg acc:0.0410%, last loss: 10.27
# Train completion:64.55%, time:217 m:30 s, avg loss: 10.81, avg acc:0.0409%, last loss: 10.30
# Train completion:64.68%, time:217 m:57 s, avg loss: 10.81, avg acc:0.0408%, last loss: 10.30
# Train completion:64.81%, time:218 m:24 s, avg loss: 10.81, avg acc:0.0407%, last loss: 10.29
# Train completion:64.95%, time:218 m:50 s, avg loss: 10.81, avg acc:0.0407%, last loss: 10.33
# Train completion:65.08%, time:219 m:16 s, avg loss: 10.81, avg acc:0.0406%, last loss: 10.16
# Train completion:65.21%, time:219 m:43 s, avg loss: 10.81, avg acc:0.0405%, last loss: 10.13
# Train completion:65.34%, time:220 m:11 s, avg loss: 10.80, avg acc:0.0404%, last loss: 10.28
# Train completion:65.47%, time:220 m:38 s, avg loss: 10.80, avg acc:0.0403%, last loss: 10.43
# Train completion:65.61%, time:221 m:4 s, avg loss: 10.80, avg acc:0.0402%, last loss: 10.21
# Train completion:65.74%, time:221 m:31 s, avg loss: 10.80, avg acc:0.0402%, last loss: 10.29
# Train completion:65.87%, time:221 m:57 s, avg loss: 10.80, avg acc:0.0401%, last loss: 10.41
# Train completion:66.00%, time:222 m:25 s, avg loss: 10.80, avg acc:0.0400%, last loss: 10.30
# Train completion:66.13%, time:222 m:52 s, avg loss: 10.80, avg acc:0.0399%, last loss: 10.32
# Train completion:66.27%, time:223 m:18 s, avg loss: 10.80, avg acc:0.0398%, last loss: 10.29
# Train completion:66.40%, time:223 m:44 s, avg loss: 10.80, avg acc:0.0398%, last loss: 10.39
# Train completion:66.53%, time:224 m:10 s, avg loss: 10.80, avg acc:0.0397%, last loss: 10.47
# Train completion:66.66%, time:224 m:37 s, avg loss: 10.80, avg acc:0.0396%, last loss: 10.25
# Train completion:66.79%, time:225 m:3 s, avg loss: 10.79, avg acc:0.0395%, last loss: 10.42
# Train completion:66.93%, time:225 m:30 s, avg loss: 10.79, avg acc:0.0394%, last loss: 10.33
# Train completion:67.06%, time:225 m:58 s, avg loss: 10.79, avg acc:0.0394%, last loss: 10.22
# Train completion:67.19%, time:226 m:24 s, avg loss: 10.79, avg acc:0.0393%, last loss: 10.37
# Train completion:67.32%, time:226 m:50 s, avg loss: 10.79, avg acc:0.0392%, last loss: 10.21
# Train completion:67.45%, time:227 m:16 s, avg loss: 10.79, avg acc:0.0391%, last loss: 10.22
# Train completion:67.59%, time:227 m:44 s, avg loss: 10.79, avg acc:0.0391%, last loss: 10.39
# Train completion:67.72%, time:228 m:10 s, avg loss: 10.79, avg acc:0.0390%, last loss: 10.24
# Train completion:67.85%, time:228 m:37 s, avg loss: 10.79, avg acc:0.0389%, last loss: 10.26
# Train completion:67.98%, time:229 m:3 s, avg loss: 10.79, avg acc:0.0388%, last loss: 10.09
# Train completion:68.11%, time:229 m:30 s, avg loss: 10.78, avg acc:0.0388%, last loss: 10.27
# Train completion:68.25%, time:229 m:56 s, avg loss: 10.78, avg acc:0.0387%, last loss: 10.23
# ...
# Train completion:94.51%, time:319 m:45 s, avg loss: 10.64, avg acc:0.0419%, last loss: 10.33
# Train completion:94.65%, time:320 m:11 s, avg loss: 10.64, avg acc:0.0418%, last loss: 10.25
# Train completion:94.78%, time:320 m:37 s, avg loss: 10.64, avg acc:0.0418%, last loss: 10.27
# Train completion:94.91%, time:321 m:4 s, avg loss: 10.64, avg acc:0.0417%, last loss: 10.20
# Train completion:95.04%, time:321 m:29 s, avg loss: 10.64, avg acc:0.0417%, last loss: 10.27
# Train completion:95.17%, time:321 m:55 s, avg loss: 10.64, avg acc:0.0416%, last loss: 10.16
# Train completion:95.31%, time:322 m:22 s, avg loss: 10.64, avg acc:0.0416%, last loss: 10.23
# Train completion:95.44%, time:322 m:49 s, avg loss: 10.64, avg acc:0.0415%, last loss: 10.21
# Train completion:95.57%, time:323 m:15 s, avg loss: 10.64, avg acc:0.0414%, last loss: 10.42
# Train completion:95.70%, time:323 m:42 s, avg loss: 10.64, avg acc:0.0414%, last loss: 10.26
# Train completion:95.83%, time:324 m:9 s, avg loss: 10.64, avg acc:0.0413%, last loss: 10.18
# Train completion:95.97%, time:324 m:35 s, avg loss: 10.63, avg acc:0.0413%, last loss: 10.21
# Train completion:96.10%, time:325 m:2 s, avg loss: 10.63, avg acc:0.0412%, last loss: 10.47
# Train completion:96.23%, time:325 m:29 s, avg loss: 10.63, avg acc:0.0412%, last loss: 10.22
# Train completion:96.36%, time:325 m:57 s, avg loss: 10.63, avg acc:0.0411%, last loss: 10.22
# Train completion:96.49%, time:326 m:22 s, avg loss: 10.63, avg acc:0.0410%, last loss: 10.11
# Train completion:96.63%, time:326 m:47 s, avg loss: 10.63, avg acc:0.0410%, last loss: 10.23
# Train completion:96.76%, time:327 m:13 s, avg loss: 10.63, avg acc:0.0409%, last loss: 10.21
# Train completion:96.89%, time:327 m:39 s, avg loss: 10.63, avg acc:0.0409%, last loss: 10.26
# Train completion:97.02%, time:328 m:6 s, avg loss: 10.63, avg acc:0.0408%, last loss: 10.25
# Train completion:97.15%, time:328 m:32 s, avg loss: 10.63, avg acc:0.0408%, last loss: 10.23
# Train completion:97.29%, time:328 m:59 s, avg loss: 10.63, avg acc:0.0407%, last loss: 10.30
# Train completion:97.42%, time:329 m:25 s, avg loss: 10.63, avg acc:0.0407%, last loss: 10.16
# Train completion:97.55%, time:329 m:52 s, avg loss: 10.63, avg acc:0.0406%, last loss: 10.17
# Train completion:97.68%, time:330 m:19 s, avg loss: 10.63, avg acc:0.0405%, last loss: 10.32
# Train completion:97.81%, time:330 m:46 s, avg loss: 10.63, avg acc:0.0405%, last loss: 10.47
# Train completion:97.95%, time:331 m:13 s, avg loss: 10.63, avg acc:0.0404%, last loss: 10.21
# Train completion:98.08%, time:331 m:41 s, avg loss: 10.63, avg acc:0.0404%, last loss: 10.22
# Train completion:98.21%, time:332 m:7 s, avg loss: 10.63, avg acc:0.0403%, last loss: 10.24
# Train completion:98.34%, time:332 m:34 s, avg loss: 10.63, avg acc:0.0403%, last loss: 10.24
# Train completion:98.47%, time:332 m:59 s, avg loss: 10.63, avg acc:0.0402%, last loss: 10.40
# Train completion:98.61%, time:333 m:25 s, avg loss: 10.62, avg acc:0.0402%, last loss: 10.25
# Train completion:98.74%, time:333 m:51 s, avg loss: 10.62, avg acc:0.0401%, last loss: 10.21
# Train completion:98.87%, time:334 m:17 s, avg loss: 10.62, avg acc:0.0401%, last loss: 10.16
# Train completion:99.00%, time:334 m:42 s, avg loss: 10.62, avg acc:0.0400%, last loss: 10.18
# Train completion:99.13%, time:335 m:8 s, avg loss: 10.62, avg acc:0.0399%, last loss: 10.19
# Train completion:99.27%, time:335 m:34 s, avg loss: 10.62, avg acc:0.0399%, last loss: 10.14
# Train completion:99.40%, time:335 m:59 s, avg loss: 10.62, avg acc:0.0398%, last loss: 10.24
# Train completion:99.53%, time:336 m:25 s, avg loss: 10.62, avg acc:0.0398%, last loss: 10.27
# Train completion:99.66%, time:336 m:51 s, avg loss: 10.62, avg acc:0.0397%, last loss: 10.16
# Train completion:99.79%, time:337 m:24 s, avg loss: 10.62, avg acc:0.0397%, last loss: 10.18
# Train completion:99.93%, time:337 m:56 s, avg loss: 10.62, avg acc:0.0396%, last loss: 10.24
# ----------------------------------------------------------------------------------------------------
# Eval for epoch 1/25 started
# ----------------------------------------------------------------------------------------------------
# Eval completion:1.38%, time:338 m:18 s, avg loss: 10.29, avg acc:0.0000%, last loss: 10.27
# Eval completion:2.75%, time:338 m:24 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.14
# Eval completion:4.13%, time:338 m:31 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.34
# Eval completion:5.51%, time:338 m:37 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.27
# Eval completion:6.88%, time:338 m:43 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.22
# Eval completion:8.26%, time:338 m:50 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.26
# Eval completion:9.64%, time:338 m:56 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# Eval completion:11.01%, time:339 m:3 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.26
# Eval completion:12.39%, time:339 m:9 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.36
# Eval completion:13.77%, time:339 m:14 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.33
# Eval completion:15.14%, time:339 m:21 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.29
# Eval completion:16.52%, time:339 m:27 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.41
# Eval completion:17.89%, time:339 m:33 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.32
# Eval completion:19.27%, time:339 m:39 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.12
# Eval completion:20.65%, time:339 m:45 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.36
# Eval completion:22.02%, time:339 m:52 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.31
# Eval completion:23.40%, time:339 m:58 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.56
# Eval completion:24.78%, time:340 m:4 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.30
# Eval completion:26.15%, time:340 m:11 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.13
# Eval completion:27.53%, time:340 m:17 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.16
# Eval completion:28.91%, time:340 m:23 s, avg loss: 10.28, avg acc:0.0000%, last loss: 10.28
# Eval completion:30.28%, time:340 m:29 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.33
# Eval completion:31.66%, time:340 m:36 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.05
# Eval completion:33.04%, time:340 m:42 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.20
# Eval completion:34.41%, time:340 m:48 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.18
# Eval completion:35.79%, time:340 m:55 s, avg loss: 10.27, avg acc:0.0000%, last loss: 10.14
# Eval completion:37.17%, time:341 m:2 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.35
# Eval completion:38.54%, time:341 m:9 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.27
# Eval completion:39.92%, time:341 m:15 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.23
# Eval completion:41.30%, time:341 m:21 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# Eval completion:42.67%, time:341 m:28 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.26
# Eval completion:44.05%, time:341 m:34 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.13
# Eval completion:45.43%, time:341 m:40 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.10
# Eval completion:46.80%, time:341 m:46 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.16
# Eval completion:48.18%, time:341 m:52 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.36
# Eval completion:49.55%, time:341 m:58 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.30
# Eval completion:50.93%, time:342 m:5 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.30
# Eval completion:52.31%, time:342 m:11 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.21
# Eval completion:53.68%, time:342 m:17 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.23
# Eval completion:55.06%, time:342 m:23 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# Eval completion:56.44%, time:342 m:30 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.17
# Eval completion:57.81%, time:342 m:36 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.27
# Eval completion:59.19%, time:342 m:42 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.46
# Eval completion:60.57%, time:342 m:49 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.22
# Eval completion:61.94%, time:342 m:55 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.38
# Eval completion:63.32%, time:343 m:1 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.50
# Eval completion:64.70%, time:343 m:7 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.16
# Eval completion:66.07%, time:343 m:14 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.29
# Eval completion:67.45%, time:343 m:20 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.24
# Eval completion:68.83%, time:343 m:26 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.30
# Eval completion:70.20%, time:343 m:32 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.24
# Eval completion:71.58%, time:343 m:39 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.36
# Eval completion:72.96%, time:343 m:45 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.15
# Eval completion:74.33%, time:343 m:51 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.32
# Eval completion:75.71%, time:343 m:58 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.53
# Eval completion:77.09%, time:344 m:4 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.32
# Eval completion:78.46%, time:344 m:11 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.23
# Eval completion:79.84%, time:344 m:18 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.15
# Eval completion:81.21%, time:344 m:24 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.27
# Eval completion:82.59%, time:344 m:31 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.22
# Eval completion:83.97%, time:344 m:37 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# Eval completion:85.34%, time:344 m:43 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.56
# Eval completion:86.72%, time:344 m:50 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.26
# Eval completion:88.10%, time:344 m:56 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.14
# Eval completion:89.47%, time:345 m:3 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.22
# Eval completion:90.85%, time:345 m:9 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.19
# Eval completion:92.23%, time:345 m:16 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# Eval completion:93.60%, time:345 m:22 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.37
# Eval completion:94.98%, time:345 m:28 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.18
# Eval completion:96.36%, time:345 m:34 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.26
# Eval completion:97.73%, time:345 m:40 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.26
# Eval completion:99.11%, time:345 m:46 s, avg loss: 10.26, avg acc:0.0000%, last loss: 10.28
# ----------------------------------------------------------------------------------------------------
# Completed epoch 1/25 in 345 m:50 s, avg train loss: 10.62, avg train acc: 0.0396%, avg eval loss: 10.26, avg eval acc: 0.0000
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Training for epoch 2/25 started
# ----------------------------------------------------------------------------------------------------
# Train completion:0.13%, time:346 m:17 s, avg loss: 10.13, avg acc:0.0000%, last loss: 10.12
# Train completion:0.26%, time:346 m:45 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.27
# Train completion:0.40%, time:347 m:10 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.14
# Train completion:0.53%, time:347 m:37 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.21
# Train completion:0.66%, time:348 m:3 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.18
# Train completion:0.79%, time:348 m:30 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.06
# Train completion:0.92%, time:348 m:56 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.12
# Train completion:1.06%, time:349 m:21 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.14
# Train completion:1.19%, time:349 m:48 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.16
# Train completion:1.32%, time:350 m:14 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.10
# Train completion:1.45%, time:350 m:39 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.21
# Train completion:1.58%, time:351 m:5 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.32
# Train completion:1.72%, time:351 m:31 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.18
# Train completion:1.85%, time:351 m:56 s, avg loss: 10.16, avg acc:0.0000%, last loss: 10.13
# Train completion:1.98%, time:352 m:22 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.14
# Train completion:2.11%, time:352 m:47 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.24
# Train completion:2.24%, time:353 m:14 s, avg loss: 10.15, avg acc:0.0000%, last loss: 10.18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <cell line: 12>()
#      31 _, pred=output.topk(1,dim=1)
#      33 loss.backward()
# ---> 34 optimizer.step()
#      35 lr_decay.step()
#      37 last_loss=loss.item()
#
# File ~\Anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:65, in _LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      63 instance._step_count += 1
#      64 wrapped = func.__get__(instance, cls)
# ---> 65 return wrapped(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\optimizer.py:109, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     107 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     108 with torch.autograd.profiler.record_function(profile_name):
# --> 109     return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:161, in AdamW.step(self, closure)
#     157             max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     159         state_steps.append(state['step'])
# --> 161     adamw(params_with_grad,
#     162           grads,
#     163           exp_avgs,
#     164           exp_avg_sqs,
#     165           max_exp_avg_sqs,
#     166           state_steps,
#     167           amsgrad=amsgrad,
#     168           beta1=beta1,
#     169           beta2=beta2,
#     170           lr=group['lr'],
#     171           weight_decay=group['weight_decay'],
#     172           eps=group['eps'],
#     173           maximize=group['maximize'],
#     174           foreach=group['foreach'],
#     175           capturable=group['capturable'])
#     177 return loss
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:218, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     215 else:
#     216     func = _single_tensor_adamw
# --> 218 func(params,
#     219      grads,
#     220      exp_avgs,
#     221      exp_avg_sqs,
#     222      max_exp_avg_sqs,
#     223      state_steps,
#     224      amsgrad=amsgrad,
#     225      beta1=beta1,
#     226      beta2=beta2,
#     227      lr=lr,
#     228      weight_decay=weight_decay,
#     229      eps=eps,
#     230      maximize=maximize,
#     231      capturable=capturable)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:313, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     310 else:
#     311     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 313 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
save_model_path=r"C:\Users\mihnea.andrei\Work\facial_recognition\saved_models"
save_file="/ViTm_WeightTransformerAttn,embedded=%d,depth=%d,eval_loss=%.4f,eval_acc=%d%%.pt"%(
    embed_dim,depth,np.mean(all_eval_losses),np.mean(all_eval_accs))

torch.save(model_fit,save_model_path+save_file)

# %%
plt.figure(figsize=(10,5))
plt.title("Train losses")
plt.plot(all_train_losses,label="train losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Evaluation losses")
plt.plot(all_eval_losses,label="eval losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Train accuracies")
plt.plot(all_train_accs,label="train accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Eval accuracies")
plt.plot(all_train_accs,label="eval accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()
